# %% [markdown]
# Let's try to query all the archiveTypes present on the wiki. This information is available through two properties:
#
# - ArchiveType present at the dataset level (not part of core)
# - ProxyArchiveType available at the variable level (part of core)
#
# This is the query from core:

# %%
import json
import requests

url = "http://wiki.linked.earth/store/db/query"

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?a 
WHERE {
{
    # ?w core:proxyArchiveType ?t.
    # ?t rdfs:label ?a
}
}"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)
print(response)
print("The following archive types are available on the wiki:")    
for item in res['results']['bindings']:
    print ("*" + item['a']['value'])
# Out:
# <Response [200]>
# The following archive types are available on the wiki:
# *Coral
# *GlacierIce
# *LakeSediment
# *MarineSediment
# *Speleothem

# %% [markdown]
# Doesn't return any of the ProxyArchiveTypes.
#
# This is the response from wiki:

# %%
import json
import requests

url = "http://wiki.linked.earth/store/db/query"

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?a 
WHERE {
{
    # ?dataset wiki:Property-3AArchiveType ?a.
}
}"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)
print(response)
print("The following archive types are available on the wiki:")    
for item in res['results']['bindings']:
    print ("*" + item['a']['value'])
# Out:
# <Response [200]>
# The following archive types are available on the wiki:
# *tree
# *marine sediment
# *speleothem
# *lake sediment
# *glacier ice
# *borehole
# *documents
# *hybrid
# *coral
# *bivalve
# *sclerosponge

# %% [markdown]
# Trying to go around the core issue is not easy because I don't know how to fix the URL interpretation of ':', '_', '(',')'

# %% [markdown]
# Trying to query through the wiki prefix but not sure how to deal with special characters in URL. See below:

# %%
# DataSetName = ["Aus-StewartIsland.D'Arrigo.1996", "Arc-BigRoundLake.Thomas.2009"]
DataSetName = ["ME0005A-43JC.Benway.2006"]

# %%
import json
import requests
import pandas as pd

url = "http://wiki.linked.earth/store/db/query"

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?dataset ?a
WHERE {"""

query+= "VALUES ?b {"
for item in DataSetName:
    query +="\""+item+"\" "
query+= "}\n"

query+= "?dataset wiki:Property-3AName%5F%28L%29 ?b. \n"
query+= ' ?dataset wiki:Property-3AArchiveType ?a \n}'

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

print(response,res)
#archiveType = []
#for item in res['results']['bindings']:
#    archiveType.append(item['a']['value'])

#results = pd.DataFrame({'dataset name': DataSetName,'archive type': archiveType})
#results
# Out:
# <Response [200]> {'head': {'vars': ['dataset', 'a']}, 'results': {'bindings': []}}

# %% [markdown]
# #### Get all the LiPD filenames from the wiki

# %%
import json
import requests

url = "http://wiki.linked.earth/store/db/query"

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
SELECT ?ds ?name
WHERE {
  # ?ds a core:Dataset .
  # ?ds core:name ?name
}"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

files_in_wiki = set()
for item in res['results']['bindings']:
    files_in_wiki.add(item['name']['value'])

# %%
files_in_wiki
# Out:
# {'A7.Oppo.2005',
#  'Afr-ColdAirCave.Sundqvist.2013',
#  'Afr-LakeMalawi.Powers.2011',
#  'Afr-LakeTanganyika.Tierney.2010',
#  'Afr-P178-15P.Tierney.2015',
#  'Ant-BerknerIsland.Mulvaney.2002',
#  'Ant-CoastalDML.Thamban.2012',
#  'Ant-DSS.DahlJensen.1999',
#  'Ant-DSS.Moy.2012',
#  'Ant-DomeC.Jouzel.2001',
#  'Ant-DomeC.Stenni.2001',
#  'Ant-DomeF1993.Uemura.2014',
#  'Ant-DomeF2001.Uemura.2008',
#  'Ant-Ferrigno.Thomas.2013',
#  'Ant-JamesRossIsland.Mulvaney.2013',
#  'Ant-MES.Rhodes.2012',
#  'Ant-PlateauRemote.Mosley-Thompson.2013',
#  'Ant-SipleStation.Mosley-Thompson.1990',
#  'Ant-SiteDML05.Graf.2002',
#  'Ant-SiteDML07.Graf.2002',
#  'Ant-SiteDML17.Graf.2002',
#  'Ant-TALDICE.Stenni.2010',
#  'Ant-TalosDome.Stenni.2002',
#  'Ant-TaylorDome.Steig.2000',
#  'Ant-US-ITASE-2000-1.Steig.2013',
#  'Ant-US-ITASE-2002-4.Steig.2013',
#  'Ant-VLG.Bertler.2011',
#  'Ant-Vostok.Ekaykin.2014',
#  'Ant-WAIS-Divide.Severinghaus.2012',
#  'Ant-WDC05A.Steig.2013',
#  'Ant-WDC06A.Steig.2013',
#  'Arc-Agassiz.Vinther.2008',
#  'Arc-AkademiiNaukIceCap.Opel.2013',
#  'Arc-Arjeplog.Bjorklund.2014',
#  'Arc-Armarnaes.Bjorklund.2012',
#  'Arc-Austfonna.Isaksson.2005',
#  'Arc-Avam-Taimyr.Briffa.2008',
#  'Arc-BigRoundLake.Thomas.2009',
#  'Arc-BlueLake.Bird.2008',
#  'Arc-CampCentury.Fisher.1969',
#  'Arc-Crete.Vinther.2010',
#  'Arc-DevonIceCap.Fisher.1983',
#  'Arc-Dye.Vinther.2010',
#  'Arc-Forfjorddalen.McCarroll.2013',
#  'Arc-GISP2.Grootes.1997',
#  'Arc-GRIP.Vinther.2010',
#  'Arc-GulfofAlaska.Wilson.2014',
#  'Arc-HalletLake.McKay.2008',
#  'Arc-HudsonLake.Clegg.2011',
#  'Arc-Hvítárvatn.Larsen.2011',
#  'Arc-Iceland.Bergthorsson.1969',
#  'Arc-Indigirka.Hughes.1999',
#  'Arc-Kittelfjall.Bjorklund.2012',
#  "Arc-Kongressvatnet.D'Andrea.2012",
#  'Arc-Laanila.Lindholm.2013',
#  'Arc-LakeC2.Lamoureux.1996',
#  'Arc-LakeDonardBaffinIsland.Moore.2001',
#  "Arc-LakeE.D'Andrea.2011",
#  'Arc-LakeLehmilampi.Haltia-Hovi.2007',
#  'Arc-LakeNataujärvi.Ojala.2005',
#  'Arc-LenaRiver.McDonald.1998',
#  'Arc-Lomonosovfonna.Divine.2011',
#  'Arc-LowerMurrayLake.Cook.2008',
#  'Arc-MD992275.Jiang.2005',
#  'Arc-MackenzieDelta.Porter.2013',
#  'Arc-NGTB16.Schwager.1998',
#  'Arc-PennyIceCapP96.Fisher.1998',
#  'Arc-PennyIceCapP96.Okuyama.2003',
#  'Arc-PolarUrals.Wilson.2015',
#  'Arc-PrinceOfWales.Kinnard.2011',
#  'Arc-SoperLake.Hughen.2000',
#  'Arc-StoreggaSlide.Sejrup.2011',
#  'Arc-Tjeggelvas.Bjorklund.2012',
#  'Arc-Tornetrask.Melvin.2012',
#  'Arc-VøringPlateau.Berner.2011',
#  'Arc-WindyDome.Henderson.2011',
#  'Arc-Yamalia.Briffa.2013',
#  "Arc-Yukon.D'Arrigo.2006",
#  'Asi-AltaiAktru.Cook.2005',
#  'Asi-AltaiDjasator.Cook.2011',
#  'Asi-AltaiJablonsky.Cook.2000',
#  'Asi-AltaiKorumdu.Cook.2005',
#  'Asi-AltaiKuraisky.Cook.2011',
#  'Asi-AltaiKuraiskySteppe.Cook.2011',
#  'Asi-AltaiSamakhaSteppe.Cook.2011',
#  'Asi-AltaiTjute.Cook.2011',
#  'Asi-AltaiUlaganValley.Cook.2011',
#  'Asi-AltaiUstUlaganLake.Cook.2005',
#  'Asi-BARELC.PAGES2k.2013',
#  'Asi-BHUTSP.PAGES2k.2013',
#  'Asi-BHUTTD.PAGES2k.2013',
#  'Asi-BT001.Cook.2010',
#  'Asi-BT002.Cook.2010',
#  'Asi-BT003.Cook.2010',
#  'Asi-BT004.Cook.2010',
#  'Asi-BT005.Cook.2010',
#  'Asi-BT006.Cook.2010',
#  'Asi-BT008.Cook.2010',
#  'Asi-BT009.Cook.2010',
#  'Asi-BT010.Cook.2010',
#  'Asi-BT011.Cook.2010',
#  'Asi-BT018.Cook.2010',
#  'Asi-BURGPW.PAGES2k.2013',
#  'Asi-CENTIB.PAGES2k.2013',
#  'Asi-CHIN004.Wu.2013',
#  'Asi-CHIN005.Sheppard.2013',
#  'Asi-CHIN006.Sheppard.2013',
#  'Asi-CHIN016.Li.2010',
#  'Asi-CHIN017.Li.2010',
#  'Asi-CHIN018.Li.2010',
#  'Asi-CHIN019.Li.2010',
#  'Asi-CHIN020.Li.2010',
#  'Asi-CHIN021.Li.2010',
#  'Asi-CHIN026.Wright.2010',
#  'Asi-CHIN029.Krusic.2010',
#  'Asi-CHIN037.Fan.2013',
#  'Asi-CHIN038.Fan.2013',
#  'Asi-CHIN039.Fan.2013',
#  'Asi-CHIN040.Fan.2013',
#  'Asi-CHIN041.Fan.2013',
#  'Asi-CHIN042.Brauning.2013',
#  'Asi-CHIN043.Brauning.2013',
#  'Asi-CHIN044.Brauning.2013',
#  'Asi-CHIN045.Brauning.2013',
#  'Asi-CHIN046.Brauning.2013',
#  'Asi-CHIN047.Brauning.2013',
#  'Asi-CHIN048.Brauning.2013',
#  'Asi-CHIN049.Brauning.2013',
#  'Asi-CHIN050.Shao.2013',
#  'Asi-CHIN051.Shao.2013',
#  'Asi-CHIN052.Shao.2013',
#  'Asi-CHIN053.Shao.2013',
#  'Asi-CHIN054.Shao.2013',
#  'Asi-CHIN055.Shao.2013',
#  'Asi-CHIN056.Shao.2013',
#  'Asi-CHIN057.Shao.2013',
#  'Asi-CHIN058.Shao.2013',
#  'Asi-CHIN059.Shao.2013',
#  'Asi-CHIN060.Shao.2013',
#  'Asi-CHIN061.Shao.2013',
#  'Asi-CHIN062.Shao.2013',
#  'Asi-CHIN063.Shao.2013',
#  'Asi-CHIN064.Shao.2013',
#  'Asi-CHIN065.Shao.2013',
#  'Asi-CHIN066.Shao.2013',
#  'Asi-CentralChina.Wang.1998',
#  'Asi-DEZQIN.PAGES2k.2013',
#  'Asi-DQHZHO.PAGES2k.2013',
#  'Asi-DUSHJP.PAGES2k.2013',
#  'Asi-Dasuopu.Thompson.2000',
#  'Asi-ENEPAB.PAGES2k.2013',
#  'Asi-ESPERG.PAGES2k.2013',
#  'Asi-ESPPAK.PAGES2k.2013',
#  'Asi-EastChina.Wang.1990',
#  'Asi-EastChina.Wang.1998',
#  'Asi-Fujian.Wang.1998',
#  'Asi-GANGCD.PAGES2k.2013',
#  'Asi-GHEGAN.PAGES2k.2013',
#  'Asi-GOUQIN.PAGES2k.2013',
#  'Asi-Guangdong.Zheng.1982',
#  'Asi-GuangdongAndGuangxi.Zhang.1980',
#  'Asi-Guliya.Thompson.1997',
#  'Asi-HBHXJP.PAGES2k.2013',
#  'Asi-HBLXJP.PAGES2k.2013',
#  'Asi-HBMXJP.PAGES2k.2013',
#  'Asi-HEBQIN.PAGES2k.2013',
#  'Asi-HRPCSM.PAGES2k.2013',
#  'Asi-HXBURU.PAGES2k.2013',
#  'Asi-HYGJUP.PAGES2k.2013',
#  'Asi-Hunan-Jiangsu.Zhang.1980',
#  'Asi-Hushre.PAGES2k.2013',
#  'Asi-INDI015.Borgaonkar.2013',
#  'Asi-INDI024.Borgaonkar.2013',
#  'Asi-INDI025.Borgaonkar.2013',
#  "Asi-INDO005.D'Arrigo.2010",
#  'Asi-JAPA012.Yasue.1997',
#  'Asi-JAPA013.Yasue.1997',
#  'Asi-JAPA014.Yasue.2013',
#  'Asi-JAPA015.Yasue.2013',
#  'Asi-JAPA016.Yasue.2013',
#  'Asi-JAPA017.Yasue.2013',
#  'Asi-JAPA019.Sano.2013',
#  'Asi-JAPA020.Kimura.2013',
#  'Asi-KAZ001.Solomina.2010',
#  'Asi-KERALA.PAGES2k.2013',
#  'Asi-KYRG002.Esper.2007',
#  'Asi-KYRG003.Esper.2007',
#  'Asi-KYRG004.Esper.2007',
#  'Asi-KYRG005.Esper.2007',
#  'Asi-KYRG007.Esper.2007',
#  'Asi-KYRG008.Shiyatov.2013',
#  'Asi-KYRG009.Shiyatov.2013',
#  'Asi-KYRG010.Shiyatov.2013',
#  'Asi-KYRG011.Shiyatov.2013',
#  'Asi-KYRG012.Solomina.2013',
#  'Asi-KYRG013.Solomina.2013',
#  'Asi-KYRG014.Solomina.2013',
#  'Asi-KYRG015.Solomina.2013',
#  'Asi-KunashirIsland.Demezhko.2009',
#  'Asi-LAJQIN.PAGES2k.2013',
#  'Asi-LowerYangtzeRiver.Zhang.1980',
#  'Asi-MCCHFH.Sano.2008',
#  'Asi-MONG002.Jacoby.2013',
#  'Asi-MONG004.Jacoby.2013',
#  'Asi-MONG006.Jacoby.2006',
#  'Asi-MONG007.Schweingruber.2013',
#  'Asi-MONG009.Jacoby.2013',
#  'Asi-MONG010.Jacoby.2013',
#  'Asi-MONG011.Jacoby.2006',
#  'Asi-MONG012.Jacoby.2006',
#  'Asi-MONG014.Jacoby.2013',
#  'Asi-MONG015.Jacoby.2013',
#  'Asi-MONG016.Jacoby.2010',
#  'Asi-MONG017.Jacoby.2010',
#  'Asi-MONG018.Jacoby.2010',
#  'Asi-MONG019.Jacoby.2010',
#  'Asi-MONG020.Jacoby.2010',
#  'Asi-MONG021.Jacoby.2010',
#  'Asi-MONG024.Jacoby.2010',
#  'Asi-MONG025.Jacoby.2010',
#  'Asi-MONG026.Jacoby.2010',
#  'Asi-MONG027.Jacoby.2010',
#  'Asi-MONG028.Jacoby.2010',
#  'Asi-MONG029.Jacoby.2010',
#  'Asi-MONG030.Jacoby.2010',
#  'Asi-MONG031.Jacoby.2010',
#  'Asi-MONG032.Jacoby.2010',
#  'Asi-MONG033.Jacoby.2010',
#  'Asi-MQACJP.PAGES2k.2013',
#  'Asi-MQAXJP.PAGES2k.2013',
#  'Asi-MQBXJP.PAGES2k.2013',
#  'Asi-MQDXJP.PAGES2k.2013',
#  'Asi-MQFXJP.PAGES2k.2013',
#  'Asi-MQRXJP.PAGES2k.2013',
#  'Asi-MTASMD.Davi.2013',
#  'Asi-MTASSP.Davi.2013',
#  'Asi-MiddleYangtzeRiver.Zhang.1980',
#  'Asi-NEPA003.Krusic.2013',
#  'Asi-NEPA010.Krusic.2013',
#  'Asi-NEPA014.Krusic.2013',
#  'Asi-NEPA015.Krusic.2013',
#  'Asi-NEPA018.Krusic.2013',
#  'Asi-NEPA019.Krusic.2013',
#  'Asi-NEPA021.Krusic.2013',
#  'Asi-NEPA025.Krusic.2013',
#  'Asi-NEPA027.Krusic.2013',
#  'Asi-NEPA029.Krusic.2013',
#  'Asi-NEPA030.Krusic.2013',
#  'Asi-NEPA032.Krusic.2013',
#  'Asi-NEPA036.Krusic.2013',
#  'Asi-NEPA042.Krusic.2010',
#  'Asi-NOGSAK.PAGES2k.2013',
#  'Asi-PAKI001.Esper.2007',
#  'Asi-PAKI002.Esper.2007',
#  'Asi-PAKI003.Esper.2007',
#  'Asi-PAKI004.Esper.2007',
#  'Asi-PAKI006.Esper.2007',
#  'Asi-PAKI007.Esper.2007',
#  'Asi-PAKI009.Esper.2007',
#  'Asi-PAKI010.Esper.2007',
#  'Asi-PAKI011.Esper.2007',
#  'Asi-PAKI012.Esper.2007',
#  'Asi-PAKI014.Esper.2007',
#  'Asi-PAKI015.Esper.2007',
#  'Asi-PAKI016.Esper.2007',
#  'Asi-PAKI017.Cook.2013',
#  'Asi-PAKI018.Cook.2013',
#  'Asi-PAKI020.Cook.2013',
#  'Asi-PAKI021.Cook.2013',
#  'Asi-PAKI022.Cook.2013',
#  'Asi-PAKI023.Cook.2013',
#  'Asi-PAKI024.Cook.2013',
#  'Asi-PAKI025.Cook.2013',
#  'Asi-PAKI027.Cook.2013',
#  'Asi-PAKI028.Cook.2013',
#  'Asi-PAKI029.Cook.2013',
#  'Asi-PAKI030.Cook.2013',
#  'Asi-PAKI031.Cook.2013',
#  'Asi-PAKI033.Cook.2013',
#  'Asi-PAKI035.Cook.2013',
#  'Asi-PAKI036.Cook.2013',
#  'Asi-PAKI039.Cook.2013',
#  'Asi-PAKI040.Cook.2011',
#  'Asi-PTCYUN.PAGES2k.2013',
#  'Asi-Puruogangri.Thompson.2006',
#  'Asi-QUMAJP.PAGES2k.2013',
#  'Asi-RANGCD.PAGES2k.2013',
#  'Asi-RUSS219.Jacoby.2010',
#  'Asi-RUSS236.Sano.2009',
#  'Asi-SANGTS.PAGES2k.2013',
#  'Asi-SHIESP.PAGES2k.2013',
#  'Asi-SHIYAT.PAGES2k.2013',
#  'Asi-SO90-39KG_SO130-275KL.Munz.2015',
#  'Asi-SODAPS.PAGES2k.2013',
#  'Asi-SihailongwaLake.Chu.2011',
#  'Asi-SourthAndMiddleUrals.Demezhko.2007',
#  'Asi-SouthChina.Wang.1998',
#  'Asi-TDAXJP.PAGES2k.2013',
#  'Asi-TDBXJP.PAGES2k.2013',
#  'Asi-TH001.Buckley.2010',
#  'Asi-TIANMU.PAGES2k.2013',
#  'Asi-TW001.Wright.2010',
#  'Asi-UKHEWD.Schweingruber.2002',
#  'Asi-UKHEWW.Schweingruber.2002',
#  'Asi-UKHLWD.Schweingruber.2002',
#  'Asi-UKHLWW.Schweingruber.2002',
#  'Asi-UKHMND.Schweingruber.2002',
#  'Asi-UKHMXD.Schweingruber.2002',
#  'Asi-UKHTRW.Schweingruber.2002',
#  'Asi-UULEWD.Schweingruber.2002',
#  'Asi-UULEWW.Schweingruber.2002',
#  'Asi-UULLWD.Schweingruber.2002',
#  'Asi-UULLWW.Schweingruber.2002',
#  'Asi-UULMND.Schweingruber.2002',
#  'Asi-UULMXD.Schweingruber.2002',
#  'Asi-UULTRW.Schweingruber.2002',
#  'Asi-VIET001.Buckley.2010',
#  'Asi-WEXYUN.Wright.2010',
#  'Asi-WULANJ.PAGES2k.2013',
#  'Asi-WXIYUN.Wright.2010',
#  'Asi-YKC.Yasue.2013',
#  'Asi-YKCOM.Yasue.2013',
#  'Asi-ZHANGX.PAGES2k.2010',
#  'Asi-ZHIDJP.Shao.2003',
#  'Asi-ZhejiangAndFujian.Zhang.1980',
#  'Aus-BuckleysChance.Buckley.1997',
#  'Aus-CTPEastTasmania.Allen.2001',
#  'Aus-CTPWestTasmania.Allen.2001',
#  'Aus-DuckholeLake.Saunders.2013',
#  'Aus-MtRead.Cook.2006',
#  'Aus-Oroko.Cook.2002',
#  'Aus-PinkPine.Duncan.2010',
#  "Aus-StewartIsland.D'Arrigo.1996",
#  'Aus-TakapariCedar.Xiong.2000',
#  'BJ8-03-13GGC.Linsley.2010',
#  'BJ8-03-70GGC.Linsley.2010',
#  'CO00COKY-SAMPLEDATA',
#  'DSDP502.deMenocal.1992',
#  'DSDP552.Shackleton.1984',
#  'DSDP607.Lisiecki.2005',
#  'DSDP610.Lisiecki.2005',
#  'Eur-CentralEurope.Dobrovolný.2009',
#  'Eur-CentralandEasternPyrenees.Pla.2004',
#  'Eur-CoastofPortugal.Abrantes.2011',
#  'Eur-EasternCarpathianMountains.Popa.2008',
#  'Eur-EuropeanAlps.Büntgen.2011',
#  'Eur-FinnishLakelands.Helama.2014',
#  'Eur-LakeSilvaplana.Larocque-Tobler.2010',
#  'Eur-LakeSilvaplana.Trachsel.2010',
#  'Eur-Lötschental.Büntgen.2006',
#  'Eur-MaritimeFrenchAlps.Büntgen.2012',
#  'Eur-NorthernScandinavia.Esper.2012',
#  'Eur-NorthernSpain.Martín-Chivelet.2011',
#  'Eur-RAPiD-17-5P.Moffa-Sanchez.2014',
#  'Eur-Seebergsee.Larocque-Tobler.2012',
#  'Eur-SpanishPyrenees.Dorado-Linan.2012',
#  'Eur-SpannagelCave.Mangini.2005',
#  'Eur-Stockholm.Leijonhufvud.2009',
#  'Eur-Tallinn.Tarand.2001',
#  'Eur-TatraMountains.Büntgen.2013',
#  'GIK16160-3.Wang.2003',
#  'GIK17748-2.Kim.2002',
#  'GIK17940-2.Pelejero.1999',
#  'GIK23258.Sarnthein.2003',
#  'GeoB10042-1.Setiawan.2016',
#  'GeoB10043-3.Setiawan.2016',
#  'GeoB10069-3.Gibbons.2014',
#  'GeoB1023-5.Kim.2002',
#  'GeoB12605-3.Kuhnert.2014',
#  'GeoB12610-2.Rippert.2015',
#  'GeoB3129-1.Weldeab.2006',
#  'GeoB33021.Kim.2002',
#  'GeoB3911-3.Weldeab.2006',
#  'GeoB5844-2.Arz.2003',
#  'GeoB7702-3.Castaneda.2010',
#  'JM98-1-PC.Husum.2004',
#  'JR51GC35.Bendle.2007',
#  'Juxtlahuaca.Lachniet.2012',
#  'Juxtlahuaca.Lachniet.2013',
#  'Juxtlahuaca.Lachniet.2017',
#  'KNR-159-5_33GGC.Lacerra.2017',
#  'KNR-159-5_78GGC.Lacerra.2017',
#  'KNR166-2-26JPC.Schmidt.2011',
#  'KNR166-2JPC51.Schmidt.2012',
#  'KNR195-5 CDH26.Bova.2015',
#  'KNR195-5-CDH23.Bova.2015',
#  'KT05-7_PC02.Kawahata.2009',
#  'Kesang.Cheng.2012',
#  'Kurupa.Boldt.2015',
#  'LV29-114-3.Max.2012',
#  'LakeSurprise.Falster.2018',
#  'M25_4-KL1.Emeis.2000',
#  'M35003-4.Ruehlemann.1999',
#  'M77-2_056.Nurnberg.2015',
#  'MD01-2378.Xu.2008',
#  'MD01-2390.Steinke.2008',
#  'MD01-2412.Harada.2006',
#  'MD02-2575.Ziegler.2008',
#  'MD03-2601.Kim.2012',
#  'MD03-2797.Weldeab.2007',
#  'MD05-2904.Steinke.2011',
#  'MD95-2015.Marchal.2002',
#  'MD95-2043.Cacho.1999',
#  'MD97-2121.Marr.2013',
#  'MD97-2141.Rosentha.2003',
#  'MD972120-MD972121.Pahnke.2006',
#  'MD98-2165.Levi.2007',
#  'MD98-2170.Stott.2004',
#  'MD982176.Stott.2004',
#  'MD982181.Khider.2014',
#  'ME0005A-43JC.Benway.2006',
#  "NAm-AlmondButterLower.D'Arrigo.2005",
#  "NAm-AlmondButterUpper.D'Arrigo.2005",
#  'NAm-Arapahoe.Kienast.1996',
#  'NAm-ArrowsmithMountain.Briffa.1996',
#  'NAm-Athabasca.Schweingruber.1996',
#  'NAm-AthabascaGlacier.Schweingruber.1996',
#  'NAm-AthabascaGlacier2.Luckman.2005',
#  'NAm-BakerLake.Hughes.2005',
#  'NAm-BarlowPassamMtHood.Briffa.1996',
#  'NAm-BasinPond.Gajewski.1988',
#  'NAm-BellMountain.Schweingruber.1996',
#  'NAm-Bennington.Luckman.2001',
#  'NAm-Bennington.Luckman.2013',
#  'NAm-BigBendLake.Jacoby.2003',
#  'NAm-BigWhite.Parish.2000',
#  'NAm-BigWhite2.Wilson.2005',
#  'NAm-BlanchardRiver.Luckman.2013',
#  'NAm-Bonif.Schweingruber.1996',
#  'NAm-BorealPlateau.Graumlich.2005',
#  'NAm-BowSummit-PeytoLake.Luckman.2005',
#  "NAm-BurntOver.D'Arrigo.2005",
#  'NAm-CameronPass.Bigler.2007',
#  'NAm-CanyonCreek.Lloyd.2002',
#  'NAm-CardinalDivide.Luckman.2001',
#  'NAm-CarltonRidge.Kipfmuller.2008',
#  'NAm-CeaderBreaks.Briffa.1996',
#  'NAm-CienegadeNuestraSenoradeGuadalupe.Fule.2009',
#  'NAm-CirquePeak.Graybill.1995',
#  'NAm-ClearPond.Gajewski.1988',
#  'NAm-ConroyLake.Gajewski.1988',
#  'NAm-CoppermineRiver.Jacoby.1989',
#  'NAm-CornwallHills.Wilson.2005',
#  'NAm-CottonwoodPass.Briffa.1996',
#  'NAm-CraterLakeNE.Briffa.2002',
#  'NAm-DanaPlateauInyoNationalForest.King.2000',
#  'NAm-DarkLake.Gajewski.1988',
#  'NAm-DeerMountain.Wiles.2011',
#  'NAm-DenaliNationalPark.Schweingruber.1996',
#  'NAm-DonJekRiverBridge.Schweingruber.1996',
#  'NAm-EagleFecal_PtarmiganMerge.Jacoby.2011',
#  'NAm-ElephantMountain.Conkey.1994',
#  'NAm-EurekaSummit.Schweingruber.1996',
#  'NAm-FirthRiver.Anchukaitis.2013',
#  'NAm-FishCreekTrail.Biondi.2001',
#  'NAm-FlintCreekRange.Hughes.2005',
#  'NAm-FlowerLake.Graybill.1995',
#  'NAm-FoolCreek.Brown.2005',
#  'NAm-FortChimo.Fritts.1981',
#  'NAm-FremontGlacier.Hill.0',
#  'NAm-FrenchGlacier.Colenutt.1995',
#  'NAm-GalenaPassSawtooth.Briffa.1996',
#  'NAm-GeraldineLakes.Luckman.2001',
#  'NAm-GraniteMountain.Graumlich.2003',
#  'NAm-GranitePassHuntMountain.Briffa.1996',
#  'NAm-GreatBasin.Salzer.2013',
#  'NAm-GreenLake.Menounos.2006',
#  'NAm-HartsPassN2.Peterson.1994',
#  'NAm-HellsKitchenLake.Gajewski.1988',
#  'NAm-HerringAlpine.Fritts.1995',
#  'NAm-HighlandFireOutlook.Briffa.1996',
#  'NAm-HighwoodPass.Luckman.2001',
#  'NAm-Hilda.Kavanagh.2000',
#  'NAm-HohLakeHigh.Peterson.1994',
#  'NAm-HornbyCabin.Jacoby.1989',
#  "NAm-IttyhaukBay.D'Arrigo.2011",
#  'NAm-KobukNoatak.King.2003',
#  'NAm-LaTasajera.Biondi.2001',
#  'NAm-LacNoir.Paquette.2013',
#  'NAm-LacRomanel.Schweingruber.1996',
#  'NAm-LakeMina.St.Jacques.2008',
#  'NAm-LakeoftheClouds.Gajewski.1988',
#  'NAm-Landslide.Luckman.2006',
#  'NAm-LittlePineLake.Gajewski.1988',
#  "NAm-Manitoba.D'Arrigo.2006",
#  'NAm-McGinnisTrail.Wiles.2013',
#  'NAm-MeadowMountain.Wilson.2005',
#  'NAm-MedicineBowPeak.Briffa.1996',
#  'NAm-MedusaBay.Buckley.2003',
#  'NAm-MinersWell.Wiles.2000',
#  'NAm-MountAdamsLow.Peterson.1994',
#  'NAm-MountWashington.Graybill.1994',
#  'NAm-MtLemon.Briffa.2002',
#  'NAm-MtStHelens.Briffa.1996',
#  'NAm-NabesnaMine.Jacoby.2003',
#  'NAm-Nadahini.Luckman.2013',
#  'NAm-Nakiska.Luckman.2001',
#  "NAm-NorthernAlaskaComposite.D'Arrigo.2006",
#  'NAm-OregonCaves.Ersek.2012',
#  'NAm-ParkMountain.Wilson.2005',
#  'NAm-PearlPeak.Graybill.1994',
#  'NAm-PethaiPeninsula.Schweingruber.1996',
#  'NAm-PeytoLake.Schweingruber.1996',
#  'NAm-PikePeaks.Harlan.1996',
#  'NAm-Pintlers.Littell.2011',
#  'NAm-PintlersTwo.Littell.2011',
#  'NAm-PowderRiverPass.Briffa.1996',
#  'NAm-PrinceWilliamSound.Barclay.1999',
#  'NAm-PyramidMountain.Luckman.2001',
#  'NAm-RedMountainPassSilverton.Graybill.1994',
#  'NAm-RockGlacierYukon.Kenigsberg.2013',
#  'NAm-RoweLakes.Colenutt.2011',
#  'NAm-RubyLake.Gajewski.1988',
#  'NAm-STREC.Gennaretti.2014',
#  'NAm-SanFrancisoPeaksUpdate.Graybill.2005',
#  'NAm-ScatterLake.Graumlich.2003',
#  'NAm-SettlementPointAfognakIsland.Harlan.1998',
#  "NAm-SewardComposite.D'Arrigo.2006",
#  'NAm-SheepMountain.Graybill.1995',
#  'NAm-SheepTrail.Brown.2005',
#  'NAm-ShermanCreekPass.Briffa.1996',
#  'NAm-SiberianOutpostView.Bunn.2010',
#  'NAm-SignalMountain.Luckman.2001',
#  'NAm-SleepingDeerRoad.Hughes.2005',
#  'NAm-SmallRiver.Luckman.2001',
#  'NAm-SmithersSkiArea.Schweingruber.1996',
#  'NAm-SnakeCreek.Kenigsberg.2013',
#  'NAm-SnowBowlSanFranciscoPeak.Briffa.2002',
#  "NAm-SouthernAlaskacomposite.D'Arrigo.2006",
#  'NAm-SpillwayLakeYosemiteNationalPark.King.2000',
#  'NAm-SpruceCreek.Church.1981',
#  'NAm-StarrigawanOldSitka.Kaiser.1996',
#  'NAm-Sugarloaf.Kenigsberg.2013',
#  'NAm-SunshineMeadows.Colenutt.1995',
#  'NAm-SunwaptaPass.Schweingruber.1996',
#  'NAm-SurpriseValley.Luckman.2001',
#  'NAm-SylvanPassbeiCody.Briffa.1996',
#  'NAm-TamarackBowl.Sauchyn.2016',
#  'NAm-TimberGapUpper.Graybill.1995',
#  'NAm-TogwateePass.Briffa.1996',
#  'NAm-TwistedTreeHeartrotHill.Jacoby.1989',
#  'NAm-UpperWrightLakes.Graumlich.2005',
#  'NAm-VancouverCyprusProvincialPark.Briffa.1996',
#  'NAm-VicaryMine.Sauchyn.2016',
#  "NAm-WindyRidgeAlaska.D'Arrigo.2005",
#  "NAm-WrangellsComposite.D'Arrigo.2006",
#  'NAm-YellowMountainRidge.King.2002',
#  'NAm-Ymir.Wilson.2005',
#  'NAm-YosemiteParkEEingang.Briffa.1996',
#  'NAm-wa069.Peterson.1994',
#  'NAm-wa071.Peterson.1994',
#  'ODP1019.Barron.2003',
#  'ODP1098B.Shevenell.2011',
#  'ODP658.Sarnthein.1989',
#  'ODP659.Tiedemann.1994',
#  'ODP662.Lisiecki.2005',
#  'ODP664.Raymo.1997',
#  'ODP976.Jimenez-Amat.2015',
#  'Ocn-AbrahamReef.Druffel.1999',
#  'Ocn-AlboranSea384B.Nieto-Moreno.2013',
#  'Ocn-AlboranSea436B.Nieto-Moreno.2013',
#  'Ocn-AmedeeIsland.DeLong.2012',
#  'Ocn-AqabaJordanAQ18.Heiss.1999',
#  'Ocn-AqabaJordanAQ19.Heiss.1999',
#  'Ocn-ArabianSea.Doose-Rolinski.2001',
#  'Ocn-Bermuda.DraschbaA.2000',
#  'Ocn-Bermuda.DraschbaB.2000',
#  'Ocn-BermudaSouthShore.Goodkin.2008',
#  'Ocn-BiscayneBay.Swart.1996',
#  'Ocn-BuccooReefTobagoMontastrea.Moses.2006',
#  'Ocn-BuccooReefTobagoSidereastrea.Moses.2006',
#  'Ocn-BunakenIsland.Charles.2003',
#  'Ocn-BundegireefNingaloo.Cooper.2012',
#  'Ocn-CH07-98-MC-22.Saenger.2011',
#  'Ocn-CapeGhir.Doose-Rolinski.2007',
#  'Ocn-CapeGhir.McGregor.2007',
#  'Ocn-CapeHatteras.Cleroux.2008',
#  'Ocn-CariacoBasin.Black.2007',
#  'Ocn-CariacoBasin.Lea.2003',
#  'Ocn-ChileanMargin.Lamy.2002',
#  'Ocn-ClerkeReefRowleyShoals.Cooper.2012',
#  'Ocn-Clipperton1b.Wu.2014',
#  'Ocn-Clipperton2b.Wu.2014',
#  'Ocn-Clipperton4b.Wu.2014',
#  'Ocn-Clipperton6a.Wu.2014',
#  'Ocn-ClippertonAtoll.Linsley.2000',
#  'Ocn-CoralBayNingaloo.Cooper.2012',
#  'Ocn-CoralSea.Calvo.2007',
#  'Ocn-DoubleReef.Asami.2005',
#  'Ocn-DryTortugas.DeLong.2014',
#  'Ocn-DryTortugas.Lund.2006',
#  'Ocn-DryTortugasA.Lund.2006',
#  'Ocn-EasternTropicalNorthAtlantic.Kuhnert.2011',
#  'Ocn-EmeraldBasin.Keigwin.2003',
#  'Ocn-FiskBasin.Richey.2009',
#  'Ocn-FloridaBay.Swart.1996',
#  'Ocn-GBR.Wei.2009',
#  'Ocn-GarrisonBasin.Richey.2009',
#  'Ocn-GingerbreadsBahamas.Saenger.2009',
#  'Ocn-GreatBahamaBank.Lund.2006',
#  'Ocn-GreatBahamaBank.Richter.2006',
#  'Ocn-GreatBarrierReef.Hendy.2002',
#  'Ocn-Guadeloupe.Steinhilber.2010',
#  'Ocn-GulfofGuinea.Weldeab.2007',
#  'Ocn-GulfofMaine.Wanamaker.2007',
#  'Ocn-HaferaIsland.Wu.2013',
#  'Ocn-HoutmanAbrolhos.Kuhnert.1999',
#  'Ocn-HoutmanAbrolhosHAB05B.Zinke.2014',
#  'Ocn-HoutmanAbrolhosHAB10A.Zinke.2014',
#  'Ocn-HoutmanAbrolhosIslands.Cooper.2012',
#  'Ocn-Ifaty1.Zinke.2014',
#  'Ocn-Ifaty4.Zinke.2004',
#  'Ocn-IfatyTul3.Zinke.2014',
#  'Ocn-ImperieuseRowleyShoals.Cooper.2012',
#  'Ocn-JacafFjord.Sepúlveda.2009',
#  'Ocn-KNR140‐2‐59GGC.Saenger.2011',
#  'Ocn-Kiritimati.Evans.1998',
#  'Ocn-KuroshioCurrent.Isono.2009',
#  'Ocn-LaingIslandPapuaNewGuinea.Tudhope.2001',
#  'Ocn-LaurentianFan.Keigwin.2005',
#  'Ocn-Lombok.Charles.2003',
#  'Ocn-LosRoques.Hetzinger.2008',
#  'Ocn-MD95-2011.Grimalt.2002',
#  'Ocn-MD98-2160.Newton.2010',
#  'Ocn-MD98-2177.Newton.2010',
#  'Ocn-MadangLagoonPapuaNewGuinea.Kuhnert.2001',
#  'Ocn-MadangLagoonPapuaNewGuinea.Tudhope.1995',
#  'Ocn-Mafia.Damassa.2006',
#  'Ocn-Mahe.Charles.1997',
#  'Ocn-Maiana.Urban.2000',
#  'Ocn-MakassarStrait.Linsley.2010',
#  'Ocn-MakassarStrait.Oppo.2009',
#  'Ocn-Malindi.Cole.2000',
#  'Ocn-Malindi.Nakamura.2009',
#  'Ocn-MaloChannelEspirituSantoIsland.Kilbourne.2004',
#  'Ocn-Mayotte.Zinke.2008',
#  'Ocn-MentawaiIslands.Abram.2008',
#  'Ocn-MinorcaContourite.Moreno.2012',
#  'Ocn-Miyanohama.Felis.2009',
#  'Ocn-MontegoBayJamaica.Haase-Schramm.2003',
#  'Ocn-Moorea.Boiseau.1998',
#  'Ocn-Nauru.Guilderson.1999',
#  'Ocn-NewIrelandPapua.Alibert.2008',
#  'Ocn-Ningaloo.Kuhnert.2000',
#  'Ocn-NorthEastBreakers_Bermuda.Kuhnert.2002',
#  'Ocn-NorthEastBreakers_Bermuda.Kuhnert.2005',
#  'Ocn-NorthIceland.Sicre.2011',
#  'Ocn-NorthwestPacificOcean.Harada.2004',
#  'Ocn-ODP984.Came.2007',
#  'Ocn-OkinawaTrough.Wu.2012',
#  'Ocn-PalauRockIslands.Osborne.2014',
#  'Ocn-PalauUlongChannel.Osborne.2014',
#  'Ocn-Palmyra.Cobb.2003',
#  'Ocn-Palmyra.Nurhati.2011',
#  'Ocn-PedradeLume-CapeVerdeIslands.Moses.2006',
#  'Ocn-PedroBankJamaica.Haase-Schramm.2003',
#  'Ocn-Philippines.Stott.2007',
#  'Ocn-PigmyBasin.Richey.2015',
#  'Ocn-PuntaMaroma.Vásquez-Bedoya.2012',
#  'Ocn-RAPiD-12-1K.Thornalley.2009',
#  'Ocn-Rabaul.Quinn.2006',
#  'Ocn-RarotongaSrCa2r.Linsley.2006',
#  'Ocn-Rarotonga_d18O2R.Linsley.2006',
#  'Ocn-Rarotonga_d18O3R.Linsley.2006',
#  'Ocn-Rarotonga_d18O99.Linsley.2006',
#  'Ocn-RedSea.Felis.2000',
#  'Ocn-Reunion.Pfeiffer.2004',
#  'Ocn-SWCoastOfIndia.Saraswat.2013',
#  'Ocn-SantaBarbaraBasin.Zhao.2000',
#  'Ocn-SavusavuBay1F.Linsley.2006',
#  'Ocn-SavusavuBayAB.Linsley.2006',
#  'Ocn-SavusavuBayFiji.Bagnato.2005',
#  'Ocn-SecasIslandPanama.Linsley.1994',
#  'Ocn-SinaiPeninsula,RedSea.Moustafa.2000',
#  'Ocn-SouthAtlanticWestAfrica.Leduc.2010',
#  'Ocn-SouthIceland.Sicre.2011',
#  'Ocn-SouthernChileMargin.Mohtadi.2007',
#  'Ocn-SubTropicalEasternNorthAtlantic.deMenocal.2000',
#  'Ocn-TagusMudPatch.Abrantes.2005',
#  'Ocn-TantabiddiReefNingaloo.Cooper.2012',
#  'Ocn-Tarawa.Cole.1990',
#  'Ocn-TongueoftheOcean.Rosenheim.2005',
#  'Ocn-TongueoftheOceanExuma.Rosenheim.2005',
#  'Ocn-TurrumoteReefPuertoRico.Kilbourne.2008',
#  'Ocn-UrvinaBay.Dunbar.1994',
#  'Ocn-Vanuatu.Gorman.2012',
#  'Ocn-Vanuatu.Quinn.1996',
#  'Ocn-WEqPacific.Stott.2007',
#  'Ocn-WesternAntarcticPeninsula.Shevenell.2011',
#  'Ocn-WesternSvalbard.Spielhagen.2011',
#  'Ocn-XishaIslandSouthChinaSea.Sun.2004',
#  'P178-15P.Tierney.2015',
#  'Palmyra.Cobb.2013',
#  'SAm-CentralAndes11.PAGES2k.2011',
#  'SAm-CentralAndes15.Neukom.2014',
#  'SAm-CentralAndes6.Villalba.2014',
#  'SAm-CentralAndes9.Mundo.2014',
#  'SAm-LagunaAculeo.vonGunten.2009',
#  'SAm-LagunaChepical.deJong.2013',
#  'SAm-LagunaEscondida.Elbert.2013',
#  'SAm-QuelccayaIceCap.Thompson.2013',
#  'SK168-GC1.Gebregiorgis.2016',
#  'SK237-GC04.Saraswat.2013',
#  'TR163-22.Lea.2006',
#  'TestDataset.2017.Khider'}

# %% [markdown]
# #### For a filename , get the archive Type

# %%
DataSetName = ["Aus-StewartIsland.D'Arrigo.1996", "Arc-BigRoundLake.Thomas.2009"]
# DataSetName = ["Afr-LakeMalawi.Powers.2011"]

# %% [markdown]
# These datasets have an archiveType.
# http://wiki.linked.earth/Aus-StewartIsland.D%27Arrigo.1996
# http://wiki.linked.earth/Arc-BigRoundLake.Thomas.2009

# %%
import json
import requests
import pandas as pd

url = "http://wiki.linked.earth/store/db/query"

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?dataset ?a ?pot
WHERE {"""

query+= "VALUES ?b {"
for item in DataSetName:
    query +="\""+item+"\" "
query+= "}\n"

query+= "?dataset core:name ?b. \n"
query+= ' ?dataset wiki:Property-3AArchiveType ?a. \n}'
# query+= ' ?dataset core:includesPaleoData ?pd. \n}'
# query+= ' ?pd core:foundInMeasurementTable ?table. \n}'
# query+= ' ?table core:includesVariable ?var . \n}'
# query+= ' ?var core:proxyObservationType ?pot \n}'

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

#archiveType = []
#for item in res['results']['bindings']:
#    archiveType.append(item['a']['value'])

#results = pd.DataFrame({'dataset name': DataSetName,'archive type': archiveType})
#results

print(response, res)
# Out:
# <Response [200]> {'head': {'vars': ['dataset', 'a', 'pot']}, 'results': {'bindings': [{'dataset': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Aus-2DStewartIsland.D-27Arrigo.1996'}, 'a': {'type': 'literal', 'value': 'tree'}}, {'dataset': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Arc-2DBigRoundLake.Thomas.2009'}, 'a': {'type': 'literal', 'value': 'lake sediment'}}]}}

# %% [markdown]
# To see how many lipd files have paleodata from all the files in the wiki

# %%
import os
import sys
import json
import requests
import urllib

# datasetname = "Afr-LakeMalawi.Powers.2011"
datasetname = "Arc-BigRoundLake.Thomas.2009"

endpoint = "http://wiki.linked.earth/store/db/query" # Query Metadata
wikiapi = "http://wiki.linked.earth/wiki/api.php" # Fetch file data

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
SELECT ?name ?data ?pot
WHERE {
  # ?ds a core:Dataset .
  # ?ds core:name ?name .
  # ?ds core:includesPaleoData ?data .
  # ?data core:foundInMeasurementTable ?table .
  # ?table core:includesVariable ?var .
}"""
# ?data core:foundInMeasurementTable ?table .
#   ?table core:includesVariable ?var .
#   ?var core:proxyObservationType ?pot.

# ?table core:hasFileName ?filename

# ?ds core:name '""" + datasetname + """' .
response = requests.post(endpoint, data = {'query': query})
res = json.loads(response.text)
# print(response, res)

files_with_paleo = set()
for item in res['results']['bindings']:
    files_with_paleo.add(item['name']['value'])

# %%
len(files_with_paleo)
# Out:
# 157

# %%
file_list = list(files_with_paleo.intersection(files_in_wiki))
print(file_list)
len(file_list)
# Out:
# ['NAm-SnowBowlSanFranciscoPeak.Briffa.2002', 'Arc-PolarUrals.Wilson.2015', 'Aus-MtRead.Cook.2006', 'Asi-KYRG008.Shiyatov.2013', 'Asi-BT010.Cook.2010', "NAm-SewardComposite.D'Arrigo.2006", 'Ocn-AbrahamReef.Druffel.1999', 'Ocn-BermudaSouthShore.Goodkin.2008', 'Ocn-CH07-98-MC-22.Saenger.2011', 'Asi-KYRG004.Esper.2007', 'Ocn-JacafFjord.Sepúlveda.2009', 'Asi-PAKI035.Cook.2013', 'NAm-Bonif.Schweingruber.1996', 'NAm-SunwaptaPass.Schweingruber.1996', 'NAm-SpruceCreek.Church.1981', 'SAm-CentralAndes11.PAGES2k.2011', 'Arc-StoreggaSlide.Sejrup.2011', "NAm-SouthernAlaskacomposite.D'Arrigo.2006", 'Ocn-SWCoastOfIndia.Saraswat.2013', 'Asi-CHIN017.Li.2010', 'M77-2_056.Nurnberg.2015', 'Asi-CHIN044.Brauning.2013', 'Eur-NorthernSpain.Martín-Chivelet.2011', 'Asi-BT005.Cook.2010', 'Ocn-AqabaJordanAQ19.Heiss.1999', 'Ocn-CariacoBasin.Black.2007', 'MD95-2043.Cacho.1999', 'Eur-SpanishPyrenees.Dorado-Linan.2012', 'NAm-CraterLakeNE.Briffa.2002', 'Asi-NEPA015.Krusic.2013', "Aus-StewartIsland.D'Arrigo.1996", 'Ocn-Rarotonga_d18O99.Linsley.2006', 'Ocn-Mafia.Damassa.2006', 'Asi-NEPA030.Krusic.2013', 'Ocn-CariacoBasin.Lea.2003', 'Ant-US-ITASE-2002-4.Steig.2013', 'Asi-ZhejiangAndFujian.Zhang.1980', 'Ocn-PedradeLume-CapeVerdeIslands.Moses.2006', 'Asi-CHIN037.Fan.2013', 'Arc-PennyIceCapP96.Okuyama.2003', 'Juxtlahuaca.Lachniet.2012', 'Ocn-ODP984.Came.2007', 'Arc-Agassiz.Vinther.2008', 'Asi-NOGSAK.PAGES2k.2013', 'Ocn-AmedeeIsland.DeLong.2012', 'ODP1019.Barron.2003', 'Asi-MONG030.Jacoby.2010', 'Asi-Hushre.PAGES2k.2013', 'Aus-TakapariCedar.Xiong.2000', 'MD01-2390.Steinke.2008', 'Ocn-IfatyTul3.Zinke.2014', 'Asi-MONG033.Jacoby.2010', 'Asi-HYGJUP.PAGES2k.2013', 'Asi-GuangdongAndGuangxi.Zhang.1980', 'Arc-MD992275.Jiang.2005', 'NAm-HerringAlpine.Fritts.1995', 'Asi-TW001.Wright.2010', 'Arc-LakeDonardBaffinIsland.Moore.2001', 'NAm-MtLemon.Briffa.2002', 'NAm-RedMountainPassSilverton.Graybill.1994', 'NAm-Bennington.Luckman.2013', 'Arc-LakeNataujärvi.Ojala.2005', 'Asi-CHIN018.Li.2010', 'DSDP502.deMenocal.1992', 'NAm-CanyonCreek.Lloyd.2002', "Arc-Kongressvatnet.D'Andrea.2012", 'GeoB10069-3.Gibbons.2014', 'Arc-SoperLake.Hughen.2000', 'SAm-CentralAndes6.Villalba.2014', 'Ant-DomeC.Stenni.2001', 'Ocn-NorthwestPacificOcean.Harada.2004', 'Ocn-BuccooReefTobagoSidereastrea.Moses.2006', 'NAm-PyramidMountain.Luckman.2001', 'Ocn-Ifaty1.Zinke.2014', 'Asi-PAKI030.Cook.2013', 'Ocn-NorthIceland.Sicre.2011', 'Afr-LakeTanganyika.Tierney.2010', 'Asi-CHIN059.Shao.2013', 'Asi-JAPA015.Yasue.2013', 'Asi-PAKI010.Esper.2007', 'Asi-ZHIDJP.Shao.2003', 'Ocn-Rarotonga_d18O3R.Linsley.2006', 'Asi-MONG032.Jacoby.2010', 'Eur-CentralandEasternPyrenees.Pla.2004', 'Ocn-Rabaul.Quinn.2006', 'Ocn-AlboranSea384B.Nieto-Moreno.2013', 'NAm-SunshineMeadows.Colenutt.1995', 'Asi-KYRG013.Solomina.2013', 'Asi-NEPA027.Krusic.2013', 'Asi-CHIN049.Brauning.2013', 'Asi-MONG031.Jacoby.2010', 'Ocn-Nauru.Guilderson.1999', 'Asi-CHIN004.Wu.2013', 'Ocn-MakassarStrait.Linsley.2010', 'Ocn-AlboranSea436B.Nieto-Moreno.2013', 'Asi-RUSS219.Jacoby.2010', 'Asi-Guangdong.Zheng.1982', 'Asi-BT009.Cook.2010', 'Asi-CHIN063.Shao.2013', 'Asi-KYRG007.Esper.2007', 'Asi-SODAPS.PAGES2k.2013', 'Afr-P178-15P.Tierney.2015', 'Asi-AltaiJablonsky.Cook.2000', 'Asi-PAKI022.Cook.2013', 'NAm-Arapahoe.Kienast.1996', 'NAm-Sugarloaf.Kenigsberg.2013', 'Ocn-WEqPacific.Stott.2007', 'SK168-GC1.Gebregiorgis.2016', 'NAm-MedicineBowPeak.Briffa.1996', 'NAm-FoolCreek.Brown.2005', 'Ant-VLG.Bertler.2011', 'Ocn-EasternTropicalNorthAtlantic.Kuhnert.2011', 'Asi-SO90-39KG_SO130-275KL.Munz.2015', 'Ocn-MD95-2011.Grimalt.2002', 'Afr-LakeMalawi.Powers.2011', 'Arc-Tjeggelvas.Bjorklund.2012', 'NAm-CottonwoodPass.Briffa.1996', 'Arc-GulfofAlaska.Wilson.2014', 'Ocn-Rarotonga_d18O2R.Linsley.2006', 'Ocn-PalauRockIslands.Osborne.2014', 'NAm-ParkMountain.Wilson.2005', 'Eur-EasternCarpathianMountains.Popa.2008', 'Asi-UKHLWW.Schweingruber.2002', 'Asi-NEPA003.Krusic.2013', 'Ocn-WesternAntarcticPeninsula.Shevenell.2011', 'Arc-Iceland.Bergthorsson.1969', 'Asi-Fujian.Wang.1998', 'NAm-BlanchardRiver ...
# 157

# %%
import pandas as pd
master_table = pd.DataFrame(columns = ['dataset name', 'archiveType', 'proxyObservationType', 'units', 'proxySystem'])

# %% [markdown]
# Get all the proxyObsTypes for files that have paleodata

# %%
import os
import sys
import json
import requests
import urllib

no_content_files = []
no_paleodata = []
# datasetname = "Afr-LakeMalawi.Powers.2011"
# datasetname = "Afr-LakeTanganyika.Tierney.2010"
# file_list=['NAm-SnowBowlSanFranciscoPeak.Briffa.2002', "NAm-SewardComposite.D'Arrigo.2006", 'Ocn-AbrahamReef.Druffel.1999']
# file_list = ['Arc-BigRoundLake.Thomas.2009']

endpoint = "http://wiki.linked.earth/store/db/query" # Query Metadata
wikiapi = "http://wiki.linked.earth/wiki/api.php" # Fetch file data

for datasetname in file_list:
    query = """PREFIX core: <http://linked.earth/ontology#>
    PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
    SELECT ?name ?a ?potName ?uni ?psys
    WHERE {
    
       # binding defaults
      bind("NA" as ?default_units)
      bind("NA" as ?default_psys)
      
      # ?ds a core:Dataset .
      # ?ds core:name ?name .
      # ?ds core:name '""" + datasetname + """' .
      # ?ds wiki:Property-3AArchiveType ?a.
      # ?ds core:includesPaleoData ?data .
      # ?data core:foundInMeasurementTable ?table .
      # ?table core:includesVariable ?var .
      # ?var core:proxyObservationType ?pot .
      # ?var core:name ?potName .
      
      OPTIONAL {
          # ?var core:hasUnits ?wiki_uni .
          # ?var core:hasProxySystem ?wiki_psys .
      }
      
      # either take ?wiki_uni/wiki_psys value or default and bind it as the result ?uni/psys
      bind(coalesce(?wiki_uni, ?default_units) as ?uni)
      bind(coalesce(?wiki_psys, ?default_psys) as ?psys)
      
    }"""

    try:
        response = requests.post(endpoint, data = {'query': query})
        res = json.loads(response.text)
        print(response, res)
        print('$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$')
        
        if not res['results']['bindings']:
            no_content_files.append(datasetname)
        for item in res['results']['bindings']:
            df = pd.DataFrame({'dataset name':item['name']['value'], 'archiveType': item['a']['value'], 'proxyObservationType':item['potName']['value'], 'units':item['uni']['value'], 'proxySystem':item['psys']['value']}, index=[0])
            master_table = master_table.append(df, ignore_index = True)
    except:
        no_paleodata.append(datasetname)
        print('Dataset does not have Paleodata :(')


master_table.to_csv(r'D:\\annotating_paleoclimate_data\\proxyObsTypeWiki.csv', sep = ',', encoding = 'utf-8',index = False)
# Out:
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'segment'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'MXD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.MXDDefaultSensor.MXD'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'residual'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ARS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'RBar'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SnowBowlSanFranciscoPeak.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Dataset does not have Paleodata :(
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ocn-AbrahamReef.Druffel.1999'}, 'a': {'type': 'literal', 'value': 'coral'}, 'potName': {'type': 'literal', 'value': 'd13C'}, 'uni': {'type': 'literal', 'value': 'permil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Coral.Porites_porites_austraiensis.D13C'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ocn-CH07-98-MC-22.Saenger.2011'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'Mg_Ca'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'literal', 'value': 'NA'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-Bonif.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'density'}, 'uni': {'type': 'literal', 'value': 'g/cm3'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-Bonif.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'MXD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.MXDDefaultSensor.MXD'}}, {'name': {'type': 'literal', 'value': 'NAm-Bonif.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-SunwaptaPass.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'MXD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.MXDDefaultSensor.MXD'}}, {'name': {'type': 'literal', 'value': 'NAm-SunwaptaPass.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ARS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SunwaptaPass.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SunwaptaPass.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SunwaptaPass.Schweingruber.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'core'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-SpruceCreek.Church.1981'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SpruceCreek.Church.1981'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ARS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SpruceCreek.Church.1981'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-SpruceCreek.Church.1981'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'SAm-CentralAndes11.PAGES2k.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes11.PAGES2k.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Dataset does not have Paleodata :(
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ocn-SWCoastOfIndia.Saraswat.2013'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'ghostMeasured'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'literal', 'value': 'NA'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'M77-2_056.Nurnberg.2015'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'u. peregrina d13c'}, 'uni': {'type': 'literal', 'value': 'per mil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Uvigirina_peregrina.D13C'}}, {'name': {'type': 'literal', 'value': 'M77-2_056.Nurnberg.2015'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'g. ruber w d13c'}, 'uni': {'type': 'literal', 'value': 'per mil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.D13C'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-CHIN044.Brauning.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-CHIN044.Brauning.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ocn-CariacoBasin.Black.2007'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'Mg_Ca'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'literal', 'value': 'NA'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Eur-SpanishPyrenees.Dorado-Linan.2012'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Eur-SpanishPyrenees.Dorado-Linan.2012'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'segment'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'density'}, 'uni': {'type': 'literal', 'value': 'g/cm3'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'MXD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.MXDDefaultSensor.MXD'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'residual'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CraterLakeNE.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Dataset does not have Paleodata :(
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ant-US-ITASE-2002-4.Steig.2013'}, 'a': {'type': 'literal', 'value': 'glacier ice'}, 'potName': {'type': 'literal', 'value': 'd18O'}, 'uni': {'type': 'literal', 'value': 'permil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.GlacierIce.D18ODefaultSensor.D18O'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Arc-PennyIceCapP96.Okuyama.2003'}, 'a': {'type': 'literal', 'value': 'glacier ice'}, 'potName': {'type': 'literal', 'value': 'melt'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.GlacierIce.MeltDefaultSensor.Melt'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Juxtlahuaca.Lachniet.2012'}, 'a': {'type': 'literal', 'value': 'speleothem'}, 'potName': {'type': 'literal', 'value': 'distance_from_top'}, 'uni': {'type': 'literal', 'value': 'mm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Speleothem.DistanceDefaultSensor.Distance'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Arc-Agassiz.Vinther.2008'}, 'a': {'type': 'literal', 'value': 'glacier ice'}, 'potName': {'type': 'literal', 'value': 'd18O'}, 'uni': {'type': 'literal', 'value': 'permil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.GlacierIce.D18ODefaultSensor.D18O'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-NOGSAK.PAGES2k.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-NOGSAK.PAGES2k.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Ocn-AmedeeIsland.DeLong.2012'}, 'a': {'type': 'literal', 'value': 'coral'}, 'potName': {'type': 'literal', 'value': 'Sr_Ca'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Coral.Porites_lutea.Sr/Ca'}}, {'name': {'type': 'literal', 'value': 'Ocn-AmedeeIsland.DeLong.2012'}, 'a': {'type': 'literal', 'value': 'coral'}, 'potName': {'type': 'literal', 'value': 'Sr_Ca'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Coral.Porites_lutea.Sr/Ca'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'a. nodulifer'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Azpeitia_nodulifer.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'n. interruptestriata'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Nitzschia_interruptestriata.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'nitzschia sp.'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Nitzschia.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'rhizosolenia spp.'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Rhizosolenia.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'stephanopyxis spp.'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Stephanopyxis.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 't. nitzschioides'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Thalassionema_nitzschioides.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 't. eccentrica'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Thalassiosira_eccentrica.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 't. pacifica'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Thalassiosira_pacifica.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 't. longissima'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Thalassiothrix_longissima.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'p. sulcata'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Paralia_sulcata.Floral'}}, {'name': {'type': 'literal', 'value': 'ODP1019.Barron.2003'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'diatom benthic'}, 'uni': {'type': 'literal', 'value': 'percent'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URI ...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-MONG030.Jacoby.2010'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-MONG030.Jacoby.2010'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-Hushre.PAGES2k.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-Hushre.PAGES2k.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Aus-TakapariCedar.Xiong.2000'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Aus-TakapariCedar.Xiong.2000'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'MD01-2390.Steinke.2008'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'd18oss'}, 'uni': {'type': 'literal', 'value': 'per mil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.D18O'}}, {'name': {'type': 'literal', 'value': 'MD01-2390.Steinke.2008'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'mgcass'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.Mg/Ca'}}, {'name': {'type': 'literal', 'value': 'MD01-2390.Steinke.2008'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'mgcasl'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.Mg/Ca'}}, {'name': {'type': 'literal', 'value': 'MD01-2390.Steinke.2008'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'mgca'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.Mg/Ca'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-HerringAlpine.Fritts.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'sampleCount'}, 'uni': {'type': 'literal', 'value': 'count'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-HerringAlpine.Fritts.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-HerringAlpine.Fritts.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-HerringAlpine.Fritts.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-HerringAlpine.Fritts.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-TW001.Wright.2010'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-TW001.Wright.2010'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'density'}, 'uni': {'type': 'literal', 'value': 'g/cm3'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ARS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'core'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ARS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ringWidth'}, 'uni': {'type': 'literal', 'value': 'cm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-MtLemon.Briffa.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'sampleCount'}, 'uni': {'type': 'literal', 'value': 'count'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'segment'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ringWidth'}, 'uni': {'type': 'literal', 'value': 'cm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'residual'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-RedMountainPassSilverton.Graybill.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'core'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-Bennington.Luckman.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Arc-LakeNataujärvi.Ojala.2005'}, 'a': {'type': 'literal', 'value': 'lake sediment'}, 'potName': {'type': 'literal', 'value': 'X_radiograph_dark_layer'}, 'uni': {'type': 'literal', 'value': 'dark_sum'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.LakeSediment.VarvePropertyDefaultSensor.VarveProperty'}}, {'name': {'type': 'literal', 'value': 'Arc-LakeNataujärvi.Ojala.2005'}, 'a': {'type': 'literal', 'value': 'lake sediment'}, 'potName': {'type': 'literal', 'value': 'X_radiograph_dark_layer'}, 'uni': {'type': 'literal', 'value': 'dark_sum'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.LakeSediment.VarvePropertyDefaultSensor.VarveProperty'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-CanyonCreek.Lloyd.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'sampleCount'}, 'uni': {'type': 'literal', 'value': 'count'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CanyonCreek.Lloyd.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-CanyonCreek.Lloyd.2002'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'core'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Dataset does not have Paleodata :(
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'GeoB10069-3.Gibbons.2014'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'mg/ca'}, 'uni': {'type': 'literal', 'value': 'mmol/mol'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Globigerinoides_ruber.Mg/Ca'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi2'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi2'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi3'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi3'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi4'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'SAm-CentralAndes6.Villalba.2014'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi4'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-KYRG010.Shiyatov.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-KYRG010.Shiyatov.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-wa071.Peterson.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ringWidth'}, 'uni': {'type': 'literal', 'value': 'cm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-wa071.Peterson.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-wa071.Peterson.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'RBar'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-wa071.Peterson.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-wa071.Peterson.1994'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'RBar'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-AthabascaGlacier2.Luckman.2005'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'sampleCount'}, 'uni': {'type': 'literal', 'value': 'count'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'residual'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'corrs'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-FrenchGlacier.Colenutt.1995'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'core'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-PAKI009.Esper.2007'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-PAKI009.Esper.2007'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-PAKI031.Cook.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-PAKI031.Cook.2013'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'sampleCount'}, 'uni': {'type': 'literal', 'value': 'count'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ringWidth'}, 'uni': {'type': 'literal', 'value': 'cm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'RBar'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SD'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'SE'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}, {'name': {'type': 'literal', 'value': 'NAm-PintlersTwo.Littell.2011'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'EPS'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-SylvanPassbeiCody.Briffa.1996'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'ringWidth'}, 'uni': {'type': 'literal', 'value': 'cm'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.DefaultSensor'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Asi-RUSS236.Sano.2009'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}, {'name': {'type': 'literal', 'value': 'Asi-RUSS236.Sano.2009'}, 'a': {'type': 'literal', 'value': 'tree'}, 'potName': {'type': 'literal', 'value': 'trsgi'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.Wood.TRWDefaultSensor.TRW'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Arc-Lomonosovfonna.Divine.2011'}, 'a': {'type': 'literal', 'value': 'glacier ice'}, 'potName': {'type': 'literal', 'value': 'd18O'}, 'uni': {'type': 'literal', 'value': 'permil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.GlacierIce.D18ODefaultSensor.D18O'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'KNR195-5-CDH23.Bova.2015'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'c37total'}, 'uni': {'type': 'literal', 'value': 'NA'}, 'psys': {'type': 'literal', 'value': 'NA'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'GeoB12610-2.Rippert.2015'}, 'a': {'type': 'literal', 'value': 'marine sediment'}, 'potName': {'type': 'literal', 'value': 'n. dutertrei d18o'}, 'uni': {'type': 'literal', 'value': 'per mil'}, 'psys': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/ProxySystem.MarineSediment.Neogloboquadrina_dutertrei.D18O'}}]}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Dataset does not have Paleodata :(
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <Response [200]> {'head': {'vars': ['name', 'a', 'potName', 'uni', 'psys']}, 'results': {'bindings': []}}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
print(len(no_content_files))
no_content_files
# Out:
# 75
# ['Arc-PolarUrals.Wilson.2015',
#  'Aus-MtRead.Cook.2006',
#  'Asi-KYRG008.Shiyatov.2013',
#  'Asi-BT010.Cook.2010',
#  'Ocn-BermudaSouthShore.Goodkin.2008',
#  'Asi-KYRG004.Esper.2007',
#  'Ocn-JacafFjord.Sepúlveda.2009',
#  'Asi-PAKI035.Cook.2013',
#  'Arc-StoreggaSlide.Sejrup.2011',
#  'Asi-CHIN017.Li.2010',
#  'Eur-NorthernSpain.Martín-Chivelet.2011',
#  'Asi-BT005.Cook.2010',
#  'Ocn-AqabaJordanAQ19.Heiss.1999',
#  'MD95-2043.Cacho.1999',
#  'Asi-NEPA015.Krusic.2013',
#  'Ocn-Rarotonga_d18O99.Linsley.2006',
#  'Ocn-Mafia.Damassa.2006',
#  'Asi-NEPA030.Krusic.2013',
#  'Ocn-CariacoBasin.Lea.2003',
#  'Asi-ZhejiangAndFujian.Zhang.1980',
#  'Ocn-PedradeLume-CapeVerdeIslands.Moses.2006',
#  'Asi-CHIN037.Fan.2013',
#  'Ocn-ODP984.Came.2007',
#  'Ocn-IfatyTul3.Zinke.2014',
#  'Asi-MONG033.Jacoby.2010',
#  'Asi-HYGJUP.PAGES2k.2013',
#  'Asi-GuangdongAndGuangxi.Zhang.1980',
#  'Arc-MD992275.Jiang.2005',
#  'Arc-LakeDonardBaffinIsland.Moore.2001',
#  'Asi-CHIN018.Li.2010',
#  'DSDP502.deMenocal.1992',
#  'Arc-SoperLake.Hughen.2000',
#  'Ant-DomeC.Stenni.2001',
#  'Ocn-NorthwestPacificOcean.Harada.2004',
#  'Ocn-BuccooReefTobagoSidereastrea.Moses.2006',
#  'Ocn-Ifaty1.Zinke.2014',
#  'Asi-CHIN059.Shao.2013',
#  'Asi-JAPA015.Yasue.2013',
#  'Asi-PAKI010.Esper.2007',
#  'Asi-ZHIDJP.Shao.2003',
#  'Ocn-Rarotonga_d18O3R.Linsley.2006',
#  'Asi-MONG032.Jacoby.2010',
#  'Asi-KYRG013.Solomina.2013',
#  'Asi-NEPA027.Krusic.2013',
#  'Asi-MONG031.Jacoby.2010',
#  'Ocn-Nauru.Guilderson.1999',
#  'Ocn-MakassarStrait.Linsley.2010',
#  'Ocn-AlboranSea436B.Nieto-Moreno.2013',
#  'Asi-Guangdong.Zheng.1982',
#  'Asi-KYRG007.Esper.2007',
#  'Asi-SODAPS.PAGES2k.2013',
#  'Afr-P178-15P.Tierney.2015',
#  'Asi-AltaiJablonsky.Cook.2000',
#  'Asi-PAKI022.Cook.2013',
#  'Ocn-WEqPacific.Stott.2007',
#  'Ant-VLG.Bertler.2011',
#  'Ocn-EasternTropicalNorthAtlantic.Kuhnert.2011',
#  'Ocn-MD95-2011.Grimalt.2002',
#  'Arc-Tjeggelvas.Bjorklund.2012',
#  'Arc-GulfofAlaska.Wilson.2014',
#  'Asi-UKHLWW.Schweingruber.2002',
#  'Asi-NEPA003.Krusic.2013',
#  'Arc-Iceland.Bergthorsson.1969',
#  'Asi-Fujian.Wang.1998',
#  'Asi-CHIN061.Shao.2013',
#  'Ocn-CapeHatteras.Cleroux.2008',
#  'Ocn-Malindi.Nakamura.2009',
#  'Asi-CHIN043.Brauning.2013',
#  'Ant-BerknerIsland.Mulvaney.2002',
#  'CO00COKY-SAMPLEDATA',
#  'Ocn-Mayotte.Zinke.2008',
#  'Asi-DQHZHO.PAGES2k.2013',
#  'Asi-NEPA010.Krusic.2013',
#  'Asi-CHIN042.Brauning.2013',
#  'Asi-BARELC.PAGES2k.2013']

# %%
import os
import sys
import json
import requests
import urllib

# datasetname = "Afr-LakeMalawi.Powers.2011"
datasetname = "Arc-BigRoundLake.Thomas.2009"

endpoint = "http://wiki.linked.earth/store/db/query" # Query Metadata
wikiapi = "http://wiki.linked.earth/wiki/api.php" # Fetch file data

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
SELECT ?name ?data ?table ?pot
WHERE {
  # ?ds a core:Dataset .
  # ?ds core:name ?name .
  # ?ds core:name '""" + datasetname + """' .
  # ?ds core:includesPaleoData ?data .
  # ?data core:foundInMeasurementTable ?table .
  
}"""
# ?data core:foundInMeasurementTable ?table .
#   ?table core:includesVariable ?var .
#   ?var core:proxyObservationType ?pot.

response = requests.post(endpoint, data = {'query': query})
res = json.loads(response.text)
print(response, res)
# Out:
# <Response [200]> {'head': {'vars': ['name', 'data', 'table', 'pot']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'Arc-BigRoundLake.Thomas.2009'}, 'data': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Arc-2DBigRoundLake.Thomas.2009.PaleoData1'}, 'table': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Arc-2DBigRoundLake.Thomas.2009.paleo1measurement1'}}, {'name': {'type': 'literal', 'value': 'Arc-BigRoundLake.Thomas.2009'}, 'data': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Arc-2DBigRoundLake.Thomas.2009.PaleoData2'}, 'table': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/Arc-2DBigRoundLake.Thomas.2009.paleo2measurement1'}}]}}
