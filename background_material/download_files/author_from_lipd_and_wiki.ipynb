# %% [markdown]
# #### To get authors from lipd files

# %%
import lipd
import pandas as pd
import os

# %%
input_path = 'D:\\annotating_paleoclimate_data\\recommender\\download_files\\linked_earth_wiki_files_new'

# f = open('file-name.txt')
tup = list(os.walk(input_path))
root, dir_names, file_names = tup[0][0], tup[0][1], tup[0][2]

# %%
len(file_names)
# Out:
# 706

# %%
from collections import defaultdict

# %%
author_info = set()
investigator_info = set()
no_info = set()
dataCon = set()
reverse_index_author = {}

# %%
def add_to_reversed_index_author_map(val, archive):
    for a_name in val.split(','):
        reverse_index_author.setdefault(a_name,[]).append(archive)

# %%
for line in file_names:
    print(line)
    if '.lpd' in line:
        filen = line.strip()
        l = os.path.join(root, line.strip())
        d= lipd.readLipd(l)
        if 'archiveType' not in d:
            continue
        archive = d['archiveType']
        if 'pub' in d:
            path = d['pub'][0]
            if 'author' in path:
                print(path['author'])
                author_list = path['author']
                for auth in author_list:
                    if 'name' in auth:
                        val = auth['name'][0] if type(auth['name']) == list else auth['name']
                        add_to_reversed_index_author_map(val, archive)
                author_info.add(line)
        if line not in author_info and 'investigator' in d:
            path_investigators = d['investigator']
            print(path_investigators)
            for auth in path_investigators:
                if 'name' in auth:
                    val = auth['name'][0] if type(auth['name']) == list else auth['name']
                    add_to_reversed_index_author_map(val, archive)
            investigator_info.add(line)
        elif line not in author_info and line not in investigator_info :
            no_info.add(line)
# Out:
# A7.Oppo.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: A7.Oppo.2005.lpd
# Finished read: 1 record
# [{'name': 'Youbin Sun'}, {'name': 'Delia W. Oppo'}, {'name': 'Rong Xiang'}, {'name': 'Weiguo Liu'}, {'name': 'Shu Gao'}]
# Afr-ColdAirCave.Sundqvist.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-ColdAirCave.Sundqvist.2013.lpd
# Finished read: 1 record
# Afr-LakeMalawi.Powers.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeMalawi.Powers.2011.lpd
# Finished read: 1 record
# Afr-LakeTanganyika.Tierney.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeTanganyika.Tierney.2010.lpd
# Finished read: 1 record
# Afr-P178-15P.Tierney.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-P178-15P.Tierney.2015.lpd
# ...

# %%
len(reverse_index_author)
# Out:
# 407

# %%
import collections
for key in reverse_index_author.keys():
    reverse_index_author[key] = dict(collections.Counter(reverse_index_author[key]))

# %%
print('Author Files:')
print(len(author_info))
print('-------------------------------------------------------------------------------------------')
print('Investigator Files')
print(len(investigator_info.difference(author_info)))
print('-------------------------------------------------------------------------------------------')
print('No Info')
print(len(no_info))
print('-------------------------------------------------------------------------------------------')
# Out:
# Author Files:
# 75
# -------------------------------------------------------------------------------------------
# Investigator Files
# 105
# -------------------------------------------------------------------------------------------
# No Info
# 513
# -------------------------------------------------------------------------------------------

# %% [markdown]
# Current Author Information contains
# 1. Capital and small case names
# 2. mix of initials and complete names

# %% [markdown]
# These following scientists names are not correctly recorded. Changing the keys and adding correct keys back to dataset.
#
# | Sr. No. | Present Name | Correct Name |
# | --- | --- | ----------- |
# | 1. | and Y. Shibata. Harada | Y. Shibata |
# | 2. |  N. | N. Harada |
# | 3. | ' 'N. Ahagon | N. Ahagon |
# | 4. | ' 'T. Sakamoto | T. Sakamoto |
# | 5. | ' 'M. Uchida | M. Uchida |
# | 6. | ' 'M. Ikehara | M. Ikehara |
# | 7. | W.L. Fairbanks | W.L. Prell |
# | 8. | ' 'R.G. | R.G. Fairbanks |
# | 9. | ' 'Prell | W.L. Prell |
#
# 'and Y. Shibata. Harada': Counter({'marine sediment': 1})<br />
# ' N.': Counter({'marine sediment': 1}), <br />
# ' N. Ahagon': Counter({'marine sediment': 1}),<br />
# ' T. Sakamoto': Counter({'marine sediment': 1}),<br />
# ' M. Uchida': Counter({'marine sediment': 1}),<br />
# ' M. Ikehara': Counter({'marine sediment': 1}),<br />
# 'W.L. Fairbanks': Counter({'marine sediment': 1}),<br />
# ' R.G.': Counter({'marine sediment': 1}),<br />
# ' Prell': Counter({'marine sediment': 1}),<br />

# %%
reverse_index_author['Y. Shibata'] = reverse_index_author['and Y. Shibata. Harada']
del reverse_index_author['and Y. Shibata. Harada']

reverse_index_author['N. Harada'] = reverse_index_author[' N.']
del reverse_index_author[' N.']

reverse_index_author['N. Ahagon'] = reverse_index_author[' N. Ahagon']
del reverse_index_author[' N. Ahagon']

reverse_index_author['T. Sakamoto'] = reverse_index_author[' T. Sakamoto']
del reverse_index_author[' T. Sakamoto']

reverse_index_author['M. Uchida'] = reverse_index_author[' M. Uchida']
del reverse_index_author[' M. Uchida']

reverse_index_author[' M. Ikehara'] = reverse_index_author[' M. Ikehara']
del reverse_index_author[' M. Ikehara']

reverse_index_author['W.L. Prell'] = reverse_index_author['W.L. Fairbanks']
del reverse_index_author['W.L. Fairbanks']

reverse_index_author['R.G. Fairbanks'] = reverse_index_author[' R.G.']
del reverse_index_author[' R.G.']
del reverse_index_author[' Prell']

# %%
author_names = reverse_index_author.keys()
reverse_index_author
# Out:
# {'Youbin Sun': {'marine sediment': 1},
#  'Delia W. Oppo': {'marine sediment': 5},
#  'Rong Xiang': {'marine sediment': 1},
#  'Weiguo Liu': {'marine sediment': 1},
#  'Shu Gao': {'marine sediment': 1},
#  'Jessica Tierney': {'marine sediment': 1},
#  'Caroline Ummenhofer': {'marine sediment': 1},
#  'Peter deMenocal': {'marine sediment': 2},
#  'Tas van Ommen': {'glacier ice': 1},
#  'Vin Morgan': {'glacier ice': 1},
#  'Alan Elcheikh': {'glacier ice': 1},
#  'Dorthe Dahl-Jensen': {'glacier ice': 1},
#  'Anais Orsi': {'glacier ice': 1},
#  'Bruce Cornuelle': {'glacier ice': 1},
#  'Severinghaus Jeff': {'glacier ice': 1},
#  'Christophe Kinnard': {'glacier ice': 1},
#  'Christian M. Zdanowicz': {'glacier ice': 1},
#  'David A. Fisher': {'glacier ice': 1},
#  'Elisabeth Isaksson': {'glacier ice': 1},
#  'Elisabeth de Vernal': {'glacier ice': 1},
#  'Lonnie G. Thompson': {'glacier ice': 1},
#  'Guoqiang Chu': {'lake sediment': 1},
#  'Qing Sun': {'lake sediment': 1},
# ...

# %%
len(author_names)
# Out:
# 405

# %%
seed_author_list = {}
for n in author_names:
    n = n.title()
    n_list = n.split()
    with_ini = False
    for ind, inner_n in enumerate(n_list):
        if ind != 1 and '.' in inner_n:
            with_ini = True            
    if not with_ini:
        try:
            seed_author_list[n[0].upper()].add(n)
        except KeyError:
            seed_author_list[n[0].upper()] = {n}

# %%
seed_author_list
# Out:
# {'Y': {'Yair Rosenthal',
#   'Yemane Asmerom',
#   'Yiming V. Wang',
#   'Youbin Sun',
#   'Yuan Lin',
#   'Yusuke Yokoyama'},
#  'D': {'Da Hodgson',
#   'Damassa',
#   'David A. Fisher',
#   'David Lund',
#   'David W. Lea',
#   'Delia W. Oppo',
#   'Delong',
#   'Dierk Hebbeln',
#   'Dirk Nürnberg',
#   'Dorothy K. Pak',
#   'Dorthe Dahl-Jensen',
#   'Draschba',
#   'Druffel',
#   'Dunbar'},
#  'R': {'Rainer Zahn',
#   'Ralf Tiedemann',
#   'Ralph R Schneider',
#   'Ralph R. Schneider',
#   'Ralph Schneider',
#   'Reinhild Rosenberg',
#   'Richey J.N',
#   'Riza Yuliratno Setiawan',
#   'Rong Xiang'},
#  'W': {'Wanamaker',
#   'Wei',
#   'Weiguo Liu',
#   'Wenyu Shang',
#   'William A. Weinlein',
#   'Wolfgang Kuhnt',
#   'Wu'},
#  'S': {'S Lebreiro',
#   'Samantha C. Bova',
#   'Sarnthein M.',
#   'Schulz M.',
#   'Severinghaus Jeff',
#   'Shirley Van Kreveld',
#   'Shu Gao',
#   'Stefan Löhr',
#   'Stefan Schouten',
#   'Stefano Bernasconi',
#   'Stephan Hetzinger',
# ...

# %% [markdown]
# We are only keeping authors of the form : **FirstName Middle Initial(with '.')  LastName**
#
#
# Deleting the following repeated values
# 1. 'Karl-Heinz \xa0Baumann'
# 2. 'Nicholas J Shackleton'
# 3. 'Nicholas Shackleton'
# 4. 'Nick Shackleton'
# 5. 'Peter J Müller'
# 6. 'Ralph R Schneider'
# 7. 'Ralph Schneider'
#
# Incorrect author names in the data, adding them to the dataset.
# 1. Fairbanks, R.G.; Prell, W.L.

# %%
seed_author_list['K'].remove('Karl-Heinz \xa0Baumann')
seed_author_list['N'].remove('Nicholas J Shackleton')
seed_author_list['N'].remove('Nicholas Shackleton')
seed_author_list['N'].remove('Nick Shackleton')
seed_author_list['P'].remove('Peter J Müller')
seed_author_list['R'].remove('Ralph R Schneider')
seed_author_list['R'].remove('Ralph Schneider')

seed_author_list['R'].add('R.G. Fairbanks')
seed_author_list['W'].add('W.L. Prell')

# %%
seed_author_list
# Out:
# {'Y': {'Yair Rosenthal',
#   'Yemane Asmerom',
#   'Yiming V. Wang',
#   'Youbin Sun',
#   'Yuan Lin',
#   'Yusuke Yokoyama'},
#  'D': {'Da Hodgson',
#   'Damassa',
#   'David A. Fisher',
#   'David Lund',
#   'David W. Lea',
#   'Delia W. Oppo',
#   'Delong',
#   'Dierk Hebbeln',
#   'Dirk Nürnberg',
#   'Dorothy K. Pak',
#   'Dorthe Dahl-Jensen',
#   'Draschba',
#   'Druffel',
#   'Dunbar'},
#  'R': {'R.G. Fairbanks',
#   'Rainer Zahn',
#   'Ralf Tiedemann',
#   'Ralph R. Schneider',
#   'Reinhild Rosenberg',
#   'Richey J.N',
#   'Riza Yuliratno Setiawan',
#   'Rong Xiang'},
#  'W': {'W.L. Prell',
#   'Wanamaker',
#   'Wei',
#   'Weiguo Liu',
#   'Wenyu Shang',
#   'William A. Weinlein',
#   'Wolfgang Kuhnt',
#   'Wu'},
#  'S': {'S Lebreiro',
#   'Samantha C. Bova',
#   'Sarnthein M.',
#   'Schulz M.',
#   'Severinghaus Jeff',
#   'Shirley Van Kreveld',
#   'Shu Gao',
#   'Stefan Löhr',
#   'Stefan Schouten',
#   'Stefano Bernasconi',
#   'Stephan Hetzinger',
# ...

# %% [markdown]
# For all names we will check how close each of the input names is to the indexed names in the list
#
# 1. we will first split the input name and each of names for that indexed names. (called reference name henceforth)
# 2. match the lastName, if there is a complete match with the reference lastName, check for firstName
# 3. if the lastName is a substring of the reference lastName, check for firstName example '\xa0Baumann' and 'Baumann'
# 4. if there are a few letters different example Müller and Muller, we will check the firstName and confirm both are equal. Map this lastName to the former one Müller.

# %%
com_same = []
last_same = []
ref_same = []
iter_same = []

# %%
def editDistance(str1, str2, m, n):
    dp = [[0 for x in range(n + 1)] for x in range(m + 1)]
 
    # Fill d[][] in bottom up manner
    for i in range(m + 1):
        for j in range(n + 1):
 
            if i == 0:
                dp[i][j] = j    # Min. operations = j
 
            elif j == 0:
                dp[i][j] = i    # Min. operations = i
 
            elif str1[i-1] == str2[j-1]:
                dp[i][j] = dp[i-1][j-1]

            else:
                dp[i][j] = 1 + min(dp[i][j-1],        # Insert
                                   dp[i-1][j],        # Remove
                                   dp[i-1][j-1])    # Replace
 
    return dp[m][n]

# %%
def check_fname(auth_list, rn_list):
    if ('.' in auth_list[0] and rn_list[0][0] == auth_list[0][0]):
        return True
    elif rn_list[0] == auth_list[0]:
        return True
    else:
        matching = 0
        auth_fname, rn_fname = auth_list[0], rn_list[0]
        ap, rp = 0, 0
        while ap < len(auth_fname) and rp < len(rn_fname):
            if auth_fname[ap] == rn_fname[rp]:
                matching += 1
                ap += 1
                rp += 1
            else:
                break
        if matching >= 2:
            return True
        return False

# %%
author_names_map = {}
for n in author_names:
    auth = n.title()
    auth_list = auth.split()
    auth_lastName = auth_list[-1]
    reference_names = seed_author_list[auth[0].upper()]
    for rn in reference_names:

        rn_list = rn.split()
        rn_lastName = rn_list[-1]
        # complete names are same
        if rn_list == auth_list:
            author_names_map[n] = rn
            com_same.append(n)
            break
        # lastNames are completely equal
        elif rn_lastName == auth_lastName:
            if check_fname(auth_list, rn_list):
                author_names_map[n] = rn
                last_same.append(n)
                break
        # refernce lastName is a substring of input lastName
        elif rn_lastName in auth_lastName:
            if check_fname(auth_list, rn_list):
                author_names_map[n] = rn
                ref_same.append(n)
                break
        # check where the characters of the lastName are different
        if len(auth_lastName) >= 3 and len(rn_lastName) >= 3:     
            edit_dist = editDistance(auth_lastName, rn_lastName, len(auth_lastName), len(rn_lastName))
            if edit_dist <= 2:
                if check_fname(auth_list, rn_list):
                    author_names_map[n] = rn
                    iter_same.append(n)
                    break
    if n not in author_names_map:
        author_names_map[n] = auth

# %%
# change to FirstName. LastName format

for val in author_names:
    arr = val.split()
    if len(arr) == 2 and '.' in arr[1] and val.isupper():
        print(val)
        author_names_map[val] = " ".join([arr[1], arr[0].title()])
# Out:
# SARNTHEIN M.
# ERLENKEUSER H.
# KUCERA M.
# PFLAUMANN U.
# SCHULZ M.

# %%
len(author_names_map)
# Out:
# 405

# %%
def update_in_dict(in_dict, key_dict):
    for key, value in key_dict.items():
        in_dict[key] = in_dict.get(key, 0) + value
    return in_dict

# %%
unique_names = set(author_names_map.values())
print(len(unique_names))
author_archive_map = {}
for key, value in author_names_map.items(): 
    in_dict = {}
    if value in author_archive_map:
        in_dict = author_archive_map[value]
    author_archive_map[value] = update_in_dict(in_dict, reverse_index_author[key])
# Out:
# 353

# %%
author_archive_map
# Out:
# {'Youbin Sun': {'marine sediment': 1},
#  'Delia W. Oppo': {'marine sediment': 8},
#  'Rong Xiang': {'marine sediment': 1},
#  'Weiguo Liu': {'marine sediment': 1},
#  'Shu Gao': {'marine sediment': 1},
#  'Jessica Tierney': {'marine sediment': 2},
#  'Caroline Ummenhofer': {'marine sediment': 1},
#  'Peter Demenocal': {'marine sediment': 3},
#  'Tas Van Ommen': {'glacier ice': 1},
#  'Vin Morgan': {'glacier ice': 1},
#  'Alan Elcheikh': {'glacier ice': 1},
#  'Dorthe Dahl-Jensen': {'glacier ice': 1},
#  'Anais Orsi': {'glacier ice': 1},
#  'Bruce Cornuelle': {'glacier ice': 1},
#  'Severinghaus Jeff': {'glacier ice': 1},
#  'Christophe Kinnard': {'glacier ice': 1},
#  'Christian M. Zdanowicz': {'glacier ice': 1},
#  'David A. Fisher': {'glacier ice': 1},
#  'Elisabeth Isaksson': {'glacier ice': 1},
#  'Elisabeth De Vernal': {'glacier ice': 1},
#  'Lonnie G. Thompson': {'glacier ice': 1},
#  'Guoqiang Chu': {'lake sediment': 1},
#  'Qing Sun': {'lake sediment': 1},
# ...

# %% [markdown]
# #### Get Author information from wiki

# %%
import os
import sys
import json
import requests
import urllib

# datasetname = "Afr-LakeMalawi.Powers.2011"
datasetname = "Arc-BigRoundLake.Thomas.2009"

endpoint = "http://wiki.linked.earth/store/db/query" # Query Metadata
wikiapi = "http://wiki.linked.earth/wiki/api.php" # Fetch file data

query = """PREFIX core: <http://linked.earth/ontology#>
PREFIX wiki: <http://wiki.linked.earth/Special:URIResolver/>
SELECT ?name ?auth
WHERE {
  # ?ds a core:Dataset .
  # ?ds core:name ?name .
  # ?ds core:author ?auth .
}"""

response = requests.post(endpoint, data = {'query': query})
res = json.loads(response.text)
print(response, res)

files_with_auth = set()
for item in res['results']['bindings']:
    files_with_auth.add(item['name']['value'])
# Out:
# <Response [200]> {'head': {'vars': ['name', 'auth']}, 'results': {'bindings': [{'name': {'type': 'literal', 'value': 'NAm-MedusaBay.Buckley.2003'}, 'auth': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/GTP'}}, {'name': {'type': 'literal', 'value': 'NAm-LakeoftheClouds.Gajewski.1988'}, 'auth': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/AEV_KG'}}, {'name': {'type': 'literal', 'value': 'Asi-AltaiUstUlaganLake.Cook.2005'}, 'auth': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/DO'}}, {'name': {'type': 'literal', 'value': 'MD982181.Khider.2014'}, 'auth': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/D._Khider'}}, {'name': {'type': 'literal', 'value': 'Ocn-Philippines.Stott.2007'}, 'auth': {'type': 'uri', 'value': 'http://wiki.linked.earth/Special:URIResolver/PGM_JAA'}}, {'name': {'type': 'literal', 'value': 'Afr-ColdAirCave.Sundqvist.2013'}, 'auth': {'type': 'uri', 'value': 'http://wiki.l
# ...

# %%
len(files_with_auth)
# Out:
# 358

# %%
set(files_with_auth)
# Out:
# {'Afr-ColdAirCave.Sundqvist.2013',
#  'Afr-LakeTanganyika.Tierney.2010',
#  'Ant-BerknerIsland.Mulvaney.2002',
#  'Ant-CoastalDML.Thamban.2012',
#  'Ant-DSS.DahlJensen.1999',
#  'Ant-DSS.Moy.2012',
#  'Ant-DomeC.Jouzel.2001',
#  'Ant-DomeC.Stenni.2001',
#  'Ant-DomeF1993.Uemura.2014',
#  'Ant-DomeF2001.Uemura.2008',
#  'Ant-Ferrigno.Thomas.2013',
#  'Ant-JamesRossIsland.Mulvaney.2013',
#  'Ant-MES.Rhodes.2012',
#  'Ant-PlateauRemote.Mosley-Thompson.2013',
#  'Ant-SipleStation.Mosley-Thompson.1990',
#  'Ant-SiteDML05.Graf.2002',
#  'Ant-SiteDML07.Graf.2002',
#  'Ant-SiteDML17.Graf.2002',
#  'Ant-TALDICE.Stenni.2010',
#  'Ant-TalosDome.Stenni.2002',
#  'Ant-TaylorDome.Steig.2000',
#  'Ant-US-ITASE-2000-1.Steig.2013',
#  'Ant-US-ITASE-2002-4.Steig.2013',
#  'Ant-VLG.Bertler.2011',
#  'Ant-Vostok.Ekaykin.2014',
#  'Ant-WAIS-Divide.Severinghaus.2012',
#  'Ant-WDC05A.Steig.2013',
#  'Ant-WDC06A.Steig.2013',
#  'Arc-AkademiiNaukIceCap.Opel.2013',
#  'Arc-Arjeplog.Bjorklund.2014',
# ...

# %%
files_with_auth.intersection(dataCon)
# Out:
# set()

# %%
author_archive_map.keys()
# Out:
# dict_keys(['Youbin Sun', 'Delia W. Oppo', 'Rong Xiang', 'Weiguo Liu', 'Shu Gao', 'Jessica Tierney', 'Caroline Ummenhofer', 'Peter Demenocal', 'Tas Van Ommen', 'Vin Morgan', 'Alan Elcheikh', 'Dorthe Dahl-Jensen', 'Anais Orsi', 'Bruce Cornuelle', 'Severinghaus Jeff', 'Christophe Kinnard', 'Christian M. Zdanowicz', 'David A. Fisher', 'Elisabeth Isaksson', 'Elisabeth De Vernal', 'Lonnie G. Thompson', 'Guoqiang Chu', 'Qing Sun', 'Xiaohua Wang', 'Meimei Liu', 'Yuan Lin', 'Manman Xie', 'Wenyu Shang', 'Jiaqi Liu', 'Km Saunders', 'M Grosjean', 'Da Hodgson', 'Braddock K. Linsley', 'Yair Rosenthal', 'Nicholas J. Shackleton', 'Mike A. Hall', 'Lorraine E. Lisiecki', 'Maureen E. Raymo', 'Riza Yuliratno Setiawan', 'Mahyar Mohtadi', 'John Southon', 'Jeroen Groeneveld', 'Stephan Steinke', 'Dierk Hebbeln', 'Fern T. Gibbons', 'Jun Cheng', 'Zhengyu Liu', 'Jung-Hyun Kim', 'Ralph R. Schneider', 'Peter J. Müller', 'Gerold Wefer', 'Henning Kuhnert', 'Holger Kuhlmann', 'Helge Meggers', 'Karl-Heinz Baumann', 
# ...

# %%
new_author_arch_k = []
new_author_arch_v = []
for k,v in author_archive_map.items():
    l = []
    for ki, vi in v.items():
        l.append("{}({})".format(ki,vi))
    new_author_arch_k.append(k)
    new_author_arch_v.append(",".join(l))

# %%
df = pd.DataFrame(list(zip(new_author_arch_k, new_author_arch_v)), columns =['Author', 'Archives'])
df.to_csv('D:\\annotating_paleoclimate_data\\recommender\\download_files\\author_list.csv', sep = ',', encoding = 'utf-8',index = False)

# %%
author_list = 'Charles, C.D., D.E.Hunter, and R.G.Fairbanks.'

author_list = author_list.replace(' abd ', ' AND ')
author_list = author_list.replace(' ABD ', ' AND ')
author_list = author_list.replace(' and ', ' AND ')
semicolon_sep_list = author_list.split(';')
and_sep_list = []
for part in semicolon_sep_list:
    and_sep_list.extend(part.strip().split('AND'))

for part in and_sep_list:
    part = part.strip(' ,')
    p = part.split(',')
    if len(p) == 2:
        new_part = p[1].strip(' ,') + ' ' + p[0].strip(' ,')
    elif len(p) == 4:
        new_part = p[1].strip(' ,') + ' ' + p[0].strip(' ,')
        new_part = validate_author_name(new_part)
        a_name_list.append(new_part)
        add_to_reversed_index_author_map(new_part, archive)

        new_part = p[3].strip(' ,') + ' ' + p[2].strip(' ,')
    elif len(p) > 2:
        f_part = p[1:]
        l_part = p[0]
        f_part.extend(l_part)
        new_part = ' '.join(f_part)
    else:
        print(part)
        if part.endswith('.') and ' ' in part:
            new_part = ' '.join([part[part.index(' ') + 1 :] ,part[:part.index(' ')]])
        else:
            new_part = part
            
new_part
# Out:
# R.G.Fairbanks.
# 'R.G.Fairbanks.'

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
  
    
figure(figsize=(8, 6), dpi=80)
# create data
x = [3,5,7,10]
y2 = [0.5895910780669145, 0.6260223048327137, 0.6780669144981413, 0.7092936802973978]
y3 = [0.900371747211896, 0.9130111524163569, 0.9137546468401487, 0.916728624535316]
y3_u = [0.9353159851301115, 0.9353159851301115, 0.9353159851301115, 0.9353159851301115]
y4 = [ 0.9226765799256506, 0.9315985130111524, 0.9345724907063196, 0.937546468401487]
y5 = [ 0.7479553903345725, 0.7524163568773234, 0.753903345724907, 0.7546468401486989]
y6 = [ 0.9970260223048327, 0.9970260223048327, 0.9970260223048327, 0.9970260223048327]
  
# plot lines
plt.plot(x, y2, '-o', label = "Recall Proxy")
plt.plot(x, y3, '-o', label = "Recall Interp Var")
plt.plot(x, y3_u, '-o', label = "Recall Proxy Units")
plt.plot(x, y4, '-o', label = "Recall Interp Var Det")
plt.plot(x, y5, '-o', label = "Recall Inf Var")
plt.plot(x, y6, '-o', label = "Recall Inf Var Units")
plt.legend()
plt.show()

# %%
HIT RATIO CUT OFF = 3
**************************************************************************************
Chain Length = 2 Recall = 0.5895910780669145
Chain Length = 2 MRR = 0.5790219507877505
Chain Length = 2 NDCG = 0.612264180559645
**************************************************************************************
Chain Length = 3 Recall = 0.900371747211896
Chain Length = 3 MRR = 0.8960889833008793
Chain Length = 3 NDCG = 0.9012576579961041
**************************************************************************************
Chain Length = 3_units Recall = 0.9353159851301115
Chain Length = 3_units MRR = 0.9353159851301115
Chain Length = 3_units NDCG = 0.9353159851301115
**************************************************************************************
Chain Length = 4 Recall = 0.9226765799256506
Chain Length = 4 MRR = 0.9213524517613738
Chain Length = 4 NDCG = 0.9253019960832659
**************************************************************************************
Chain Length = 5 Recall = 0.7479553903345725
Chain Length = 5 MRR = 0.7448409748038002
Chain Length = 5 NDCG = 0.7472918437937414
**************************************************************************************
Chain Length = 6 Recall = 0.9970260223048327
Chain Length = 6 MRR = 0.9966542750929368
Chain Length = 6 NDCG = 0.9967516206346255
**************************************************************************************
3:17
HIT RATIO CUT OFF = 5
**************************************************************************************
Chain Length = 2 Recall = 0.6260223048327137
Chain Length = 2 MRR = 0.5790219507877505
Chain Length = 2 NDCG = 0.612264180559645
**************************************************************************************
Chain Length = 3 Recall = 0.9130111524163569
Chain Length = 3 MRR = 0.8960889833008793
Chain Length = 3 NDCG = 0.9012576579961041
**************************************************************************************
Chain Length = 3_units Recall = 0.9353159851301115
Chain Length = 3_units MRR = 0.9353159851301115
Chain Length = 3_units NDCG = 0.9353159851301115
**************************************************************************************
Chain Length = 4 Recall = 0.9315985130111524
Chain Length = 4 MRR = 0.9213524517613738
Chain Length = 4 NDCG = 0.9253019960832659
**************************************************************************************
Chain Length = 5 Recall = 0.7524163568773234
Chain Length = 5 MRR = 0.7448409748038002
Chain Length = 5 NDCG = 0.7472918437937414
**************************************************************************************
Chain Length = 6 Recall = 0.9970260223048327
Chain Length = 6 MRR = 0.9966542750929368
Chain Length = 6 NDCG = 0.9967516206346255
**************************************************************************************

shravyamanety  3:23 PM
HIT RATIO CUT OFF = 7
**************************************************************************************
Chain Length = 2 Recall = 0.6780669144981413
Chain Length = 2 MRR = 0.5790219507877505
Chain Length = 2 NDCG = 0.612264180559645
**************************************************************************************
Chain Length = 3 Recall = 0.9137546468401487
Chain Length = 3 MRR = 0.8960889833008793
Chain Length = 3 NDCG = 0.9012576579961041
**************************************************************************************
Chain Length = 3_units Recall = 0.9353159851301115
Chain Length = 3_units MRR = 0.9353159851301115
Chain Length = 3_units NDCG = 0.9353159851301115
**************************************************************************************
Chain Length = 4 Recall = 0.9345724907063196
Chain Length = 4 MRR = 0.9213524517613738
Chain Length = 4 NDCG = 0.9253019960832659
**************************************************************************************
Chain Length = 5 Recall = 0.753903345724907
Chain Length = 5 MRR = 0.7448409748038002
Chain Length = 5 NDCG = 0.7472918437937414
**************************************************************************************
Chain Length = 6 Recall = 0.9970260223048327
Chain Length = 6 MRR = 0.9966542750929368
Chain Length = 6 NDCG = 0.9967516206346255
**************************************************************************************
3:26
HIT RATIO CUT OFF = 10
**************************************************************************************
Chain Length = 2 Recall = 0.7092936802973978
Chain Length = 2 MRR = 0.5790219507877505
Chain Length = 2 NDCG = 0.612264180559645
**************************************************************************************
Chain Length = 3 Recall = 0.916728624535316
Chain Length = 3 MRR = 0.8960889833008793
Chain Length = 3 NDCG = 0.9012576579961041
**************************************************************************************
Chain Length = 3_units Recall = 0.9353159851301115
Chain Length = 3_units MRR = 0.9353159851301115
Chain Length = 3_units NDCG = 0.9353159851301115
**************************************************************************************
Chain Length = 4 Recall = 0.937546468401487
Chain Length = 4 MRR = 0.9213524517613738
Chain Length = 4 NDCG = 0.9253019960832659
**************************************************************************************
Chain Length = 5 Recall = 0.7546468401486989
Chain Length = 5 MRR = 0.7448409748038002
Chain Length = 5 NDCG = 0.7472918437937414
**************************************************************************************
Chain Length = 6 Recall = 0.9970260223048327
Chain Length = 6 MRR = 0.9966542750929368
Chain Length = 6 NDCG = 0.9967516206346255
**************************************************************************************
# Out:
#   File "<ipython-input-64-cd4dd9a23a3a>", line 1
#     HIT RATIO CUT OFF = 3
#         ^
# SyntaxError: invalid syntax

# %%
figure(figsize=(8, 6), dpi=80)
# create data
x = [3,5,7,10]
y2 = [0.5696428571428571, 0.6439285714285714, 0.6696428571428571, 0.7160714285714286]
y3 = [0.9510714285714286, 0.9575, 0.9575, 0.9575]
y3_u = [0.9871428571428571, 0.9882142857142857, 0.9882142857142857, 0.9882142857142857]
y4 = [ 0.6907142857142857, 0.6928571428571428, 0.6935714285714286, 0.6935714285714286]
y5 = [ 0.7639285714285714, 0.7707142857142857, 0.7735714285714286, 0.7764285714285715]
y6 = [ 0.8757142857142857, 0.8757142857142857, 0.8757142857142857, 0.8757142857142857]
  
# plot lines
plt.plot(x, y2, '-o', label = "Recall Proxy")
plt.plot(x, y3, '-o', label = "Recall Interp Var")
plt.plot(x, y3_u, '-o', label = "Recall Proxy Units")
plt.plot(x, y4, '-o', label = "Recall Interp Var Det")
plt.plot(x, y5, '-o', label = "Recall Inf Var")
plt.plot(x, y6, '-o', label = "Recall Inf Var Units")
plt.legend()
plt.show()

# %%
HIT RATIO CUT OFF = 3
**************************************************************************************
Chain Length = 3 Recall = 0.5696428571428571
Chain Length = 3 MRR = 0.581860702789273
Chain Length = 3 NDCG = 0.6187462382248833
**************************************************************************************
Chain Length = 4_units Recall = 0.9871428571428571
Chain Length = 4_units MRR = 0.9860714285714286
Chain Length = 4_units NDCG = 0.986624085010204
**************************************************************************************
Chain Length = 4 Recall = 0.9510714285714286
Chain Length = 4 MRR = 0.9502976190476191
Chain Length = 4 NDCG = 0.9521104852743422
**************************************************************************************
Chain Length = 5 Recall = 0.6907142857142857
Chain Length = 5 MRR = 0.6888809523809524
Chain Length = 5 NDCG = 0.6900739308206838
**************************************************************************************
Chain Length = 6 Recall = 0.7639285714285714
Chain Length = 6 MRR = 0.7613295068027209
Chain Length = 6 NDCG = 0.765031977178463
**************************************************************************************
Chain Length = 7 Recall = 0.8757142857142857
Chain Length = 7 MRR = 0.8757142857142857
Chain Length = 7 NDCG = 0.8757142857142857
**************************************************************************************

HIT RATIO CUT OFF = 5
**************************************************************************************
Chain Length = 3 Recall = 0.6439285714285714
Chain Length = 3 MRR = 0.581860702789273
Chain Length = 3 NDCG = 0.6187462382248833
**************************************************************************************
Chain Length = 4_units Recall = 0.9882142857142857
Chain Length = 4_units MRR = 0.9860714285714286
Chain Length = 4_units NDCG = 0.986624085010204
**************************************************************************************
Chain Length = 4 Recall = 0.9575
Chain Length = 4 MRR = 0.9502976190476191
Chain Length = 4 NDCG = 0.9521104852743422
**************************************************************************************
Chain Length = 5 Recall = 0.6928571428571428
Chain Length = 5 MRR = 0.6888809523809524
Chain Length = 5 NDCG = 0.6900739308206838
**************************************************************************************
Chain Length = 6 Recall = 0.7707142857142857
Chain Length = 6 MRR = 0.7613295068027209
Chain Length = 6 NDCG = 0.765031977178463
**************************************************************************************
Chain Length = 7 Recall = 0.8757142857142857
Chain Length = 7 MRR = 0.8757142857142857
Chain Length = 7 NDCG = 0.8757142857142857
**************************************************************************************

HIT RATIO CUT OFF = 7

**************************************************************************************
Chain Length = 3 Recall = 0.6696428571428571
Chain Length = 3 MRR = 0.581860702789273
Chain Length = 3 NDCG = 0.6187462382248833
**************************************************************************************
Chain Length = 4_units Recall = 0.9882142857142857
Chain Length = 4_units MRR = 0.9860714285714286
Chain Length = 4_units NDCG = 0.986624085010204
**************************************************************************************
Chain Length = 4 Recall = 0.9575
Chain Length = 4 MRR = 0.9502976190476191
Chain Length = 4 NDCG = 0.9521104852743422
**************************************************************************************
Chain Length = 5 Recall = 0.6935714285714286
Chain Length = 5 MRR = 0.6888809523809524
Chain Length = 5 NDCG = 0.6900739308206838
**************************************************************************************
Chain Length = 6 Recall = 0.7735714285714286
Chain Length = 6 MRR = 0.7613295068027209
Chain Length = 6 NDCG = 0.765031977178463
**************************************************************************************
Chain Length = 7 Recall = 0.8757142857142857
Chain Length = 7 MRR = 0.8757142857142857
Chain Length = 7 NDCG = 0.8757142857142857
**************************************************************************************

HIT RATIO CUT OFF = 10

**************************************************************************************
Chain Length = 3 Recall = 0.7160714285714286
Chain Length = 3 MRR = 0.581860702789273
Chain Length = 3 NDCG = 0.6187462382248833
**************************************************************************************
Chain Length = 4_units Recall = 0.9882142857142857
Chain Length = 4_units MRR = 0.9860714285714286
Chain Length = 4_units NDCG = 0.986624085010204
**************************************************************************************
Chain Length = 4 Recall = 0.9575
Chain Length = 4 MRR = 0.9502976190476191
Chain Length = 4 NDCG = 0.9521104852743422
**************************************************************************************
Chain Length = 5 Recall = 0.6935714285714286
Chain Length = 5 MRR = 0.6888809523809524
Chain Length = 5 NDCG = 0.6900739308206838
**************************************************************************************
Chain Length = 6 Recall = 0.7764285714285715
Chain Length = 6 MRR = 0.7613295068027209
Chain Length = 6 NDCG = 0.765031977178463
**************************************************************************************
Chain Length = 7 Recall = 0.8757142857142857
Chain Length = 7 MRR = 0.8757142857142857
Chain Length = 7 NDCG = 0.8757142857142857
**************************************************************************************
