# %%
import lipd
import pandas as pd
import os
from collections import defaultdict

# %%
input_path = 'D:\\annotating_paleoclimate_data\\recommender\\download_files\\linked_earth_wiki_files'

tup = list(os.walk(input_path))
root, dir_names, file_names = tup[0][0], tup[0][1], tup[0][2]

# %%
table = pd.DataFrame(columns = ['filename','archiveType', 'inferredVariableType','units','proxyObservationType','interpretation/variable','interpretation/variableDetail'])

# %%
author_info = set()
investigator_info = set()
no_info = set()
dataCon = set()
reverse_index_author = {}

# %%
def add_to_reversed_index_author_map(val, archive):
    for a_name in val.split(','):
        reverse_index_author.setdefault(a_name,[]).append(archive)

# %%
for line in file_names:
    print(line)
    if '.lpd' in line:
        filen = line.strip()
        l = os.path.join(root, line.strip())
        d= lipd.readLipd(l)
        if 'archiveType' not in d:
            continue
        archive = d['archiveType']
        if 'pub' in d:
            path = d['pub'][0]
            if 'author' in path:
                print(path['author'])
                author_list = path['author']
                for auth in author_list:
                    if 'name' in auth:
                        val = auth['name'][0] if type(auth['name']) == list else auth['name']
                        add_to_reversed_index_author_map(val, archive)
                author_info.add(line)
        if line not in author_info and 'investigator' in d:
            path_investigators = d['investigator']
            print(path_investigators)
            for auth in author_list:
                if 'name' in auth:
                    val = auth['name'][0] if type(auth['name']) == list else auth['name']
                    add_to_reversed_index_author_map(val, archive)
            investigator_info.add(line)
        elif line not in author_info and line not in investigator_info :
            no_info.add(line)

# %%
import collections
for key in reverse_index_author.keys():
    reverse_index_author[key] = dict(collections.Counter(reverse_index_author[key]))

# %%
reverse_index_author['Y. Shibata'] = reverse_index_author['and Y. Shibata. Harada']
del reverse_index_author['and Y. Shibata. Harada']

reverse_index_author['N. Harada'] = reverse_index_author[' N.']
del reverse_index_author[' N.']

reverse_index_author['N. Ahagon'] = reverse_index_author[' N. Ahagon']
del reverse_index_author[' N. Ahagon']

reverse_index_author['T. Sakamoto'] = reverse_index_author[' T. Sakamoto']
del reverse_index_author[' T. Sakamoto']

reverse_index_author['M. Uchida'] = reverse_index_author[' M. Uchida']
del reverse_index_author[' M. Uchida']

reverse_index_author[' M. Ikehara'] = reverse_index_author[' M. Ikehara']
del reverse_index_author[' M. Ikehara']

reverse_index_author['W.L. Prell'] = reverse_index_author['W.L. Fairbanks']
del reverse_index_author['W.L. Fairbanks']

reverse_index_author['R.G. Fairbanks'] = reverse_index_author[' R.G.']
del reverse_index_author[' R.G.']
del reverse_index_author[' Prell']

# %%
author_names = reverse_index_author.keys()

# %%
seed_author_list = {}
for n in author_names:
    n = n.title()
    n_list = n.split()
    with_ini = False
    for ind, inner_n in enumerate(n_list):
        if ind != 1 and '.' in inner_n:
            with_ini = True            
    if not with_ini:
        try:
            seed_author_list[n[0].upper()].add(n)
        except KeyError:
            seed_author_list[n[0].upper()] = {n}

# %%
seed_author_list['K'].remove('Karl-Heinz \xa0Baumann')
seed_author_list['N'].remove('Nicholas J Shackleton')
seed_author_list['N'].remove('Nicholas Shackleton')
seed_author_list['N'].remove('Nick Shackleton')
seed_author_list['P'].remove('Peter J Müller')
seed_author_list['R'].remove('Ralph R Schneider')
seed_author_list['R'].remove('Ralph Schneider')

seed_author_list['R'].add('R.G. Fairbanks')
seed_author_list['W'].add('W.L. Prell')

# %%
com_same = []
last_same = []
ref_same = []
iter_same = []

# %%
def editDistance(str1, str2, m, n):
    dp = [[0 for x in range(n + 1)] for x in range(m + 1)]
 
    # Fill d[][] in bottom up manner
    for i in range(m + 1):
        for j in range(n + 1):
 
            if i == 0:
                dp[i][j] = j    # Min. operations = j
 
            elif j == 0:
                dp[i][j] = i    # Min. operations = i
 
            elif str1[i-1] == str2[j-1]:
                dp[i][j] = dp[i-1][j-1]

            else:
                dp[i][j] = 1 + min(dp[i][j-1],        # Insert
                                   dp[i-1][j],        # Remove
                                   dp[i-1][j-1])    # Replace
 
    return dp[m][n]

# %%
def check_fname(auth_list, rn_list):
    if ('.' in auth_list[0] and rn_list[0][0] == auth_list[0][0]):
        return True
    elif rn_list[0] == auth_list[0]:
        return True
    else:
        matching = 0
        auth_fname, rn_fname = auth_list[0], rn_list[0]
        ap, rp = 0, 0
        while ap < len(auth_fname) and rp < len(rn_fname):
            if auth_fname[ap] == rn_fname[rp]:
                matching += 1
                ap += 1
                rp += 1
            else:
                break
        if matching >= 2:
            return True
        return False

# %%
author_names_map = {}
for n in author_names:
    auth = n.title()
    
    reference_names = seed_author_list[auth[0].upper()]
    for rn in reference_names:

        auth_list, rn_list = auth.split(), rn.split()
        auth_lastName, rn_lastName = auth_list[-1], rn_list[-1]
        # complete names are same
        if rn_list == auth_list:
            author_names_map[n] = rn
            com_same.append(n)
            break
        # lastNames are completely equal
        elif rn_lastName == auth_lastName:
            if check_fname(auth_list, rn_list):
                author_names_map[n] = rn
                last_same.append(n)
                break
        # refernce lastName is a substring of input lastName
        elif rn_lastName in auth_lastName:
            if check_fname(auth_list, rn_list):
                author_names_map[n] = rn
                ref_same.append(n)
                break
        # check where the characters of the lastName are different
        if len(auth_lastName) >= 3 and len(rn_lastName) >= 3:     
            edit_dist = editDistance(auth_lastName, rn_lastName, len(auth_lastName), len(rn_lastName))
            if edit_dist <= 2:
                if check_fname(auth_list, rn_list):
                    author_names_map[n] = rn
                    iter_same.append(n)
                    break
    if n not in author_names_map:
        author_names_map[n] = auth

# %%
# change to FirstName. LastName format
        
author_names_map['SARNTHEIN M.'] = 'M. Sarthein'
author_names_map['ERLENKEUSER H.'] = 'H. Erlenkeuser'
author_names_map['KUCERA M.'] = 'M. Kucera'
author_names_map['PFLAUMANN U.'] = 'U. Pflaumann'
author_names_map['SCHULZ M.'] = 'M. Schulz'

# %%
table1 = pd.DataFrame(columns = ['filename','archiveType','proxyObservationType','units'])
table2 = pd.DataFrame(columns = ['filename','archiveType','proxyObservationType', 'inferredVariableType','units'])

ignore_inf_types = ['Age', 'Year']

# %%
seq1, seq2 = 0, 0
uniPr, proPr = 0, 0

# %%
input_path = 'D:\\annotating_paleoclimate_data\\recommender\\download_files\\linked_earth_wiki_files_new'
# input_path = 'D:\\annotating_paleoclimate_data\\recommender\\download_files\\temp_folder'

tup = list(os.walk(input_path))
root, dir_names, file_names = tup[0][0], tup[0][1], tup[0][2]

# %%
for line in file_names:
    print(line)
    if '.lpd' in line:
        filen = line.strip()
        line = os.path.join(root, line.strip())
        d = lipd.readLipd(line)
        if 'paleoData' not in d:
            continue
        path = d['paleoData']['paleo0']['measurementTable']['paleo0measurement0']['columns']
#         print(path.keys())
        archive = d['archiveType']
        # print('archive: ', archive)
        for key in path.keys() :
            print(path[key].keys())
            
            unit = 'NotApplicable'
            inferredVType = 'NA'
            proxyOType = 'NA'
            if 'proxyObservationType' in path[key].keys() :
                if 'units' in path[key].keys() :
                    unit = path[key]['units']
                    uniPr += 1
                proxyOType = path[key]['proxyObservationType']
                
                if proxyOType != 'NA':
                    df = pd.DataFrame({'filename':[filen], 'archiveType': [archive],'proxyObservationType':[proxyOType],'units':[unit]})
                    table1 = table1.append(df, ignore_index = True)
                    seq1 += 1
                
            elif 'inferredVariableType' in path[key].keys() :
                if 'units' in path[key].keys() :
                    unit = path[key]['units']
                if 'inferredFrom' in path[key].keys() :
                    if 'proxyObservationType' in path[key]['inferredFrom']:
                        proxyOType = path[key]['inferredFrom']['proxyObservationType']
                        proPr += 1
                inferredVType = path[key]['inferredVariableType']
            
                if inferredVType not in ignore_inf_types and (inferredVType != 'NA' or proxyOType != 'NA'): 
                    df = pd.DataFrame({'filename':[filen], 'archiveType': [archive],'proxyObservationType':[proxyOType],'inferredVariableType': [inferredVType],'units':[unit]})
                    table2 = table2.append(df, ignore_index = True)
                    seq2 += 1
# Out:
# A7.Oppo.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: A7.Oppo.2005.lpd
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'instrument', 'measurementMethod', 'variableName', 'proxyObservationType', 'measurementStandard', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'instrument', 'measurementMethod', 'variableName', 'proxyObservationType', 'takenAtDepth', 'variableType', '1', 'values', 'hasResolution'])
# dict_keys(['calibration', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# Afr-ColdAirCave.Sundqvist.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-ColdAirCave.Sundqvist.2013.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'iso2kUI', 'measurementMethod', 'variableName', 'pages2kID', 'precededBy', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Afr-LakeMalawi.Powers.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeMalawi.Powers.2011.lpd
# Finished read: 1 record
# dict_keys(['description', 'number', 'TSid', 'variableName', 'proxyObservationType', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution', 'hasMinValue'])
# dict_keys(['description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Afr-LakeTanganyika.Tierney.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeTanganyika.Tierney.2010.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Afr-P178-15P.Tierney.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-P178-15P.Tierney.2015.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-BerknerIsland.Mulvaney.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-BerknerIsland.Mulvaney.2002.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-CoastalDML.Thamban.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-CoastalDML.Thamban.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DomeC.Jouzel.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeC.Jouzel.2001.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DomeC.Stenni.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
# reading: Ant-DomeC.Stenni.2001.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DomeF1993.Uemura.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeF1993.Uemura.2014.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DomeF2001.Uemura.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeF2001.Uemura.2008.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DSS.DahlJensen.1999.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DSS.DahlJensen.1999.lpd
# Finished read: 1 record
# dict_keys(['number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-DSS.Moy.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DSS.Moy.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-Ferrigno.Thomas.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-Ferrigno.Thomas.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-JamesRossIsland.Mulvaney.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-JamesRossIsland.Mulvaney.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasMinValue', 'hasResolution'])
# Ant-MES.Rhodes.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-MES.Rhodes.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-PlateauRemote.Mosley-Thompson.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-PlateauRemote.Mosley-Thompson.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-SipleStation.Mosley-Thompson.1990.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SipleStation.Mosley-Thompson.1990.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-SiteDML05.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML05.Graf.2002.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-SiteDML07.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML07.Graf.2002.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-SiteDML17.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML17.Graf.2002.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-TALDICE.Stenni.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TALDICE.Stenni.2010.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-TalosDome.Stenni.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TalosDome.Stenni.2002.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-TaylorDome.Steig.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TaylorDome.Steig.2000.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-US-ITASE-2000-1.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-US-ITASE-2000-1.Steig.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-US-ITASE-2002-4.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-US-ITASE-2002-4.Steig.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-VLG.Bertler.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-VLG.Bertler.2011.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-Vostok.Ekaykin.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-Vostok.Ekaykin.2014.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-WAIS-Divide.Severinghaus.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-WAIS-Divide.Severinghaus.2012.lpd
# Finished read: 1 record
# dict_keys(['number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-WDC05A.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-WDC05A.Steig.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Ant-WDC06A.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-WDC06A.Steig.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'qCnotes', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-Agassiz.Vinther.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Agassiz.Vinther.2008.lpd
# 1.6 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasMinValue', 'hasResolution'])
# Arc-AkademiiNaukIceCap.Opel.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-AkademiiNaukIceCap.Opel.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-Arjeplog.Bjorklund.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Arjeplog.Bjorklund.2014.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'variableName', 'notes', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-Armarnaes.Bjorklund.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Armarnaes.Bjorklund.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Austfonna.Isaksson.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Austfonna.Isaksson.2005.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Avam-Taimyr.Briffa.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Avam-Taimyr.Briffa.2008.lpd
# Finished read: 1 record
# dict_keys(['description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasMinValue', 'hasResolution'])
# Arc-BigRoundLake.Thomas.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-BigRoundLake.Thomas.2009.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['calibration', 'number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-BlueLake.Bird.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-BlueLake.Bird.2008.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['calibration', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-CampCentury.Fisher.1969.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-CampCentury.Fisher.1969.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Crete.Vinther.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Crete.Vinther.2010.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-DevonIceCap.Fisher.1983.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-DevonIceCap.Fisher.1983.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Dye.Vinther.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Dye.Vinther.2010.lpd
# 1.31 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Forfjorddalen.McCarroll.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Forfjorddalen.McCarroll.2013.lpd
# Finished read: 1 record
# dict_keys(['description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'pages2kID', 'precededBy', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-GISP2.Grootes.1997.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-GISP2.Grootes.1997.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-GRIP.Vinther.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-GRIP.Vinther.2010.lpd
# 1.3 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-GulfofAlaska.Wilson.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-GulfofAlaska.Wilson.2014.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-HalletLake.McKay.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-HalletLake.McKay.2008.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'measurementMethod', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'measurementMethod', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'measurementMethod', 'variableName', 'notes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-HudsonLake.Clegg.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-HudsonLake.Clegg.2011.lpd
# 1.14 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: get_csv_from_columns: Arc-HudsonLake.Clegg.2011.chron0model0ensemble0.csv, 'values'
# Finished read: 1 record
# dict_keys(['calibration', 'number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Hvítárvatn.Larsen.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Hvítárvatn.Larsen.2011.lpd
# 1.72 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'variableName', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasMinValue', 'hasResolution'])
# Arc-Iceland.Bergthorsson.1969.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Iceland.Bergthorsson.1969.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'number', 'TSid', 'inferredVariableType', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Indigirka.Hughes.1999.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Indigirka.Hughes.1999.lpd
# Finished read: 1 record
# dict_keys(['description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Kittelfjall.Bjorklund.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Kittelfjall.Bjorklund.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'measurementMaterial', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-Kongressvatnet.D'Andrea.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Kongressvatnet.D'Andrea.2012.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-Laanila.Lindholm.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-Laanila.Lindholm.2013.lpd
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# Arc-LakeC2.Lamoureux.1996.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-LakeC2.Lamoureux.1996.lpd
# 1.92 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasMinValue', 'hasResolution'])
# Arc-LakeDonardBaffinIsland.Moore.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arc-LakeDonardBaffinIsland.Moore.2001.lpd
# 1.11 MB :That's a big file! This may take a while to load...
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Finished read: 1 record
# dict_keys(['detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'proxyObservationType', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# Arc-LakeE.D'Andrea.2011.lpd
# ...
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'qCnotes', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# SAm-LagunaChepical.deJong.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SAm-LagunaChepical.deJong.2013.lpd
# Finished read: 1 record
# dict_keys(['calibration', 'dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'qCnotes', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'detail', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# SAm-LagunaEscondida.Elbert.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SAm-LagunaEscondida.Elbert.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'qCCertification', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'notes', 'pages2kID', 'qCCertification', 'qCnotes', 'takenAtDepth', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# SAm-QuelccayaIceCap.Thompson.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SAm-QuelccayaIceCap.Thompson.2013.lpd
# Finished read: 1 record
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'precededBy', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'pages2kID', 'precededBy', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMedianValue'])
# dict_keys(['dataType', 'description', 'number', 'hasMaxValue', 'hasMeanValue', 'units', 'TSid', 'variableName', 'notes', 'proxyObservationType', 'qCCertification', 'useInGlobalTemperatureAnalysis', 'variableType', 'values', 'hasResolution', 'hasMinValue', 'hasMedianValue'])
# SK168-GC1.Gebregiorgis.2016.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SK168-GC1.Gebregiorgis.2016.lpd
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'notes', 'proxyObservationType', 'measurementStandard', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'notes', 'proxyObservationType', 'measurementStandard', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'notes', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'notes', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# SK237-GC04.Saraswat.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SK237-GC04.Saraswat.2013.lpd
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'variableName', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# TestDataset.2017.Khider.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: TestDataset.2017.Khider.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: merge_csv_table: paleo, 'TestDataset.Paleo1.measurementTable1.csv'
# Error: merge_csv_table: chron, 'TestDataset.Chron1.measurementTable1.csv'
# Error: get_csv_from_columns: TestDataset.2017.Khider.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: TestDataset.2017.Khider.chron0measurement0.csv, 'values'
# Finished read: 1 record
# dict_keys(['description', 'detail', 'error', 'number', 'hasMax', 'hasMean', 'hasMedian', 'hasMin', 'resolution', 'units', 'TSid', 'inferredVariableType', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'proxyObservationType', 'takenAtDepth', 'variableType'])
# dict_keys(['description', 'detail', 'error', 'number', 'hasMax', 'hasMean', 'hasMedian', 'hasMin', 'units', 'TSid', 'inferredVariableType', 'interpretation', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'takenAtDepth', 'variableType'])
# dict_keys(['description', 'detail', 'error', 'number', 'hasMax', 'hasMaxValue', 'hasMean', 'hasMeanValue', 'hasMedian', 'hasMedianValue', 'hasMin', 'hasMinValue', 'resolution', 'units', 'TSid', 'interpretation', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'proxyObservationType', 'sensorSpecies', 'takenAtDepth', 'variableType'])
# dict_keys(['description', 'detail', 'error', 'number', 'hasMax', 'hasMaxValue', 'hasMean', 'hasMeanValue', 'hasMedian', 'hasMedianValue', 'hasMin', 'hasMinValue', 'resolution', 'units', 'TSid', 'interpretation', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'proxyObservationType', 'sensorSpecies', 'takenAtDepth', 'variableType'])
# dict_keys(['calibration', 'description', 'detail', 'error', 'number', 'hasMax', 'hasMaxValue', 'hasMean', 'hasMeanValue', 'hasMedian', 'hasMedianValue', 'hasMin', 'hasMinValue', 'resolution', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'takenAtDepth', 'variableType'])
# dict_keys(['calibration', 'description', 'detail', 'error', 'number', 'hasMax', 'hasMaxValue', 'hasMean', 'hasMeanValue', 'hasMedian', 'hasMedianValue', 'hasMin', 'hasMinValue', 'resolution', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'measurementMaterial', 'measurementMethod', 'nOAAdataFormat', 'nOAAdataType', 'nOAAseasonality', 'variableName', 'notes', 'takenAtDepth', 'variableType'])
# TR163-22.Lea.2006.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: TR163-22.Lea.2006.lpd
# Finished read: 1 record
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'variableName', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'instrument', 'measurementMethod', 'variableName', 'proxyObservationType', 'measurementStandard', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'instrument', 'measurementMethod', 'variableName', 'proxyObservationType', 'measurementStandard', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'interpretation', 'instrument', 'measurementMethod', 'variableName', 'notes', 'proxyObservationType', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])
# dict_keys(['calibration', 'number', 'hasMaxValue', 'hasMeanValue', 'hasMedianValue', 'hasMinValue', 'units', 'TSid', 'inferredFrom', 'inferredVariableType', 'interpretation', 'variableName', 'takenAtDepth', 'variableType', 'values', 'hasResolution'])

# %%
table_com=table1.explode('proxyObservationType').explode('units').reset_index()
table_com = table_com.drop(columns = ['index'])
table_com.to_csv('arch_pro_uni.csv', sep = ',', encoding = 'utf-8',index = False)

table_com=table2.explode('proxyObservationType').explode('units').explode('inferredVariableType').reset_index()
table_com = table_com.drop(columns = ['index'])
table_com.to_csv('arch_pro_inf_uni.csv', sep = ',', encoding = 'utf-8',index = False)

# %%
print('seq1' , seq1)
print('seq2' , seq2)
# Out:
# seq1 2230
# seq2 175

# %%
print('uniPresent' , uniPr)
print('proPr' , proPr)
# Out:
# uniPresent 2136
# proPr 91
