# %%
import lipd
import pandas as pd
import os

# %%
input_path = 'D:\\annotating_paleoclimate_data\\recommender\\download_files'

# f = open('file-name.txt')
tup = list(os.walk(input_path))
root, dir_names, file_names = tup[0][0], tup[0][1], tup[0][2]
table = pd.DataFrame(columns = ['filename','archiveType', 'inferredVariableType','units','proxyObservationType','interpretation/variable','interpretation/variableDetail'])

# %%
file_names
# Out:
# ['A7.Oppo.2005.lpd',
#  'Afr-ColdAirCave.Sundqvist.2013.lpd',
#  'Afr-LakeMalawi.Powers.2011.lpd',
#  'Afr-LakeTanganyika.Tierney.2010.lpd',
#  'Afr-P178-15P.Tierney.2015.lpd',
#  'Ant-BerknerIsland.Mulvaney.2002.lpd',
#  'Ant-CoastalDML.Thamban.2012.lpd',
#  'Ant-DomeC.Jouzel.2001.lpd',
#  'Ant-DomeC.Stenni.2001.lpd',
#  'Ant-DomeF1993.Uemura.2014.lpd',
#  'Ant-DomeF2001.Uemura.2008.lpd',
#  'Ant-DSS.DahlJensen.1999.lpd',
#  'Ant-DSS.Moy.2012.lpd',
#  'Ant-Ferrigno.Thomas.2013.lpd',
#  'Ant-JamesRossIsland.Mulvaney.2013.lpd',
#  'Ant-MES.Rhodes.2012.lpd',
#  'Ant-PlateauRemote.Mosley-Thompson.2013.lpd',
#  'Ant-SipleStation.Mosley-Thompson.1990.lpd',
#  'Ant-SiteDML05.Graf.2002.lpd',
#  'Ant-SiteDML07.Graf.2002.lpd',
#  'Ant-SiteDML17.Graf.2002.lpd',
#  'Ant-TALDICE.Stenni.2010.lpd',
#  'Ant-TalosDome.Stenni.2002.lpd',
#  'Ant-TaylorDome.Steig.2000.lpd',
#  'Ant-US-ITASE-2000-1.Steig.2013.lpd',
#  'Ant-US-ITASE-2002-4.Steig.2013.lpd',
#  'Ant-VLG.Bertler.2011.lpd',
#  'Ant-Vostok.Ekaykin.2014.lpd',
#  'Ant-WAIS-Divide.Severinghaus.2012.lpd',
#  'Ant-WDC05A.Steig.2013.lpd',
#  'Ant-WDC06A.Steig.2013.lpd',
#  'Arc-Agassiz.Vinther.2008.lpd',
#  'Arc-AkademiiNaukIceCap.Opel.2013.lpd',
#  'Arc-Arjeplog.Bjorklund.2014.lpd',
#  'Arc-Armarnaes.Bjorklund.2012.lpd',
#  'Arc-Austfonna.Isaksson.2005.lpd',
#  'Arc-Avam-Taimyr.Briffa.2008.lpd',
#  'Arc-BigRoundLake.Thomas.2009.lpd',
#  'Arc-BlueLake.Bird.2008.lpd',
#  'Arc-CampCentury.Fisher.1969.lpd',
#  'Arc-Crete.Vinther.2010.lpd',
#  'Arc-DevonIceCap.Fisher.1983.lpd',
#  'Arc-Dye.Vinther.2010.lpd',
#  'Arc-Forfjorddalen.McCarroll.2013.lpd',
#  'Arc-GISP2.Grootes.1997.lpd',
#  'Arc-GRIP.Vinther.2010.lpd',
#  'Arc-GulfofAlaska.Wilson.2014.lpd',
#  'Arc-HalletLake.McKay.2008.lpd',
#  'Arc-HudsonLake.Clegg.2011.lpd',
#  'Arc-Hvítárvatn.Larsen.2011.lpd',
#  'Arc-Iceland.Bergthorsson.1969.lpd',
#  'Arc-Indigirka.Hughes.1999.lpd',
#  'Arc-Kittelfjall.Bjorklund.2012.lpd',
#  "Arc-Kongressvatnet.D'Andrea.2012.lpd",
#  'Arc-Laanila.Lindholm.2013.lpd',
#  'Arc-LakeC2.Lamoureux.1996.lpd',
#  'Arc-LakeDonardBaffinIsland.Moore.2001.lpd',
#  "Arc-LakeE.D'Andrea.2011.lpd",
#  'Arc-LakeLehmilampi.Haltia-Hovi.2007.lpd',
#  'Arc-LakeNataujärvi.Ojala.2005.lpd',
#  'Arc-LenaRiver.McDonald.1998.lpd',
#  'Arc-Lomonosovfonna.Divine.2011.lpd',
#  'Arc-LowerMurrayLake.Cook.2008.lpd',
#  'Arc-MackenzieDelta.Porter.2013.lpd',
#  'Arc-MD992275.Jiang.2005.lpd',
#  'Arc-NGTB16.Schwager.1998.lpd',
#  'Arc-PennyIceCapP96.Fisher.1998.lpd',
#  'Arc-PennyIceCapP96.Okuyama.2003.lpd',
#  'Arc-PolarUrals.Wilson.2015.lpd',
#  'Arc-PrinceOfWales.Kinnard.2011.lpd',
#  'Arc-SoperLake.Hughen.2000.lpd',
#  'Arc-StoreggaSlide.Sejrup.2011.lpd',
#  'Arc-Tjeggelvas.Bjorklund.2012.lpd',
#  'Arc-Tornetrask.Melvin.2012.lpd',
#  'Arc-VøringPlateau.Berner.2011.lpd',
#  'Arc-WindyDome.Henderson.2011.lpd',
#  'Arc-Yamalia.Briffa.2013.lpd',
#  "Arc-Yukon.D'Arrigo.2006.lpd",
#  'Asi-AltaiAktru.Cook.2005.lpd',
#  'Asi-AltaiDjasator.Cook.2011.lpd',
#  'Asi-AltaiJablonsky.Cook.2000.lpd',
#  'Asi-AltaiKorumdu.Cook.2005.lpd',
#  'Asi-AltaiKuraisky.Cook.2011.lpd',
#  'Asi-AltaiKuraiskySteppe.Cook.2011.lpd',
#  'Asi-AltaiSamakhaSteppe.Cook.2011.lpd',
#  'Asi-AltaiTjute.Cook.2011.lpd',
#  'Asi-AltaiUlaganValley.Cook.2011.lpd',
#  'Asi-AltaiUstUlaganLake.Cook.2005.lpd',
#  'Asi-BARELC.PAGES2k.2013.lpd',
#  'Asi-BHUTSP.PAGES2k.2013.lpd',
#  'Asi-BHUTTD.PAGES2k.2013.lpd',
#  'Asi-BT001.Cook.2010.lpd',
#  'Asi-BT002.Cook.2010.lpd',
#  'Asi-BT003.Cook.2010.lpd',
#  'Asi-BT004.Cook.2010.lpd',
#  'Asi-BT005.Cook.2010.lpd',
#  'Asi-BT006.Cook.2010.lpd',
#  'Asi-BT008.Cook.2010.lpd',
#  'Asi-BT009.Cook.2010.lpd',
#  'Asi-BT010.Cook.2010.lpd',
#  'Asi-BT011.Cook.2010.lpd',
#  'Asi-BT018.Cook.2010.lpd',
#  'Asi-BURGPW.PAGES2k.2013.lpd',
#  'Asi-CENTIB.PAGES2k.2013.lpd',
#  'Asi-CentralChina.Wang.1998.lpd',
#  'Asi-CHIN004.Wu.2013.lpd',
#  'Asi-CHIN005.Sheppard.2013.lpd',
#  'Asi-CHIN006.Sheppard.2013.lpd',
#  'Asi-CHIN016.Li.2010.lpd',
#  'Asi-CHIN017.Li.2010.lpd',
#  'Asi-CHIN018.Li.2010.lpd',
#  'Asi-CHIN019.Li.2010.lpd',
#  'Asi-CHIN020.Li.2010.lpd',
#  'Asi-CHIN021.Li.2010.lpd',
#  'Asi-CHIN026.Wright.2010.lpd',
#  'Asi-CHIN029.Krusic.2010.lpd',
#  'Asi-CHIN037.Fan.2013.lpd',
#  'Asi-CHIN038.Fan.2013.lpd',
#  'Asi-CHIN039.Fan.2013.lpd',
#  'Asi-CHIN040.Fan.2013.lpd',
#  'Asi-CHIN041.Fan.2013.lpd',
#  'Asi-CHIN042.Brauning.2013.lpd',
#  'Asi-CHIN043.Brauning.2013.lpd',
#  'Asi-CHIN044.Brauning.2013.lpd',
#  'Asi-CHIN045.Brauning.2013.lpd',
#  'Asi-CHIN046.Brauning.2013.lpd',
#  'Asi-CHIN047.Brauning.2013.lpd',
#  'Asi-CHIN048.Brauning.2013.lpd',
#  'Asi-CHIN049.Brauning.2013.lpd',
#  'Asi-CHIN050.Shao.2013.lpd',
#  'Asi-CHIN051.Shao.2013.lpd',
#  'Asi-CHIN052.Shao.2013.lpd',
#  'Asi-CHIN053.Shao.2013.lpd',
#  'Asi-CHIN054.Shao.2013.lpd',
#  'Asi-CHIN055.Shao.2013.lpd',
#  'Asi-CHIN056.Shao.2013.lpd',
#  'Asi-CHIN057.Shao.2013.lpd',
#  'Asi-CHIN058.Shao.2013.lpd',
#  'Asi-CHIN059.Shao.2013.lpd',
#  'Asi-CHIN060.Shao.2013.lpd',
#  'Asi-CHIN061.Shao.2013.lpd',
#  'Asi-CHIN062.Shao.2013.lpd',
#  'Asi-CHIN063.Shao.2013.lpd',
#  'Asi-CHIN064.Shao.2013.lpd',
#  'Asi-CHIN065.Shao.2013.lpd',
#  'Asi-CHIN066.Shao.2013.lpd',
#  'Asi-Dasuopu.Thompson.2000.lpd',
#  'Asi-DEZQIN.PAGES2k.2013.lpd',
#  'Asi-DQHZHO.PAGES2k.2013.lpd',
#  'Asi-DUSHJP.PAGES2k.2013.lpd',
#  'Asi-EastChina.Wang.1990.lpd',
#  'Asi-EastChina.Wang.1998.lpd',
#  'Asi-ENEPAB.PAGES2k.2013.lpd',
#  'Asi-ESPERG.PAGES2k.2013.lpd',
#  'Asi-ESPPAK.PAGES2k.2013.lpd',
#  'Asi-Fujian.Wang.1998.lpd',
#  'Asi-GANGCD.PAGES2k.2013.lpd',
#  'Asi-GHEGAN.PAGES2k.2013.lpd',
#  'Asi-GOUQIN.PAGES2k.2013.lpd',
#  'Asi-Guangdong.Zheng.1982.lpd',
#  'Asi-GuangdongAndGuangxi.Zhang.1980.lpd',
#  'Asi-Guliya.Thompson.1997.lpd',
#  'Asi-HBHXJP.PAGES2k.2013.lpd',
#  'Asi-HBLXJP.PAGES2k.2013.lpd',
#  'Asi-HBMXJP.PAGES2k.2013.lpd',
#  'Asi-HEBQIN.PAGES2k.2013.lpd',
#  'Asi-HRPCSM.PAGES2k.2013.lpd',
#  'Asi-Hunan-Jiangsu.Zhang.1980.lpd',
#  'Asi-Hushre.PAGES2k.2013.lpd',
#  'Asi-HXBURU.PAGES2k.2013.lpd',
#  'Asi-HYGJUP.PAGES2k.2013.lpd',
#  'Asi-INDI015.Borgaonkar.2013.lpd',
#  'Asi-INDI024.Borgaonkar.2013.lpd',
#  'Asi-INDI025.Borgaonkar.2013.lpd',
#  "Asi-INDO005.D'Arrigo.2010.lpd",
#  'Asi-JAPA012.Yasue.1997.lpd',
#  'Asi-JAPA013.Yasue.1997.lpd',
#  'Asi-JAPA014.Yasue.2013.lpd',
#  'Asi-JAPA015.Yasue.2013.lpd',
#  'Asi-JAPA016.Yasue.2013.lpd',
#  'Asi-JAPA017.Yasue.2013.lpd',
#  'Asi-JAPA019.Sano.2013.lpd',
#  'Asi-JAPA020.Kimura.2013.lpd',
#  'Asi-KAZ001.Solomina.2010.lpd',
#  'Asi-KERALA.PAGES2k.2013.lpd',
#  'Asi-KunashirIsland.Demezhko.2009.lpd',
#  'Asi-KYRG002.Esper.2007.lpd',
#  'Asi-KYRG003.Esper.2007.lpd',
#  'Asi-KYRG004.Esper.2007.lpd',
#  'Asi-KYRG005.Esper.2007.lpd',
#  'Asi-KYRG007.Esper.2007.lpd',
#  'Asi-KYRG008.Shiyatov.2013.lpd',
#  'Asi-KYRG009.Shiyatov.2013.lpd',
#  'Asi-KYRG010.Shiyatov.2013.lpd',
#  'Asi-KYRG011.Shiyatov.2013.lpd',
#  'Asi-KYRG012.Solomina.2013.lpd',
#  'Asi-KYRG013.Solomina.2013.lpd',
#  'Asi-KYRG014.Solomina.2013.lpd',
#  'Asi-KYRG015.Solomina.2013.lpd',
#  'Asi-LAJQIN.PAGES2k.2013.lpd',
#  'Asi-LowerYangtzeRiver.Zhang.1980.lpd',
#  'Asi-MCCHFH.Sano.2008.lpd',
#  'Asi-MiddleYangtzeRiver.Zhang.1980.lpd',
#  'Asi-MONG002.Jacoby.2013.lpd',
#  'Asi-MONG004.Jacoby.2013.lpd',
#  'Asi-MONG006.Jacoby.2006.lpd',
#  'Asi-MONG007.Schweingruber.2013.lpd',
#  'Asi-MONG009.Jacoby.2013.lpd',
#  'Asi-MONG010.Jacoby.2013.lpd',
#  'Asi-MONG011.Jacoby.2006.lpd',
#  'Asi-MONG012.Jacoby.2006.lpd',
#  'Asi-MONG014.Jacoby.2013.lpd',
#  'Asi-MONG015.Jacoby.2013.lpd',
#  'Asi-MONG016.Jacoby.2010.lpd',
#  'Asi-MONG017.Jacoby.2010.lpd',
#  'Asi-MONG018.Jacoby.2010.lpd',
#  'Asi-MONG019.Jacoby.2010.lpd',
#  'Asi-MONG020.Jacoby.2010.lpd',
#  'Asi-MONG021.Jacoby.2010.lpd',
#  'Asi-MONG024.Jacoby.2010.lpd',
#  'Asi-MONG025.Jacoby.2010.lpd',
#  'Asi-MONG026.Jacoby.2010.lpd',
#  'Asi-MONG027.Jacoby.2010.lpd',
#  'Asi-MONG028.Jacoby.2010.lpd',
#  'Asi-MONG029.Jacoby.2010.lpd',
#  'Asi-MONG030.Jacoby.2010.lpd',
#  'Asi-MONG031.Jacoby.2010.lpd',
#  'Asi-MONG032.Jacoby.2010.lpd',
#  'Asi-MONG033.Jacoby.2010.lpd',
#  'Asi-MQACJP.PAGES2k.2013.lpd',
#  'Asi-MQAXJP.PAGES2k.2013.lpd',
#  'Asi-MQBXJP.PAGES2k.2013.lpd',
#  'Asi-MQDXJP.PAGES2k.2013.lpd',
#  'Asi-MQFXJP.PAGES2k.2013.lpd',
#  'Asi-MQRXJP.PAGES2k.2013.lpd',
#  'Asi-MTASMD.Davi.2013.lpd',
#  'Asi-MTASSP.Davi.2013.lpd',
#  'Asi-NEPA003.Krusic.2013.lpd',
#  'Asi-NEPA010.Krusic.2013.lpd',
#  'Asi-NEPA014.Krusic.2013.lpd',
#  'Asi-NEPA015.Krusic.2013.lpd',
#  'Asi-NEPA018.Krusic.2013.lpd',
#  'Asi-NEPA019.Krusic.2013.lpd',
#  'Asi-NEPA021.Krusic.2013.lpd',
#  'Asi-NEPA025.Krusic.2013.lpd',
#  'Asi-NEPA027.Krusic.2013.lpd',
#  'Asi-NEPA029.Krusic.2013.lpd',
#  'Asi-NEPA030.Krusic.2013.lpd',
#  'Asi-NEPA032.Krusic.2013.lpd',
#  'Asi-NEPA036.Krusic.2013.lpd',
#  'Asi-NEPA042.Krusic.2010.lpd',
#  'Asi-NOGSAK.PAGES2k.2013.lpd',
#  'Asi-PAKI001.Esper.2007.lpd',
#  'Asi-PAKI002.Esper.2007.lpd',
#  'Asi-PAKI003.Esper.2007.lpd',
#  'Asi-PAKI004.Esper.2007.lpd',
#  'Asi-PAKI006.Esper.2007.lpd',
#  'Asi-PAKI007.Esper.2007.lpd',
#  'Asi-PAKI009.Esper.2007.lpd',
#  'Asi-PAKI010.Esper.2007.lpd',
#  'Asi-PAKI011.Esper.2007.lpd',
#  'Asi-PAKI012.Esper.2007.lpd',
#  'Asi-PAKI014.Esper.2007.lpd',
#  'Asi-PAKI015.Esper.2007.lpd',
#  'Asi-PAKI016.Esper.2007.lpd',
#  'Asi-PAKI017.Cook.2013.lpd',
#  'Asi-PAKI018.Cook.2013.lpd',
#  'Asi-PAKI020.Cook.2013.lpd',
#  'Asi-PAKI021.Cook.2013.lpd',
#  'Asi-PAKI022.Cook.2013.lpd',
#  'Asi-PAKI023.Cook.2013.lpd',
#  'Asi-PAKI024.Cook.2013.lpd',
#  'Asi-PAKI025.Cook.2013.lpd',
#  'Asi-PAKI027.Cook.2013.lpd',
#  'Asi-PAKI028.Cook.2013.lpd',
#  'Asi-PAKI029.Cook.2013.lpd',
#  'Asi-PAKI030.Cook.2013.lpd',
#  'Asi-PAKI031.Cook.2013.lpd',
#  'Asi-PAKI033.Cook.2013.lpd',
#  'Asi-PAKI035.Cook.2013.lpd',
#  'Asi-PAKI036.Cook.2013.lpd',
#  'Asi-PAKI039.Cook.2013.lpd',
#  'Asi-PAKI040.Cook.2011.lpd',
#  'Asi-PTCYUN.PAGES2k.2013.lpd',
#  'Asi-Puruogangri.Thompson.2006.lpd',
#  'Asi-QUMAJP.PAGES2k.2013.lpd',
#  'Asi-RANGCD.PAGES2k.2013.lpd',
#  'Asi-RUSS219.Jacoby.2010.lpd',
#  'Asi-RUSS236.Sano.2009.lpd',
#  'Asi-SANGTS.PAGES2k.2013.lpd',
#  'Asi-SHIESP.PAGES2k.2013.lpd',
#  'Asi-SHIYAT.PAGES2k.2013.lpd',
#  'Asi-SihailongwaLake.Chu.2011.lpd',
#  'Asi-SO90-39KG_SO130-275KL.Munz.2015.lpd',
#  'Asi-SODAPS.PAGES2k.2013.lpd',
#  'Asi-SourthAndMiddleUrals.Demezhko.2007.lpd',
#  'Asi-SouthChina.Wang.1998.lpd',
#  'Asi-TDAXJP.PAGES2k.2013.lpd',
#  'Asi-TDBXJP.PAGES2k.2013.lpd',
#  'Asi-TH001.Buckley.2010.lpd',
#  'Asi-TIANMU.PAGES2k.2013.lpd',
#  'Asi-TW001.Wright.2010.lpd',
#  'Asi-UKHEWD.Schweingruber.2002.lpd',
#  'Asi-UKHEWW.Schweingruber.2002.lpd',
#  'Asi-UKHLWD.Schweingruber.2002.lpd',
#  'Asi-UKHLWW.Schweingruber.2002.lpd',
#  'Asi-UKHMND.Schweingruber.2002.lpd',
#  'Asi-UKHMXD.Schweingruber.2002.lpd',
#  'Asi-UKHTRW.Schweingruber.2002.lpd',
#  'Asi-UULEWD.Schweingruber.2002.lpd',
#  'Asi-UULEWW.Schweingruber.2002.lpd',
#  'Asi-UULLWD.Schweingruber.2002.lpd',
#  'Asi-UULLWW.Schweingruber.2002.lpd',
#  'Asi-UULMND.Schweingruber.2002.lpd',
#  'Asi-UULMXD.Schweingruber.2002.lpd',
#  'Asi-UULTRW.Schweingruber.2002.lpd',
#  'Asi-VIET001.Buckley.2010.lpd',
#  'Asi-WEXYUN.Wright.2010.lpd',
#  'Asi-WULANJ.PAGES2k.2013.lpd',
#  'Asi-WXIYUN.Wright.2010.lpd',
#  'Asi-YKC.Yasue.2013.lpd',
#  'Asi-YKCOM.Yasue.2013.lpd',
#  'Asi-ZHANGX.PAGES2k.2010.lpd',
#  'Asi-ZhejiangAndFujian.Zhang.1980.lpd',
#  'Asi-ZHIDJP.Shao.2003.lpd',
#  'Aus-BuckleysChance.Buckley.1997.lpd',
#  'Aus-CTPEastTasmania.Allen.2001.lpd',
#  'Aus-CTPWestTasmania.Allen.2001.lpd',
#  'Aus-DuckholeLake.Saunders.2013.lpd',
#  'Aus-MtRead.Cook.2006.lpd',
#  'Aus-Oroko.Cook.2002.lpd',
#  'Aus-PinkPine.Duncan.2010.lpd',
#  "Aus-StewartIsland.D'Arrigo.1996.lpd",
#  'Aus-TakapariCedar.Xiong.2000.lpd',
#  'BJ8-03-13GGC.Linsley.2010.lpd',
#  'BJ8-03-70GGC.Linsley.2010.lpd',
#  'CO00COKY-SAMPLEDATA.lpd',
#  'DSDP502.deMenocal.1992.lpd',
#  'DSDP552.Shackleton.1984.lpd',
#  'DSDP607.Lisiecki.2005.lpd',
#  'DSDP610.Lisiecki.2005.lpd',
#  'Eur-CentralandEasternPyrenees.Pla.2004.lpd',
#  'Eur-CentralEurope.Dobrovolný.2009.lpd',
#  'Eur-CoastofPortugal.Abrantes.2011.lpd',
#  'Eur-EasternCarpathianMountains.Popa.2008.lpd',
#  'Eur-EuropeanAlps.Büntgen.2011.lpd',
#  'Eur-FinnishLakelands.Helama.2014.lpd',
#  'Eur-LakeSilvaplana.Larocque-Tobler.2010.lpd',
#  'Eur-LakeSilvaplana.Trachsel.2010.lpd',
#  'Eur-Lötschental.Büntgen.2006.lpd',
#  'Eur-MaritimeFrenchAlps.Büntgen.2012.lpd',
#  'Eur-NorthernScandinavia.Esper.2012.lpd',
#  'Eur-NorthernSpain.Martín-Chivelet.2011.lpd',
#  'Eur-RAPiD-17-5P.Moffa-Sanchez.2014.lpd',
#  'Eur-Seebergsee.Larocque-Tobler.2012.lpd',
#  'Eur-SpanishPyrenees.Dorado-Linan.2012.lpd',
#  'Eur-SpannagelCave.Mangini.2005.lpd',
#  'Eur-Stockholm.Leijonhufvud.2009.lpd',
#  'Eur-Tallinn.Tarand.2001.lpd',
#  'Eur-TatraMountains.Büntgen.2013.lpd',
#  'GeoB10042-1.Setiawan.2016.lpd',
#  'GeoB10043-3.Setiawan.2016.lpd',
#  'GeoB10069-3.Gibbons.2014.lpd',
#  'GeoB1023-5.Kim.2002.lpd',
#  'GeoB12605-3.Kuhnert.2014.lpd',
#  'GeoB12610-2.Rippert.2015.lpd',
#  'GeoB3129-1.Weldeab.2006.lpd',
#  'GeoB33021.Kim.2002.lpd',
#  'GeoB3911-3.Weldeab.2006.lpd',
#  'GeoB5844-2.Arz.2003.lpd',
#  'GeoB7702-3.Castaneda.2010.lpd',
#  'GIK16160-3.Wang.2003.lpd',
#  'GIK17748-2.Kim.2002.lpd',
#  'GIK17940-2.Pelejero.1999.lpd',
#  'GIK23258.Sarnthein.2003.lpd',
#  'JM98-1-PC.Husum.2004.lpd',
#  'JR51GC35.Bendle.2007.lpd',
#  'Juxtlahuaca.Lachniet.2012.lpd',
#  'Juxtlahuaca.Lachniet.2013.lpd',
#  'Juxtlahuaca.Lachniet.2017.lpd',
#  'Kesang.Cheng.2012.lpd',
#  'KNR-159-5_33GGC.Lacerra.2017.lpd',
#  'KNR-159-5_78GGC.Lacerra.2017.lpd',
#  'KNR166-2-26JPC.Schmidt.2011.lpd',
#  'KNR166-2JPC51.Schmidt.2012.lpd',
#  'KNR195-5-CDH23.Bova.2015.lpd',
#  'KNR195-5_CDH26.Bova.2015.lpd',
#  'KT05-7_PC02.Kawahata.2009.lpd',
#  'Kurupa.Boldt.2015.lpd',
#  'LakeSurprise.Falster.2018.lpd',
#  'LV29-114-3.Max.2012.lpd',
#  'M25_4-KL1.Emeis.2000.lpd',
#  'M35003-4.Ruehlemann.1999.lpd',
#  'M77-2_056.Nurnberg.2015.lpd',
#  'MD01-2378.Xu.2008.lpd',
#  'MD01-2390.Steinke.2008.lpd',
#  'MD01-2412.Harada.2006.lpd',
#  'MD02-2575.Ziegler.2008.lpd',
#  'MD03-2601.Kim.2012.lpd',
#  'MD03-2797.Weldeab.2007.lpd',
#  'MD05-2904.Steinke.2011.lpd',
#  'MD95-2015.Marchal.2002.lpd',
#  'MD95-2043.Cacho.1999.lpd',
#  'MD97-2121.Marr.2013.lpd',
#  'MD97-2141.Rosentha.2003.lpd',
#  'MD972120-MD972121.Pahnke.2006.lpd',
#  'MD98-2165.Levi.2007.lpd',
#  'MD98-2170.Stott.2004.lpd',
#  'MD982176.Stott.2004.lpd',
#  'MD982181.Khider.2014.lpd',
#  'ME0005A-43JC.Benway.2006.lpd',
#  "NAm-AlmondButterLower.D'Arrigo.2005.lpd",
#  "NAm-AlmondButterUpper.D'Arrigo.2005.lpd",
#  'NAm-Arapahoe.Kienast.1996.lpd',
#  'NAm-ArrowsmithMountain.Briffa.1996.lpd',
#  'NAm-Athabasca.Schweingruber.1996.lpd',
#  'NAm-AthabascaGlacier.Schweingruber.1996.lpd',
#  'NAm-AthabascaGlacier2.Luckman.2005.lpd',
#  'NAm-BakerLake.Hughes.2005.lpd',
#  'NAm-BarlowPassamMtHood.Briffa.1996.lpd',
#  'NAm-BasinPond.Gajewski.1988.lpd',
#  'NAm-BellMountain.Schweingruber.1996.lpd',
#  'NAm-Bennington.Luckman.2001.lpd',
#  'NAm-Bennington.Luckman.2013.lpd',
#  'NAm-BigBendLake.Jacoby.2003.lpd',
#  'NAm-BigWhite.Parish.2000.lpd',
#  'NAm-BigWhite2.Wilson.2005.lpd',
#  'NAm-BlanchardRiver.Luckman.2013.lpd',
#  'NAm-Bonif.Schweingruber.1996.lpd',
#  'NAm-BorealPlateau.Graumlich.2005.lpd',
#  'NAm-BowSummit-PeytoLake.Luckman.2005.lpd',
#  "NAm-BurntOver.D'Arrigo.2005.lpd",
#  'NAm-CameronPass.Bigler.2007.lpd',
#  'NAm-CanyonCreek.Lloyd.2002.lpd',
#  'NAm-CardinalDivide.Luckman.2001.lpd',
#  'NAm-CarltonRidge.Kipfmuller.2008.lpd',
#  'NAm-CeaderBreaks.Briffa.1996.lpd',
#  'NAm-CienegadeNuestraSenoradeGuadalupe.Fule.2009.lpd',
#  'NAm-CirquePeak.Graybill.1995.lpd',
#  'NAm-ClearPond.Gajewski.1988.lpd',
#  'NAm-ConroyLake.Gajewski.1988.lpd',
#  'NAm-CoppermineRiver.Jacoby.1989.lpd',
#  'NAm-CornwallHills.Wilson.2005.lpd',
#  'NAm-CottonwoodPass.Briffa.1996.lpd',
#  'NAm-CraterLakeNE.Briffa.2002.lpd',
#  'NAm-DanaPlateauInyoNationalForest.King.2000.lpd',
#  'NAm-DarkLake.Gajewski.1988.lpd',
#  'NAm-DeerMountain.Wiles.2011.lpd',
#  'NAm-DenaliNationalPark.Schweingruber.1996.lpd',
#  'NAm-DonJekRiverBridge.Schweingruber.1996.lpd',
#  'NAm-EagleFecal_PtarmiganMerge.Jacoby.2011.lpd',
#  'NAm-ElephantMountain.Conkey.1994.lpd',
#  'NAm-EurekaSummit.Schweingruber.1996.lpd',
#  'NAm-FirthRiver.Anchukaitis.2013.lpd',
#  'NAm-FishCreekTrail.Biondi.2001.lpd',
#  'NAm-FlintCreekRange.Hughes.2005.lpd',
#  'NAm-FlowerLake.Graybill.1995.lpd',
#  'NAm-FoolCreek.Brown.2005.lpd',
#  'NAm-FortChimo.Fritts.1981.lpd',
#  'NAm-FremontGlacier.Hill.0.lpd',
#  'NAm-FrenchGlacier.Colenutt.1995.lpd',
#  'NAm-GalenaPassSawtooth.Briffa.1996.lpd',
#  'NAm-GeraldineLakes.Luckman.2001.lpd',
#  'NAm-GraniteMountain.Graumlich.2003.lpd',
#  'NAm-GranitePassHuntMountain.Briffa.1996.lpd',
#  'NAm-GreatBasin.Salzer.2013.lpd',
#  'NAm-GreenLake.Menounos.2006.lpd',
#  'NAm-HartsPassN2.Peterson.1994.lpd',
#  'NAm-HellsKitchenLake.Gajewski.1988.lpd',
#  'NAm-HerringAlpine.Fritts.1995.lpd',
#  'NAm-HighlandFireOutlook.Briffa.1996.lpd',
#  'NAm-HighwoodPass.Luckman.2001.lpd',
#  'NAm-Hilda.Kavanagh.2000.lpd',
#  'NAm-HohLakeHigh.Peterson.1994.lpd',
#  'NAm-HornbyCabin.Jacoby.1989.lpd',
#  "NAm-IttyhaukBay.D'Arrigo.2011.lpd",
#  'NAm-KobukNoatak.King.2003.lpd',
#  'NAm-LacNoir.Paquette.2013.lpd',
#  'NAm-LacRomanel.Schweingruber.1996.lpd',
#  'NAm-LakeMina.St.Jacques.2008.lpd',
#  'NAm-LakeoftheClouds.Gajewski.1988.lpd',
#  'NAm-Landslide.Luckman.2006.lpd',
#  'NAm-LaTasajera.Biondi.2001.lpd',
#  'NAm-LittlePineLake.Gajewski.1988.lpd',
#  "NAm-Manitoba.D'Arrigo.2006.lpd",
#  'NAm-McGinnisTrail.Wiles.2013.lpd',
#  'NAm-MeadowMountain.Wilson.2005.lpd',
#  'NAm-MedicineBowPeak.Briffa.1996.lpd',
#  'NAm-MedusaBay.Buckley.2003.lpd',
#  'NAm-MinersWell.Wiles.2000.lpd',
#  'NAm-MountAdamsLow.Peterson.1994.lpd',
#  'NAm-MountWashington.Graybill.1994.lpd',
#  'NAm-MtLemon.Briffa.2002.lpd',
#  'NAm-MtStHelens.Briffa.1996.lpd',
#  'NAm-NabesnaMine.Jacoby.2003.lpd',
#  'NAm-Nadahini.Luckman.2013.lpd',
#  'NAm-Nakiska.Luckman.2001.lpd',
#  "NAm-NorthernAlaskaComposite.D'Arrigo.2006.lpd",
#  'NAm-OregonCaves.Ersek.2012.lpd',
#  'NAm-ParkMountain.Wilson.2005.lpd',
#  'NAm-PearlPeak.Graybill.1994.lpd',
#  'NAm-PethaiPeninsula.Schweingruber.1996.lpd',
#  'NAm-PeytoLake.Schweingruber.1996.lpd',
#  'NAm-PikePeaks.Harlan.1996.lpd',
#  'NAm-Pintlers.Littell.2011.lpd',
#  'NAm-PintlersTwo.Littell.2011.lpd',
#  'NAm-PowderRiverPass.Briffa.1996.lpd',
#  'NAm-PrinceWilliamSound.Barclay.1999.lpd',
#  'NAm-PyramidMountain.Luckman.2001.lpd',
#  'NAm-RedMountainPassSilverton.Graybill.1994.lpd',
#  'NAm-RockGlacierYukon.Kenigsberg.2013.lpd',
#  'NAm-RoweLakes.Colenutt.2011.lpd',
#  'NAm-RubyLake.Gajewski.1988.lpd',
#  'NAm-SanFrancisoPeaksUpdate.Graybill.2005.lpd',
#  'NAm-ScatterLake.Graumlich.2003.lpd',
#  'NAm-SettlementPointAfognakIsland.Harlan.1998.lpd',
#  "NAm-SewardComposite.D'Arrigo.2006.lpd",
#  'NAm-SheepMountain.Graybill.1995.lpd',
#  'NAm-SheepTrail.Brown.2005.lpd',
#  'NAm-ShermanCreekPass.Briffa.1996.lpd',
#  'NAm-SiberianOutpostView.Bunn.2010.lpd',
#  'NAm-SignalMountain.Luckman.2001.lpd',
#  'NAm-SleepingDeerRoad.Hughes.2005.lpd',
#  'NAm-SmallRiver.Luckman.2001.lpd',
#  'NAm-SmithersSkiArea.Schweingruber.1996.lpd',
#  'NAm-SnakeCreek.Kenigsberg.2013.lpd',
#  'NAm-SnowBowlSanFranciscoPeak.Briffa.2002.lpd',
#  "NAm-SouthernAlaskacomposite.D'Arrigo.2006.lpd",
#  'NAm-SpillwayLakeYosemiteNationalPark.King.2000.lpd',
#  'NAm-SpruceCreek.Church.1981.lpd',
#  'NAm-StarrigawanOldSitka.Kaiser.1996.lpd',
#  'NAm-STREC.Gennaretti.2014.lpd',
#  'NAm-Sugarloaf.Kenigsberg.2013.lpd',
#  'NAm-SunshineMeadows.Colenutt.1995.lpd',
#  'NAm-SunwaptaPass.Schweingruber.1996.lpd',
#  'NAm-SurpriseValley.Luckman.2001.lpd',
#  'NAm-SylvanPassbeiCody.Briffa.1996.lpd',
#  'NAm-TamarackBowl.Sauchyn.2016.lpd',
#  'NAm-TimberGapUpper.Graybill.1995.lpd',
#  'NAm-TogwateePass.Briffa.1996.lpd',
#  'NAm-TwistedTreeHeartrotHill.Jacoby.1989.lpd',
#  'NAm-UpperWrightLakes.Graumlich.2005.lpd',
#  'NAm-VancouverCyprusProvincialPark.Briffa.1996.lpd',
#  'NAm-VicaryMine.Sauchyn.2016.lpd',
#  'NAm-wa069.Peterson.1994.lpd',
#  'NAm-wa071.Peterson.1994.lpd',
#  "NAm-WindyRidgeAlaska.D'Arrigo.2005.lpd",
#  "NAm-WrangellsComposite.D'Arrigo.2006.lpd",
#  'NAm-YellowMountainRidge.King.2002.lpd',
#  'NAm-Ymir.Wilson.2005.lpd',
#  'NAm-YosemiteParkEEingang.Briffa.1996.lpd',
#  'Ocn-AbrahamReef.Druffel.1999.lpd',
#  'Ocn-AlboranSea384B.Nieto-Moreno.2013.lpd',
#  'Ocn-AlboranSea436B.Nieto-Moreno.2013.lpd',
#  'Ocn-AmedeeIsland.DeLong.2012.lpd',
#  'Ocn-AqabaJordanAQ18.Heiss.1999.lpd',
#  'Ocn-AqabaJordanAQ19.Heiss.1999.lpd',
#  'Ocn-ArabianSea.Doose-Rolinski.2001.lpd',
#  'Ocn-Bermuda.DraschbaA.2000.lpd',
#  'Ocn-Bermuda.DraschbaB.2000.lpd',
#  'Ocn-BermudaSouthShore.Goodkin.2008.lpd',
#  'Ocn-BiscayneBay.Swart.1996.lpd',
#  'Ocn-BuccooReefTobagoMontastrea.Moses.2006.lpd',
#  'Ocn-BuccooReefTobagoSidereastrea.Moses.2006.lpd',
#  'Ocn-BunakenIsland.Charles.2003.lpd',
#  'Ocn-BundegireefNingaloo.Cooper.2012.lpd',
#  'Ocn-CapeGhir.Doose-Rolinski.2007.lpd',
#  'Ocn-CapeGhir.McGregor.2007.lpd',
#  'Ocn-CapeHatteras.Cleroux.2008.lpd',
#  'Ocn-CariacoBasin.Black.2007.lpd',
#  'Ocn-CariacoBasin.Lea.2003.lpd',
#  'Ocn-CH07-98-MC-22.Saenger.2011.lpd',
#  'Ocn-ChileanMargin.Lamy.2002.lpd',
#  'Ocn-ClerkeReefRowleyShoals.Cooper.2012.lpd',
#  'Ocn-Clipperton1b.Wu.2014.lpd',
#  'Ocn-Clipperton2b.Wu.2014.lpd',
#  'Ocn-Clipperton4b.Wu.2014.lpd',
#  'Ocn-Clipperton6a.Wu.2014.lpd',
#  'Ocn-ClippertonAtoll.Linsley.2000.lpd',
#  'Ocn-CoralBayNingaloo.Cooper.2012.lpd',
#  'Ocn-CoralSea.Calvo.2007.lpd',
#  'Ocn-DoubleReef.Asami.2005.lpd',
#  'Ocn-DryTortugas.DeLong.2014.lpd',
#  'Ocn-DryTortugas.Lund.2006.lpd',
#  'Ocn-DryTortugasA.Lund.2006.lpd',
#  'Ocn-EasternTropicalNorthAtlantic.Kuhnert.2011.lpd',
#  'Ocn-EmeraldBasin.Keigwin.2003.lpd',
#  'Ocn-FiskBasin.Richey.2009.lpd',
#  'Ocn-FloridaBay.Swart.1996.lpd',
#  'Ocn-GarrisonBasin.Richey.2009.lpd',
#  'Ocn-GBR.Wei.2009.lpd',
#  'Ocn-GingerbreadsBahamas.Saenger.2009.lpd',
#  'Ocn-GreatBahamaBank.Lund.2006.lpd',
#  'Ocn-GreatBahamaBank.Richter.2006.lpd',
#  'Ocn-GreatBarrierReef.Hendy.2002.lpd',
#  'Ocn-Guadeloupe.Steinhilber.2010.lpd',
#  'Ocn-GulfofGuinea.Weldeab.2007.lpd',
#  'Ocn-GulfofMaine.Wanamaker.2007.lpd',
#  'Ocn-HaferaIsland.Wu.2013.lpd',
#  'Ocn-HoutmanAbrolhos.Kuhnert.1999.lpd',
#  'Ocn-HoutmanAbrolhosHAB05B.Zinke.2014.lpd',
#  'Ocn-HoutmanAbrolhosHAB10A.Zinke.2014.lpd',
#  'Ocn-HoutmanAbrolhosIslands.Cooper.2012.lpd',
#  'Ocn-Ifaty1.Zinke.2014.lpd',
#  'Ocn-Ifaty4.Zinke.2004.lpd',
#  'Ocn-IfatyTul3.Zinke.2014.lpd',
#  'Ocn-ImperieuseRowleyShoals.Cooper.2012.lpd',
#  'Ocn-JacafFjord.Sepúlveda.2009.lpd',
#  'Ocn-Kiritimati.Evans.1998.lpd',
#  'Ocn-KNR140‐2‐59GGC.Saenger.2011.lpd',
#  'Ocn-KuroshioCurrent.Isono.2009.lpd',
#  'Ocn-LaingIslandPapuaNewGuinea.Tudhope.2001.lpd',
#  'Ocn-LaurentianFan.Keigwin.2005.lpd',
#  'Ocn-Lombok.Charles.2003.lpd',
#  'Ocn-LosRoques.Hetzinger.2008.lpd',
#  'Ocn-MadangLagoonPapuaNewGuinea.Kuhnert.2001.lpd',
#  'Ocn-MadangLagoonPapuaNewGuinea.Tudhope.1995.lpd',
#  'Ocn-Mafia.Damassa.2006.lpd',
#  'Ocn-Mahe.Charles.1997.lpd',
#  'Ocn-Maiana.Urban.2000.lpd',
#  'Ocn-MakassarStrait.Linsley.2010.lpd',
#  'Ocn-MakassarStrait.Oppo.2009.lpd',
#  'Ocn-Malindi.Cole.2000.lpd',
#  'Ocn-Malindi.Nakamura.2009.lpd',
#  'Ocn-MaloChannelEspirituSantoIsland.Kilbourne.2004.lpd',
#  'Ocn-Mayotte.Zinke.2008.lpd',
#  'Ocn-MD95-2011.Grimalt.2002.lpd',
#  'Ocn-MD98-2160.Newton.2010.lpd',
#  'Ocn-MD98-2177.Newton.2010.lpd',
#  'Ocn-MentawaiIslands.Abram.2008.lpd',
#  'Ocn-MinorcaContourite.Moreno.2012.lpd',
#  'Ocn-Miyanohama.Felis.2009.lpd',
#  'Ocn-MontegoBayJamaica.Haase-Schramm.2003.lpd',
#  'Ocn-Moorea.Boiseau.1998.lpd',
#  'Ocn-Nauru.Guilderson.1999.lpd',
#  'Ocn-NewIrelandPapua.Alibert.2008.lpd',
#  'Ocn-Ningaloo.Kuhnert.2000.lpd',
#  'Ocn-NorthEastBreakers_Bermuda.Kuhnert.2002.lpd',
#  'Ocn-NorthEastBreakers_Bermuda.Kuhnert.2005.lpd',
#  'Ocn-NorthIceland.Sicre.2011.lpd',
#  'Ocn-NorthwestPacificOcean.Harada.2004.lpd',
#  'Ocn-ODP984.Came.2007.lpd',
#  'Ocn-OkinawaTrough.Wu.2012.lpd',
#  'Ocn-PalauRockIslands.Osborne.2014.lpd',
#  'Ocn-PalauUlongChannel.Osborne.2014.lpd',
#  'Ocn-Palmyra.Cobb.2003.lpd',
#  'Ocn-Palmyra.Nurhati.2011.lpd',
#  'Ocn-PedradeLume-CapeVerdeIslands.Moses.2006.lpd',
#  'Ocn-PedroBankJamaica.Haase-Schramm.2003.lpd',
#  'Ocn-Philippines.Stott.2007.lpd',
#  'Ocn-PigmyBasin.Richey.2015.lpd',
#  'Ocn-PuntaMaroma.Vásquez-Bedoya.2012.lpd',
#  'Ocn-Rabaul.Quinn.2006.lpd',
#  'Ocn-RAPiD-12-1K.Thornalley.2009.lpd',
#  'Ocn-RarotongaSrCa2r.Linsley.2006.lpd',
#  'Ocn-Rarotonga_d18O2R.Linsley.2006.lpd',
#  'Ocn-Rarotonga_d18O3R.Linsley.2006.lpd',
#  'Ocn-Rarotonga_d18O99.Linsley.2006.lpd',
#  'Ocn-RedSea.Felis.2000.lpd',
#  'Ocn-Reunion.Pfeiffer.2004.lpd',
#  'Ocn-SantaBarbaraBasin.Zhao.2000.lpd',
#  'Ocn-SavusavuBay1F.Linsley.2006.lpd',
#  'Ocn-SavusavuBayAB.Linsley.2006.lpd',
#  'Ocn-SavusavuBayFiji.Bagnato.2005.lpd',
#  'Ocn-SecasIslandPanama.Linsley.1994.lpd',
#  'Ocn-SinaiPeninsula,RedSea.Moustafa.2000.lpd',
#  'Ocn-SouthAtlanticWestAfrica.Leduc.2010.lpd',
#  'Ocn-SouthernChileMargin.Mohtadi.2007.lpd',
#  'Ocn-SouthIceland.Sicre.2011.lpd',
#  'Ocn-SubTropicalEasternNorthAtlantic.deMenocal.2000.lpd',
#  'Ocn-SWCoastOfIndia.Saraswat.2013.lpd',
#  'Ocn-TagusMudPatch.Abrantes.2005.lpd',
#  'Ocn-TantabiddiReefNingaloo.Cooper.2012.lpd',
#  'Ocn-Tarawa.Cole.1990.lpd',
#  'Ocn-TongueoftheOcean.Rosenheim.2005.lpd',
#  'Ocn-TongueoftheOceanExuma.Rosenheim.2005.lpd',
#  'Ocn-TurrumoteReefPuertoRico.Kilbourne.2008.lpd',
#  'Ocn-UrvinaBay.Dunbar.1994.lpd',
#  'Ocn-Vanuatu.Gorman.2012.lpd',
#  'Ocn-Vanuatu.Quinn.1996.lpd',
#  'Ocn-WEqPacific.Stott.2007.lpd',
#  'Ocn-WesternAntarcticPeninsula.Shevenell.2011.lpd',
#  'Ocn-WesternSvalbard.Spielhagen.2011.lpd',
#  'Ocn-XishaIslandSouthChinaSea.Sun.2004.lpd',
#  'ODP1019.Barron.2003.lpd',
#  'ODP1098B.Shevenell.2011.lpd',
#  'ODP658.Sarnthein.1989.lpd',
#  'ODP659.Tiedemann.1994.lpd',
#  'ODP662.Lisiecki.2005.lpd',
#  'ODP664.Raymo.1997.lpd',
#  'ODP976.Jimenez-Amat.2015.lpd',
#  'P178-15P.Tierney.2015.lpd',
#  'Palmyra.Cobb.2013.lpd',
#  'raw-data-table.csv',
#  'SAm-CentralAndes11.PAGES2k.2011.lpd',
#  'SAm-CentralAndes15.Neukom.2014.lpd',
#  'SAm-CentralAndes6.Villalba.2014.lpd',
#  'SAm-CentralAndes9.Mundo.2014.lpd',
#  'SAm-LagunaAculeo.vonGunten.2009.lpd',
#  'SAm-LagunaChepical.deJong.2013.lpd',
#  'SAm-LagunaEscondida.Elbert.2013.lpd',
#  'SAm-QuelccayaIceCap.Thompson.2013.lpd',
#  'SK168-GC1.Gebregiorgis.2016.lpd',
#  'SK237-GC04.Saraswat.2013.lpd',
#  'table_com.py',
#  'temp.py',
#  'TestDataset.2017.Khider.lpd',
#  'TR163-22.Lea.2006.lpd']

# %%
for line in file_names:
    print(line)
    if '.lpd' in line:
        filen = line.strip()
        line = os.path.join(root, line.strip())
        d= lipd.readLipd(line)
        if 'paleoData' not in d:
            continue
        path = d['paleoData']['paleo0']['measurementTable']['paleo0measurement0']['columns']
        print(path)
        archive = d['archiveType']
        print('archive: ', archive)
        for key in path.keys() :
            unit = 'NA'
            inferredVType = 'NA'
            proxyOType = 'NA'
            intVariable = 'NA'
            intVarDet = 'NA'
            if 'inferredVariableType' in path[key].keys() :
                #print('---inferredVariableType---')
                #print('variableName: ', key)
                if 'units' in path[key].keys() :
                    unit = path[key]['units']
                #print('units: ', unit)
                #print('inferredVariableType: ', path[key]['inferredVariableType'])
                inferredVType = path[key]['inferredVariableType']
            if 'proxyObservationType' in path[key].keys() :
                #print('---proxyObservationType')
                #print('variableName: ', key)
                #print('units: ', path[key]['units'])
                if 'units' in path[key].keys() :
                    unit = path[key]['units']
                #print('proxyObservationType: ',path[key]['proxyObservationType'])
                proxyOType = path[key]['proxyObservationType']
            if 'interpretation' in path[key].keys() :
                #print('---interpretation---')
                for inter in path[key]['interpretation']:
                    #print('variable: ', inter['variable'])
                    if type(inter) is not str :
                        if 'variable' in inter.keys() :
                            intVariable = inter['variable']
                    #print('variableDetail: ', inter['variableDetail'])
                        if 'variableDetail' in inter.keys() :
                            intVarDet = inter['variableDetail']
            if unit != 'NA' or inferredVType != 'NA' or proxyOType != 'NA' or intVariable != 'NA' or intVarDet != 'NA' :
                df = pd.DataFrame({'filename':[filen], 'archiveType': [archive],'units':[unit],'inferredVariableType': [inferredVType],'proxyObservationType':[proxyOType],'interpretation/variable':[intVariable],'interpretation/variableDetail':[intVarDet]})
                #print(df)
                table = table.append(df, ignore_index = True)
# Out:
# A7.Oppo.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: A7.Oppo.2005.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: A7.Oppo.2005.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: A7.Oppo.2005.chron0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('depth', {'number': '1', 'hasMaxValue': 450, 'hasMeanValue': 226, 'hasMedianValue': 226, 'hasMinValue': 2, 'TSid': 'PYTUMT8CO7Z', 'variableName': 'depth', 'variableType': 'measured'}), ('age1', {'number': '2', 'hasMaxValue': 18193.33, 'hasMeanValue': 11373.682933333, 'hasMedianValue': 12384.71, 'hasMinValue': 1367, 'TSid': 'PYT4OP3N0PV', 'inferredVariableType': 'Age', 'interpretation': [{'variableDetail': 'calendar', 'variable': 'Age', 'scope': 'Age'}], 'variableName': 'age1', 'takenAtDepth': {'foundInTable': 'A7.Sun.2005.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 450, 'hasMeanValue': 226, 'hasMedianValue': 226, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 147.5, 'hasMeanValue': 75.117544642857, 'hasMedianValue': 64.439999999999, 'hasMinValue': 5.5499999999993}, 'hasVariableID': 'PYTUMT8CO7Z', 'measuredOn': {'collectionmethod': 'Gravity corer', 'name': 'A7'}, 'name': 'depth'}, 'variableType': 'inferred'}), ('age2', {'number': '3', 'hasMaxValue': 17677.22, 'hasMeanValue': 10960.378816964, 'hasMedianValue': 11926.47, 'hasMinValue': 1084, 'TSid': 'PYTJJXK40RU', 'inferredVariableType': 'Age', 'interpretation': [{'variableDetail': 'calendar', 'variable': 'Age', 'scope': 'Age'}], 'variableName': 'age2', 'takenAtDepth': {'foundInTable': 'A7.Sun.2005.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 450, 'hasMeanValue': 226, 'hasMedianValue': 226, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 147.5, 'hasMeanValue': 75.117544642857, 'hasMedianValue': 64.439999999999, 'hasMinValue': 5.5499999999993}, 'hasVariableID': 'PYTUMT8CO7Z', 'measuredOn': {'collectionmethod': 'Gravity corer', 'name': 'A7'}, 'name': 'depth'}, 'variableType': 'inferred'}), ('d18og.rub', {'number': '4', 'hasMaxValue': -0.21, 'hasMeanValue': -1.4395777777778, 'hasMedianValue': -1.48, 'hasMinValue': -2.62, 'TSid': 'PYTW0D8MOY6', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Isotope'}, {'variableDetail': 'sea surface', 'variable': 'd18Osw', 'scope': 'Isotope'}], 'instrument': {'housedAt': 'Institute of Earth Environment, the Chinese Academy of Sciences', 'name': 'Finnegan MAT 252'}, 'measurementMethod': '250-255 micrometer size fraction. About 40 shells picked for stable isotope and trace element analysis', 'variableName': 'd18og.rub', 'proxyObservationType': 'D18O', 'measurementStandard': 'VPDB', 'takenAtDepth': {'foundInTable': 'A7.Sun.2005.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 450, 'hasMeanValue': 226, 'hasMedianValue': 226, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 147.5, 'hasMeanValue': 75.117544642857, 'hasMedianValue': 64.439999999999, 'hasMinValue': 5.5499999999993}, 'hasVariableID': 'PYTUMT8CO7Z', 'measuredOn': {'collectionmethod': 'Gravity corer', 'name': 'A7'}, 'name': 'depth'}, 'variableType': 'measured'}), ('mg/ca', {'number': '5', 'hasMaxValue': 4.55, 'hasMeanValue': 3.6060714285714, 'hasMedianValue': 3.64, 'hasMinValue': 2.67, 'TSid': 'PYTFSXYJF6G', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Climate'}], 'instrument': {'housedAt': 'Woods Hole Oceanographic Institution', 'name': 'Finnegan Element 2 ICP-MS'}, 'measurementMethod': '300 micrograms of foraminiferal material. 250-355 micrometer size fraction', 'variableName': 'mg/ca', 'proxyObservationType': 'Mg/Ca', 'takenAtDepth': {'foundInTable': 'A7.Sun.2005.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 450, 'hasMeanValue': 226, 'hasMedianValue': 226, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 147.5, 'hasMeanValue' ...
# archive:  marine sediment
# Afr-ColdAirCave.Sundqvist.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-ColdAirCave.Sundqvist.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Afr-ColdAirCave.Sundqvist.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'calibration': [{'uncertaintyType': 'calibrationRMSE'}], 'dataType': 'N', 'description': 'inferred temperature', 'detail': 'top of sample; signal believed to primarily reflect temperature, but influence of other factors cannot be excluded.', 'number': '1', 'hasMaxValue': 0.4736077, 'hasMeanValue': -0.22745030097935, 'hasMedianValue': -0.2160947, 'hasMinValue': -1.444134, 'TSid': 'Africa_001', 'iso2kUI': 'SP03HOSA01A', 'measurementMethod': 'Linear regression', 'variableName': 'd18O', 'pages2kID': 'Afr_012', 'precededBy': 'Afr_8', 'proxyObservationType': 'D18O', 'qCCertification': 'BMC, DN', 'qCnotes': 'Temperature estimates determined using linear regression between speleothem d18O and annual mean temperature. An "anomalous" period, from AD 1956-1976 was removed from this calibration. In the context of the Holocene, the application of this calibration results in temperature trends contrary to other published records for the last 10,000 years.', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1992, 'hasMeanValue': 1805.0648967552, 'hasMedianValue': 1804, 'hasMinValue': 1635, 'TSid': 'PYTY0O3KGL4', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'}), ('SE', {'description': 'error on temp reconstruction', 'number': '3', 'hasMaxValue': 0.5780824, 'hasMeanValue': 0.5780824, 'hasMedianValue': 0.5780824, 'hasMinValue': 0.5780824, 'TSid': 'Africa_002', 'variableName': 'SE', 'proxyObservationType': ['SE', 'D18O'], 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'})])
# archive:  physical sample
# Afr-LakeMalawi.Powers.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeMalawi.Powers.2011.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Afr-LakeMalawi.Powers.2011.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('core', {'description': 'core name', 'number': '1', 'TSid': 'Malawi01', 'variableName': 'core', 'proxyObservationType': 'Core', 'takenAtDepth': {'dataType': 'float', 'description': 'depth', 'foundInTable': 'Afr-LakeMalawi.Powers.2011.paleo1measurement1', 'hasColumnNumber': '3', 'hasMaxValue': 93, 'hasMeanValue': 40.541666666667, 'hasMedianValue': 42.625, 'hasProxySystem': {'proxyArchiveType': 'LakeSediment', 'proxySensorType': 'DefaultSensor'}, 'hasResolution': {'hasMaxValue': -2, 'hasMeanValue': -20.371428571429, 'hasMedianValue': -18, 'hasMinValue': -45}, 'hasVariableID': 'PYTWTKZRIDP', 'name': 'depth'}, 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1996, 'hasMeanValue': 1693.6111111111, 'hasMedianValue': 1694.5, 'hasMinValue': 1283, 'TSid': 'PYTVDUQKGDE', 'inferredVariableType': 'Year', 'variableName': 'year', 'takenAtDepth': {'dataType': 'float', 'description': 'depth', 'foundInTable': 'Afr-LakeMalawi.Powers.2011.paleo1measurement1', 'hasColumnNumber': '3', 'hasMaxValue': 93, 'hasMeanValue': 40.541666666667, 'hasMedianValue': 42.625, 'hasProxySystem': {'proxyArchiveType': 'LakeSediment', 'proxySensorType': 'DefaultSensor'}, 'hasResolution': {'hasMaxValue': -2, 'hasMeanValue': -20.371428571429, 'hasMedianValue': -18, 'hasMinValue': -45}, 'hasVariableID': 'PYTWTKZRIDP', 'name': 'depth'}, 'variableType': 'inferred'}), ('depth', {'dataType': 'float', 'description': 'depth', 'number': '3', 'hasMaxValue': 93, 'hasMeanValue': 40.541666666667, 'hasMedianValue': 42.625, 'TSid': 'PYTWTKZRIDP', 'variableName': 'depth', 'variableType': 'measured'}), ('TEX86', {'description': 'mean TEX86 from 1-4 replicates', 'number': '4', 'hasMaxValue': 0.753, 'hasMeanValue': 0.71188888888889, 'hasMedianValue': 0.7115, 'hasMinValue': 0.664, 'TSid': 'Malawi04', 'variableName': 'TEX86', 'notes': '; paleoData_units changed - was originally unitless', 'proxyObservationType': 'TEX86', 'takenAtDepth': {'dataType': 'float', 'description': 'depth', 'foundInTable': 'Afr-LakeMalawi.Powers.2011.paleo1measurement1', 'hasColumnNumber': '3', 'hasMaxValue': 93, 'hasMeanValue': 40.541666666667, 'hasMedianValue': 42.625, 'hasProxySystem': {'proxyArchiveType': 'LakeSediment', 'proxySensorType': 'DefaultSensor'}, 'hasResolution': {'hasMaxValue': -2, 'hasMeanValue': -20.371428571429, 'hasMedianValue': -18, 'hasMinValue': -45}, 'hasVariableID': 'PYTWTKZRIDP', 'name': 'depth'}, 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'}), ('temperature', {'calibration': [{'equation': 'ALST=55.0*TEX86−14.0', 'reference': 'Powers et al., 2010', 'uncertainty': 3.7}], 'description': 'inferred lake surface temperature', 'number': '5', 'hasMaxValue': 27.43, 'hasMeanValue': 25.153888888889, 'hasMedianValue': 25.14, 'hasMinValue': 22.5, 'TSid': 'Malawi05', 'inferredVariableType': 'Temperature', 'variableName': 'temperature', 'notes': '; paleoData_units changed - was originally deg C; climateInterpretation_seasonality changed - was originally annual', 'pages2kID': 'Afr_005', 'qCCertification': 'BMC, DN', 'takenAtDepth': {'dataType': 'float', 'description': 'depth', 'foundInTable': 'Afr-LakeMalawi.Powers.2011.paleo1measurement1', 'hasColumnNumber': '3', 'hasMaxValue': 93, 'hasMeanValue': 40.541666666667, 'hasMedianValue': 42.625, 'hasProxySystem': {'proxyArchiveType': 'LakeSediment', 'proxySensorType': 'DefaultSensor'}, 'hasResolution': {'hasMaxValue': -2, 'hasMeanValue': -20.371428571429, 'hasMedianValue': -18, 'hasMinValue': -45}, 'hasVariableID': 'PYTWTKZRIDP', 'name': 'depth'}, 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'inferred'})])
# archive:  lake sediment
# Afr-LakeTanganyika.Tierney.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-LakeTanganyika.Tierney.2010.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Afr-LakeTanganyika.Tierney.2010.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('TEX86', {'dataType': 'N', 'number': '1', 'hasMaxValue': 0.74922972398291, 'hasMeanValue': 0.69353152307671, 'hasMedianValue': 0.69443686383609, 'hasMinValue': 0.66795559296453, 'TSid': 'Africa_003', 'variableName': 'TEX86', 'proxyObservationType': 'TEX86', 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1986, 'hasMeanValue': 1357.6944444444, 'hasMedianValue': 1410, 'hasMinValue': 504, 'TSid': 'PYTIYWRSKG9', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'}), ('temperature', {'calibration': [{'notes': 'Analytical error on the basis of duplicate measurements (and corrected for n=2) was ±0,1°C. This error is compounded with the leave-one-out calibration error 0,4°C to give a total 95% error of ±0,4°C.', 'uncertaintyType': 'calibrationRMSE'}], 'dataType': 'N', 'description': 'inferred lake surface temperature', 'number': '3', 'hasMaxValue': 25.626356290112, 'hasMeanValue': 23.461144428084, 'hasMedianValue': 23.496338644764, 'hasMinValue': 22.466905720903, 'TSid': 'Africa_004', 'inferredVariableType': 'Temperature', 'variableName': 'temperature', 'notes': 'Analytical error on the basis of duplicate measurements (and corrected for n=2) was ±0,1°C. This error is compounded with the leave-one-out calibration error 0,4°C to give a total 95% error of ±0,4°C.', 'pages2kID': 'Afr_004', 'qCCertification': 'BMC, DN', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'inferred'}), ('upper95', {'dataType': 'N', 'description': '95% error range upper value', 'number': '4', 'hasMaxValue': 26.026356290112, 'hasMeanValue': 23.861144428084, 'hasMedianValue': 23.896338644764, 'hasMinValue': 22.866905720903, 'TSid': 'Africa_005', 'variableName': 'upper95', 'proxyObservationType': ['Upper95', 'TEX86'], 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'}), ('lower95', {'dataType': 'N', 'description': '95% error range lower value', 'number': '5', 'hasMaxValue': 25.226356290112, 'hasMeanValue': 23.061144428084, 'hasMedianValue': 23.096338644764, 'hasMinValue': 22.066905720903, 'TSid': 'Africa_006', 'variableName': 'lower95', 'proxyObservationType': ['Lower95', 'TEX86'], 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'})])
# archive:  lake sediment
# Afr-P178-15P.Tierney.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Afr-P178-15P.Tierney.2015.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Afr-P178-15P.Tierney.2015.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: Afr-P178-15P.Tierney.2015.paleo1measurement0.csv, 'values'
# Error: get_csv_from_columns: Afr-P178-15P.Tierney.2015.paleo2measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('temperature', {'calibration': [{'equation': 'BAYSPAR Bayesian calibration', 'reference': '10.1038/sdata.2015.29'}], 'dataType': 'float', 'description': 'median calibrated ssts from tex86, using BAYSPAR-NRS (Tierney & Tingley, 2014, GCA)', 'number': '1', 'hasMaxValue': 27.8932, 'hasMeanValue': 27.344578301887, 'hasMedianValue': 27.37305, 'hasMinValue': 26.7173, 'TSid': 'LPD53e179ad', 'inferredVariableType': 'Temperature', 'measurementMethod': 'BAYSPAR Bayesian calibration', 'variableName': 'temperature', 'notes': '; paleoData_variableName changed - was originally sst; paleoData_units changed - was originally deg C; climateInterpretation_seasonality changed - was originally Annual', 'pages2kID': 'Ocn_137', 'qCCertification': 'JET', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'inferred'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1980, 'hasMeanValue': 1127.116745283, 'hasMedianValue': 1181.875, 'hasMinValue': 131, 'TSid': 'PYTHCZK7IUA', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  marine sediment
# Ant-BerknerIsland.Mulvaney.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-BerknerIsland.Mulvaney.2002.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-BerknerIsland.Mulvaney.2002.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -24.3, 'hasMeanValue': -28.298002018163, 'hasMedianValue': -28.29, 'hasMinValue': -32.22, 'TSid': 'Ant_005', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_012', 'proxyObservationType': 'D18O', 'qCCertification': 'RM', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1992, 'hasMeanValue': 1496, 'hasMedianValue': 1496, 'hasMinValue': 1000, 'TSid': 'PYT7MHHAVNY', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-CoastalDML.Thamban.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-CoastalDML.Thamban.2012.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-CoastalDML.Thamban.2012.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -21.4503, 'hasMeanValue': -25.555087746688, 'hasMedianValue': -25.44935, 'hasMinValue': -31.9438, 'TSid': 'Ant_017', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_004', 'proxyObservationType': 'D18O', 'qCCertification': 'MT', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1994, 'hasMeanValue': 1763.5, 'hasMedianValue': 1763.5, 'hasMinValue': 1533, 'TSid': 'PYTRVR5CU7S', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DomeC.Jouzel.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeC.Jouzel.2001.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DomeC.Jouzel.2001.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -377.8, 'hasMeanValue': -396.595, 'hasMedianValue': -397, 'hasMinValue': -410.9, 'TSid': 'Ant_013', 'measurementMaterial': 'melted ice', 'measurementMethod': 'mass spectrometer', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Multi-annual averages; archiveType changed - was originally ice core', 'pages2kID': 'Ant_013', 'proxyObservationType': 'DD', 'qCCertification': 'BS', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1918.9435, 'hasMeanValue': 1043.6971564286, 'hasMedianValue': 1080.13835, 'hasMinValue': 2.6, 'TSid': 'PYTLNUWCCNN', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DomeC.Stenni.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeC.Stenni.2001.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DomeC.Stenni.2001.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -48.14, 'hasMeanValue': -50.719714285714, 'hasMedianValue': -50.74, 'hasMinValue': -52.52, 'TSid': 'Ant_012', 'measurementMaterial': 'melted ice', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Multi-annual averages; archiveType changed - was originally ice core', 'pages2kID': 'Ant_014', 'proxyObservationType': 'D18O', 'qCCertification': 'BS', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1918.9435, 'hasMeanValue': 1043.6971564286, 'hasMedianValue': 1080.13835, 'hasMinValue': 2.6, 'TSid': 'PYTKX2S8AN9', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DomeF1993.Uemura.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeF1993.Uemura.2014.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DomeF1993.Uemura.2014.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -52.02, 'hasMeanValue': -55.155064935065, 'hasMedianValue': -55.22, 'hasMinValue': -57.65, 'TSid': 'Ant_009', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to VSMOW', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Multi-annual averages; archiveType changed - was originally ice core', 'pages2kID': 'Ant_016', 'proxyObservationType': 'D18O', 'qCCertification': 'RU', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1467.208751, 'hasMeanValue': 964.86663476623, 'hasMedianValue': 976.13854, 'hasMinValue': 423.79413, 'TSid': 'PYTIWFYTB5X', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DomeF2001.Uemura.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DomeF2001.Uemura.2008.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DomeF2001.Uemura.2008.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -53.27694, 'hasMeanValue': -55.727727833333, 'hasMedianValue': -55.796975, 'hasMinValue': -58.18143, 'TSid': 'Ant_010', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to VSMOW', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_015', 'proxyObservationType': 'D18O', 'qCCertification': 'RU', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1875, 'hasMeanValue': 1308.6416198347, 'hasMedianValue': 1321.61, 'hasMinValue': 695, 'TSid': 'PYTRLGOF4WC', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DSS.DahlJensen.1999.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DSS.DahlJensen.1999.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DSS.DahlJensen.1999.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: Ant-DSS.DahlJensen.1999.paleo1measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('ghostMeasured', {'number': '1', 'TSid': 'PYT6MORX5YO', 'inferredVariableType': 'Temperature', 'variableName': 'ghostMeasured', 'proxyObservationType': 'GhostMeasured', 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1995, 'hasMeanValue': 273.68571428571, 'hasMedianValue': 1382, 'hasMinValue': -6742, 'TSid': 'PYTSKTJYYTU', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-DSS.Moy.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-DSS.Moy.2012.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-DSS.Moy.2012.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -18.8025, 'hasMeanValue': -22.065378489616, 'hasMedianValue': -22.0724, 'hasMinValue': -24.711, 'TSid': 'Ant_011', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_002', 'proxyObservationType': 'D18O', 'qCCertification': 'ADM', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1995, 'hasMeanValue': 1084, 'hasMedianValue': 1084, 'hasMinValue': 173, 'TSid': 'PYTMM3DSSEV', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-Ferrigno.Thomas.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
# reading: Ant-Ferrigno.Thomas.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-Ferrigno.Thomas.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -178.52025116667, 'hasMeanValue': -203.74575614351, 'hasMedianValue': -203.96402178333, 'hasMinValue': -231.05470933333, 'TSid': 'Ant_014', 'measurementMethod': 'Los Gatos (LWIA-24d) Liquid Water Isotope Analyzer at 5 cm resolution, corresponding to ~14 samples per year.', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_017', 'proxyObservationType': 'DD', 'qCCertification': 'ERT', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2010, 'hasMeanValue': 1856.5, 'hasMedianValue': 1856.5, 'hasMinValue': 1703, 'TSid': 'PYTWYKXIVZ3', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-JamesRossIsland.Mulvaney.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-JamesRossIsland.Mulvaney.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-JamesRossIsland.Mulvaney.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -123.435, 'hasMeanValue': -150.53155235309, 'hasMedianValue': -150.3, 'hasMinValue': -182.62, 'TSid': 'Ant_022', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_010', 'proxyObservationType': 'DD', 'qCCertification': 'RM', 'qCnotes': 'Data for past 1000 years from https://www.ncdc.noaa.gov/paleo/study/14201; data for first millennium CE from https://www.ncdc.noaa.gov/paleo/study/13954 (centennial resolution) plus this study (annual resolution). JRI ice core also has a melt-layer record covering 1000 - 2007 CE http://www.ncdc.noaa.gov/paleo/study/14201', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2007, 'hasMeanValue': 1003.5, 'hasMedianValue': 1003.5, 'TSid': 'PYTIUMCDPN2', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-MES.Rhodes.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-MES.Rhodes.2012.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-MES.Rhodes.2012.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -129.79, 'hasMeanValue': -213.56109847903, 'hasMedianValue': -214.3, 'hasMinValue': -282, 'TSid': 'Ant_033', 'measurementMaterial': 'Deuterium isotope ratio of H1:H2 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer and', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_019', 'proxyObservationType': 'DD', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2006.791, 'hasMeanValue': 1767.166850361, 'hasMedianValue': 1768.331, 'hasMinValue': 1472.646, 'TSid': 'PYTDP33CP9M', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-PlateauRemote.Mosley-Thompson.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-PlateauRemote.Mosley-Thompson.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-PlateauRemote.Mosley-Thompson.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -46.7309, 'hasMeanValue': -54.066469420655, 'hasMedianValue': -54.1268, 'hasMinValue': -59.2563, 'TSid': 'Ant_023', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_003', 'proxyObservationType': 'D18O', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1986, 'hasMeanValue': 994, 'hasMedianValue': 994, 'hasMinValue': 2, 'TSid': 'PYTIT7UETLT', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-SipleStation.Mosley-Thompson.1990.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SipleStation.Mosley-Thompson.1990.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-SipleStation.Mosley-Thompson.1990.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -26.663, 'hasMeanValue': -29.566440917108, 'hasMedianValue': -29.486, 'hasMinValue': -32.828, 'TSid': 'Ant_024', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_011', 'proxyObservationType': 'D18O', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1983, 'hasMeanValue': 1700, 'hasMedianValue': 1700, 'hasMinValue': 1417, 'TSid': 'PYT2EDUWTBN', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-SiteDML05.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML05.Graf.2002.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-SiteDML05.Graf.2002.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -40.4348, 'hasMeanValue': -45.131114538433, 'hasMedianValue': -45.1404, 'hasMinValue': -49.6834, 'TSid': 'Ant_007', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_005', 'proxyObservationType': 'D18O', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1996, 'hasMeanValue': 1081, 'hasMedianValue': 1081, 'hasMinValue': 166, 'TSid': 'PYTKLN9UPV3', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-SiteDML07.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML07.Graf.2002.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-SiteDML07.Graf.2002.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -41.01, 'hasMeanValue': -45.022231237323, 'hasMedianValue': -45.08, 'hasMinValue': -48.43, 'TSid': 'Ant_006', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_020', 'proxyObservationType': 'D18O', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1994, 'hasMeanValue': 1497, 'hasMedianValue': 1497, 'hasMinValue': 1000, 'TSid': 'PYTP5PB6TKK', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-SiteDML17.Graf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-SiteDML17.Graf.2002.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-SiteDML17.Graf.2002.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -42.76, 'hasMeanValue': -46.926575203252, 'hasMedianValue': -46.98, 'hasMinValue': -50.42, 'TSid': 'Ant_008', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_021', 'proxyObservationType': 'D18O', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1997, 'hasMeanValue': 1498.5, 'hasMedianValue': 1498.5, 'hasMinValue': 1000, 'TSid': 'PYT5ILGMU3I', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-TALDICE.Stenni.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TALDICE.Stenni.2010.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-TALDICE.Stenni.2010.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -33.5604, 'hasMeanValue': -36.193960781967, 'hasMedianValue': -36.2239, 'hasMinValue': -38.6603, 'TSid': 'Ant_025', 'measurementMaterial': 'melted ice', 'measurementMethod': 'mass spectrometer', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Multi-annual averages; archiveType changed - was originally ice core', 'pages2kID': 'Ant_022', 'proxyObservationType': 'D18O', 'qCCertification': 'BS', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1990.838, 'hasMeanValue': 1105.2055901639, 'hasMedianValue': 1147.99, 'hasMinValue': 4.3, 'TSid': 'PYT4EDNEMKJ', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-TalosDome.Stenni.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TalosDome.Stenni.2002.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-TalosDome.Stenni.2002.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -238.922, 'hasMeanValue': -286.15346198495, 'hasMedianValue': -286.979, 'hasMinValue': -331.425, 'TSid': 'Ant_026', 'measurementMaterial': 'melted ice', 'measurementMethod': 'mass spectrometer', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_001', 'proxyObservationType': 'DD', 'qCCertification': 'BS', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1995, 'hasMeanValue': 1613.5, 'hasMedianValue': 1613.5, 'hasMinValue': 1232, 'TSid': 'PYTGU3XCCO2', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-TaylorDome.Steig.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-TaylorDome.Steig.2000.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-TaylorDome.Steig.2000.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -34.36, 'hasMeanValue': -40.115744075829, 'hasMedianValue': -40.08, 'hasMinValue': -46.71, 'TSid': 'Ant_035', 'measurementMaterial': 'oxygen isotope ratio 18O/16O in H2O from melted ice compared to VSMOW, normalized to VSMOW-SLAP scale', 'measurementMethod': 'mass spectometry', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Multi-annual averages; archiveType changed - was originally ice core', 'pages2kID': 'Ant_023', 'proxyObservationType': 'D18O', 'qCCertification': 'EJS', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 1937.9837135569, 'hasMeanValue': 1007.7403506139, 'hasMedianValue': 1024.9178947368, 'hasMinValue': -25.421641791045, 'TSid': 'PYTNTICX29S', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'}), ('age', {'dataType': 'float', 'description': 'Years before present (1950) BP', 'number': '3', 'hasMaxValue': 1937.1, 'hasMeanValue': 501.19948275862, 'hasMedianValue': 515.8, 'hasMinValue': -993.4, 'TSid': 'PYTSCBZ7NI9', 'inferredVariableType': 'Age', 'variableName': 'age', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-US-ITASE-2000-1.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-US-ITASE-2000-1.Steig.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-US-ITASE-2000-1.Steig.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -25.6, 'hasMeanValue': -32.929885872918, 'hasMedianValue': -32.95, 'hasMinValue': -38.28, 'TSid': 'Ant_037', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to VSMOW, normalized to VSMOW-SLAP scale', 'measurementMethod': 'mass spectrometry', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Subannual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_008', 'proxyObservationType': 'D18O', 'qCCertification': 'EJS, DAD', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2000.95715, 'hasMeanValue': 1873.6193055967, 'hasMedianValue': 1900.99875, 'hasMinValue': 1673.293, 'TSid': 'PYTJFVNJAFN', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-US-ITASE-2002-4.Steig.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-US-ITASE-2002-4.Steig.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-US-ITASE-2002-4.Steig.2013.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('d18O', {'dataType': 'float', 'detail': 'deviation of oxygen isotope ratio 18O:16O in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -35.705184, 'hasMeanValue': -43.345712425905, 'hasMedianValue': -43.4112215, 'hasMinValue': -49.496928, 'TSid': 'Ant_050', 'measurementMaterial': 'oxygen isotope ratio 18O/16O in H2O from melted ice compared to VSMOW, normalized to VSMOW-SLAP scale', 'measurementMethod': 'laser spectroscopy', 'variableName': 'd18O', 'notes': '; climateInterpretation_seasonality changed - was originally Subannual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_024', 'proxyObservationType': 'D18O', 'qCCertification': 'EJS, DAD', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2002.81925, 'hasMeanValue': 1814.3759514151, 'hasMedianValue': 1823.11455, 'hasMinValue': 1593.5104, 'TSid': 'PYTUYW6Z7MO', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-VLG.Bertler.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-VLG.Bertler.2011.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-VLG.Bertler.2011.paleo0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('dD', {'dataType': 'float', 'detail': 'deviation of deuterium isotope ratio 2H:1H in H2O sample compared to standard mean ocean water (V-SMOW)', 'number': '1', 'hasMaxValue': -191.792, 'hasMeanValue': -224.40367131243, 'hasMedianValue': -223.7523, 'hasMinValue': -264.9713, 'TSid': 'Ant_027', 'measurementMaterial': 'oxygen isotope ratio of O16:O18 in H2O from melted ice compared to standard mean ocean water', 'measurementMethod': 'mass spectrometer', 'variableName': 'dD', 'notes': '; climateInterpretation_seasonality changed - was originally Mean annual values; archiveType changed - was originally ice core', 'pages2kID': 'Ant_025', 'proxyObservationType': 'DD', 'qCCertification': 'MAC', 'useInGlobalTemperatureAnalysis': 't', 'variableType': 'measured'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2000, 'hasMeanValue': 1570, 'hasMedianValue': 1570, 'hasMinValue': 1140, 'TSid': 'PYTKTHUTF8P', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# Ant-Vostok.Ekaykin.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ant-Vostok.Ekaykin.2014.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: Ant-Vostok.Ekaykin.2014.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: Ant-Vostok.Ekaykin.2014.paleo1measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('temperature', {'calibration': [{'uncertaintyType': 'calibrationRMSE'}], 'dataType': 'float', 'description': 'inferred temperature', 'detail': 'Reference period: 1958-2010', 'number': '1', 'hasMaxValue': 1.410603113, 'hasMeanValue': -0.53288227366071, 'hasMedianValue': -0.577781532, 'hasMinValue': -2.260119782, 'TSid': 'Ant_029', 'inferredVariableType': 'Temperature', 'measurementMaterial': 'snow isotope content', 'measurementMethod': 'Regression with the air temperature measured at Vostok station in 1958-2010', 'variableName': 'temperature', 'notes': 'Mean annual snow accumulation rate (0.021 m ice equivalent); mean annual site temperature (-56oC)', 'qCCertification': 'MAC', 'qCnotes': 'Temp inferred from accumulation rate; defer to isotopes', 'useInGlobalTemperatureAnalysis': 'f', 'variableType': 'inferred'}), ('year', {'dataType': 'float', 'description': 'Year AD', 'number': '2', 'hasMaxValue': 2009, 'hasMeanValue': 1869.5, 'hasMedianValue': 1869.5, 'hasMinValue': 1730, 'TSid': 'PYTJHNI58L8', 'inferredVariableType': 'Year', 'variableName': 'year', 'variableType': 'inferred'})])
# archive:  glacier ice
# ...
# archive:  marine sediment
# SK237-GC04.Saraswat.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: SK237-GC04.Saraswat.2013.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: SK237-GC04.Saraswat.2013.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: SK237-GC04.Saraswat.2013.chron0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('depth', {'number': '1', 'hasMaxValue': 286.5, 'hasMeanValue': 144.49298245614, 'hasMedianValue': 144.5, 'hasMinValue': 1, 'TSid': 'PYT0NKYKXZN', 'variableName': 'depth', 'variableType': 'measured'}), ('age', {'number': '2', 'hasMaxValue': 31.6, 'hasMeanValue': 15.464210526316, 'hasMedianValue': 14.44, 'hasMinValue': 0.12, 'TSid': 'PYTA9L1EG5S', 'interpretation': [{'variableDetail': 'calendar', 'variable': 'Age', 'scope': 'Age'}], 'variableName': 'age', 'takenAtDepth': {'foundInTable': 'SK237-GC04.Saraswat.2013.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 286.5, 'hasMeanValue': 144.49298245614, 'hasMedianValue': 144.5, 'hasMinValue': 1, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 0.19, 'hasMeanValue': 0.11084507042254, 'hasMedianValue': 0.11, 'hasMinValue': 0.059999999999999}, 'hasVariableID': 'PYT0NKYKXZN', 'measuredOn': {'name': 'SK237-GC04'}, 'name': 'depth'}, 'variableType': 'inferred'}), ('mg/ca', {'number': '3', 'hasMaxValue': 5.04, 'hasMeanValue': 4.0821071428571, 'hasMedianValue': 4.12, 'hasMinValue': 3.2, 'TSid': 'PYTJY56A19G', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Climate'}], 'variableName': 'mg/ca', 'proxyObservationType': 'Mg/Ca', 'takenAtDepth': {'foundInTable': 'SK237-GC04.Saraswat.2013.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 286.5, 'hasMeanValue': 144.49298245614, 'hasMedianValue': 144.5, 'hasMinValue': 1, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 0.19, 'hasMeanValue': 0.11084507042254, 'hasMedianValue': 0.11, 'hasMinValue': 0.059999999999999}, 'hasVariableID': 'PYT0NKYKXZN', 'measuredOn': {'name': 'SK237-GC04'}, 'name': 'depth'}, 'variableType': 'measured'}), ('sst - mg/ca', {'calibration': [{'calibrationReferences': {'author': ['P.S. Dekens', 'D.W. Lea', {'name': 'D.K. Pak'}, 'H.J. Spero'], 'hasDOI': '10.1029/2001GC000200', 'hasISSN': '1525-2027', 'journal': 'Geochemistry, Geophysics, Geosystems', 'title': 'Core top calibration of Mg/Ca in tropical foraminifera: Refining paleotemperature estimation'}}], 'number': '4', 'hasMaxValue': 29.48, 'hasMeanValue': 27.066357142857, 'hasMedianValue': 27.255, 'hasMinValue': 24.43, 'TSid': 'PYT3F5IG0S4', 'inferredFrom': {'number': '3', 'hasMaxValue': 5.04, 'hasMeanValue': 4.0821071428571, 'hasMedianValue': 4.12, 'hasMinValue': 3.2, 'TSid': 'PYTJY56A19G', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Climate'}], 'variableName': 'mg/ca', 'proxyObservationType': 'Mg/Ca', 'takenAtDepth': {'foundInTable': 'SK237-GC04.Saraswat.2013.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 286.5, 'hasMeanValue': 144.49298245614, 'hasMedianValue': 144.5, 'hasMinValue': 1, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 0.19, 'hasMeanValue': 0.11084507042254, 'hasMedianValue': 0.11, 'hasMinValue': 0.059999999999999}, 'hasVariableID': 'PYT0NKYKXZN', 'measuredOn': {'name': 'SK237-GC04'}, 'name': 'depth'}, 'variableType': 'measured'}, 'inferredVariableType': 'Sea Surface Temperature', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Climate'}], 'variableName': 'sst - mg/ca', 'takenAtDepth': {'foundInTable': 'SK237-GC04.Saraswat.2013.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 286.5, 'hasMeanValue': 144.49298245614, 'hasMedianValue': 144.5, 'hasMinValue': 1, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 0.19, 'hasMeanValue': 0.11084507042254, 'hasMedianValue': 0.11, 'hasMinValue': 0.059999999999999}, 'hasVariableID': 'PYT0NKYKXZN', 'measuredOn': {'name': 'SK237-GC04'}, 'name': 'depth'}, 'variableType': 'inferred'}), ('d18o', {'numbe ...
# archive:  marine sediment
# table_com.py
# temp.py
# TestDataset.2017.Khider.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: TestDataset.2017.Khider.lpd
# Error: Unable to update file to LiPD v1.3: dictionary keys changed during iteration
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: TestDataset.2017.Khider.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: TestDataset.2017.Khider.chron0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('depth', {'description': 'desc', 'detail': 'detail', 'error': 'error', 'number': '1', 'hasMax': 50, 'hasMean': 25.25, 'hasMedian': 31.25, 'hasMin': 0.5, 'resolution': 'PYTOO73ID6Y.depth.Resolution', 'TSid': 'PYTOO73ID6Y', 'inferredVariableType': 'D18o', 'measurementMaterial': 'measmaterial', 'measurementMethod': 'method', 'nOAAdataFormat': 'dataformat', 'nOAAdataType': 'datatype', 'nOAAseasonality': 'seasonality', 'variableName': 'depth', 'notes': 'notes', 'proxyObservationType': 'D18o', 'takenAtDepth': 'PYTOO73ID6Y - depth', 'variableType': 'measured'}), ('age', {'description': 'fasdf', 'detail': 'asdf', 'error': 'sdfa', 'number': '2', 'hasMax': -2.501759838213, 'hasMean': -2.9835684227636, 'hasMedian': -2.9746996222184, 'hasMin': -3.4921271966688, 'TSid': 'PYTXZLB1X8P', 'inferredVariableType': 'Age', 'interpretation': ['PYTXZLB1X8P.age.Interpretation1'], 'measurementMaterial': 'asdf', 'measurementMethod': 'fsadf', 'nOAAdataFormat': 'asdf', 'nOAAdataType': 'asdfa', 'nOAAseasonality': 'asdf', 'variableName': 'age', 'notes': 'asdf', 'takenAtDepth': {'description': 'desc', 'detail': 'detail', 'error': 'error', 'foundInTable': 'Paleo0measurement0', 'hasColumnNumber': '1', 'hasMax': 50, 'hasMean': 25.25, 'hasMedian': 31.25, 'hasMin': 0.5, 'hasProxySystem': 'ProxySystem.MolluskShell.DefaultSensor', 'hasResolution': 'PYTOO73ID6Y.depth.Resolution', 'hasVariableID': 'PYTOO73ID6Y', 'inferredVariableType': 'D18o', 'measuredOn': 'HEISER', 'measurementMaterial': 'measmaterial', 'method': 'method', 'nOAAdataFormat': 'dataformat', 'nOAAdataType': 'datatype', 'nOAAseasonality': 'seasonality', 'name': 'depth', 'notes': 'notes', 'proxyObservationType': 'D18o', 'takenAtDepth': 'PYTOO73ID6Y - depth'}, 'variableType': 'inferred'}), ('mg', {'description': 'asdfas', 'detail': 'sdfasd', 'error': 'asdf', 'number': '3', 'hasMax': 5.9978935837775, 'hasMaxValue': 5.9978935837775, 'hasMean': 5.487939249115, 'hasMeanValue': 5.487939249115, 'hasMedian': 5.4961083078768, 'hasMedianValue': 5.4961083078768, 'hasMin': 5.007731243587, 'hasMinValue': 5.007731243587, 'resolution': ['23.2975', 'PYT7Z7JMLKT.mg.Resolution'], 'TSid': 'PYT7Z7JMLKT', 'interpretation': ['PYT7Z7JMLKT.mg.Interpretation1'], 'measurementMaterial': 'asdf', 'measurementMethod': 'asdfas', 'nOAAdataFormat': 'asdfa', 'nOAAdataType': 'asdf', 'nOAAseasonality': 'asdf', 'variableName': 'mg', 'notes': 'asdfad', 'proxyObservationType': 'Mg/Ca', 'sensorSpecies': 'ruber', 'takenAtDepth': {'description': 'desc', 'detail': 'detail', 'error': 'error', 'foundInTable': 'Paleo0measurement0', 'hasColumnNumber': '1', 'hasMax': 50, 'hasMean': 25.25, 'hasMedian': 31.25, 'hasMin': 0.5, 'hasProxySystem': 'ProxySystem.MolluskShell.DefaultSensor', 'hasResolution': 'PYTOO73ID6Y.depth.Resolution', 'hasVariableID': 'PYTOO73ID6Y', 'inferredVariableType': 'D18o', 'measuredOn': 'HEISER', 'measurementMaterial': 'measmaterial', 'method': 'method', 'nOAAdataFormat': 'dataformat', 'nOAAdataType': 'datatype', 'nOAAseasonality': 'seasonality', 'name': 'depth', 'notes': 'notes', 'proxyObservationType': 'D18o', 'takenAtDepth': 'PYTOO73ID6Y - depth'}, 'variableType': 'measured'}), ('d18o', {'description': 'qwefqwe', 'detail': 'asdfa', 'error': 'fasdfas', 'number': '4', 'hasMax': 30.655470716445, 'hasMaxValue': -2.501759838213, 'hasMean': 29.652247314657, 'hasMeanValue': -2.9835684227636, 'hasMedian': 29.674027630715, 'hasMedianValue': -2.9746996222184, 'hasMin': 28.650744368906, 'hasMinValue': -3.4921271966688, 'resolution': ['23.2975', 'PYTOYBFQ376.d18o.Resolution'], 'TSid': 'PYTOYBFQ376', 'interpretation': ['PYTOYBFQ376.d18o.Interpretation1', 'PYTOYBFQ376.d18o.Interpretation2'], 'measurementMaterial': 'sdfasd', 'measurementMethod': 'asdfasd', 'nOAAdataFormat': 'fasdfad', 'nOAAdataType': 'asdfasd', 'nOAAseasonality': 'sadfasd', 'variableName': 'd18o', 'notes': 'asdfa', 'proxyObservationType': 'D18O', 'sensorSpecies': 'ruber', 'takenAtDepth': {'description': 'desc', 'detail': 'detail', 'error': 'error', 'foundInTable ...
# archive:  h
# TR163-22.Lea.2006.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: TR163-22.Lea.2006.lpd
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: Missing filename for a table
# Error: merge_csv_column: No filename found for table
# Error: get_csv_from_columns: TR163-22.Lea.2006.paleo0measurement0.csv, 'values'
# Error: get_csv_from_columns: TR163-22.Lea.2006.chron0measurement0.csv, 'values'
# Finished read: 1 record
# OrderedDict([('depth', {'number': '1', 'hasMaxValue': 881.5, 'hasMeanValue': 453.45550351288, 'hasMedianValue': 455, 'hasMinValue': 2, 'TSid': 'PYT3CJMYQQ7', 'variableName': 'depth', 'variableType': 'measured'}), ('14cage', {'number': '2', 'hasMaxValue': 135100, 'hasMeanValue': 56654.332552693, 'hasMedianValue': 52700, 'hasMinValue': 1200, 'TSid': 'PYTGJZC6UWI', 'inferredVariableType': 'Age', 'interpretation': [{'variableDetail': 'calendar', 'variable': 'Age', 'scope': 'Age'}], 'variableName': '14cage', 'takenAtDepth': {'foundInTable': 'TR163-22.Lea.2006.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 881.5, 'hasMeanValue': 453.45550351288, 'hasMedianValue': 455, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 700, 'hasMeanValue': 314.31924882629, 'hasMedianValue': 300, 'hasMinValue': 100}, 'hasVariableID': 'PYT3CJMYQQ7', 'measuredOn': {'name': 'TR163-22'}, 'name': 'depth'}, 'variableType': 'inferred'}), ('d18og', {'number': '3', 'hasMaxValue': 0.23, 'hasMeanValue': -0.84035545023697, 'hasMedianValue': -0.745, 'hasMinValue': -2.15, 'missingValue': 'NaN', 'TSid': 'PYT3L6BW4OB', 'interpretation': [{'variableDetail': 'sea surface', 'variable': 'Temperature', 'scope': 'Climate'}, {'variableDetail': 'sea surface', 'variable': 'd18Osw', 'scope': 'Isotope'}], 'instrument': {'housedAt': 'University of California Davis', 'name': 'Fisons Optima isotope ratio mass spectrometer attached to an Isocarb common acid bath auto carbonate device'}, 'measurementMethod': '25-30 individual shells were pooled, sonicated for 5s in methanol, roasted at 375 degC for 30 min in vacuo and then reacted individually in 105% H3PO4 at 90degC', 'variableName': 'd18og', 'proxyObservationType': 'D18O', 'measurementStandard': 'VPDB', 'takenAtDepth': {'foundInTable': 'TR163-22.Lea.2006.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 881.5, 'hasMeanValue': 453.45550351288, 'hasMedianValue': 455, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 700, 'hasMeanValue': 314.31924882629, 'hasMedianValue': 300, 'hasMinValue': 100}, 'hasVariableID': 'PYT3CJMYQQ7', 'measuredOn': {'name': 'TR163-22'}, 'name': 'depth'}, 'variableType': 'measured'}), ('d18ou', {'number': '4', 'hasMaxValue': 5.12, 'hasMeanValue': 4.1378947368421, 'hasMedianValue': 4.235, 'hasMinValue': 2.8, 'missingValue': 'NaN', 'TSid': 'PYT4GF6APIN', 'interpretation': [{'variableDetail': 'bottom water', 'variable': 'Temperature', 'scope': 'Climate'}, {'variableDetail': 'bottom water', 'variable': 'd18Osw', 'scope': 'Isotope'}], 'instrument': {'housedAt': 'University of Cambridge', 'name': 'VG PRISM mass spectrometer with the Multiprep device'}, 'measurementMethod': '60-100 shells were gently crushed open under glass slides. Samples were purified of organic matter with hydrogen peroxide, ultasonicated in acetone, dried at 50C', 'variableName': 'd18ou', 'proxyObservationType': 'D18O', 'measurementStandard': 'VPDB', 'takenAtDepth': {'foundInTable': 'TR163-22.Lea.2006.paleo1measurement1', 'hasColumnNumber': '1', 'hasMaxValue': 881.5, 'hasMeanValue': 453.45550351288, 'hasMedianValue': 455, 'hasMinValue': 2, 'hasProxySystem': {'proxyArchiveType': 'MarineSediment', 'proxySensorType': 'Globigerinoides ruber'}, 'hasResolution': {'hasMaxValue': 700, 'hasMeanValue': 314.31924882629, 'hasMedianValue': 300, 'hasMinValue': 100}, 'hasVariableID': 'PYT3CJMYQQ7', 'measuredOn': {'name': 'TR163-22'}, 'name': 'depth'}, 'variableType': 'measured'}), ('d18ow', {'calibration': [{'calibrationReferences': {'author': ['B.E. Bemis', 'H.J. Spero', 'J. Bijma', 'D.W. Lea'], 'hasDOI': '10.1029/98PA00070', 'journal': 'Paleoceanography', 'title': 'Reevaluation of the oxygen isotopic composition of planktonic foraminifera: experimental results and revised paleotemperature equations'}, 'equation': 'T = 16.5 - 4.8*(d ...
# archive:  marine sediment

# %%
table_com=table.explode('proxyObservationType').explode('units').explode('inferredVariableType').explode('interpretation/variable').explode('interpretation/variableDetail').reset_index()
#print(table_com)
table_com = table_com.drop(columns = ['index'])
table_com.to_csv('raw-data-table.csv', sep = ',', encoding = 'utf-8',index = False)
