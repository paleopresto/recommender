# %%
# Date : 04/29/21
# %run train_lstm_author.py -e 150 -l 0.005
# Out:
# D:\annotating_paleoclimate_data\recommender\paleorec_research\author_code\training
# list of len {'1': 1694, '2': 1841, '3': 3567, '4_units': 3614, '4': 3964, '5': 4093, '6': 5053, '7': 5058}
# 27337
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/150 Training Loss: 2.4990830426394197
# Epoch: 1/150 Training Loss: 1.5798966073396294
# Epoch: 2/150 Training Loss: 1.4195745683804588
# Epoch: 3/150 Training Loss: 1.3445511522134805
# Epoch: 4/150 Training Loss: 1.28423360225076
# Epoch: 5/150 Training Loss: 1.2468312647332789
# Epoch: 6/150 Training Loss: 1.2191127662342118
# Epoch: 7/150 Training Loss: 1.1968368875535198
# Epoch: 8/150 Training Loss: 1.1769767791898418
# Epoch: 9/150 Training Loss: 1.1627306013186443
# Epoch: 10/150 Training Loss: 1.149090275972216
# Epoch: 11/150 Training Loss: 1.1355721530083305
# ...

# %%
# Date : 04/29/21
# %run train_lstm_author.py -e 100 -l 0.005 -u
# Out:
# D:\annotating_paleoclimate_data\recommender\paleorec_research\author_code\training
# list of len {'1': 1694, '2': 1841, '3': 3567, '4_units': 3614, '4': 3964, '5': 4093, '6': 5053, '7': 5058}
# 27337
#
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Training Loss: 2.9862942220759097
# Epoch: 1/100 Training Loss: 2.1381324524701384
# Epoch: 2/100 Training Loss: 1.9882301196023142
# Epoch: 3/100 Training Loss: 1.8985830629514955
# Epoch: 4/100 Training Loss: 1.8456155294204648
# Epoch: 5/100 Training Loss: 1.8055760954425544
# Epoch: 6/100 Training Loss: 1.7734817746269258
# Epoch: 7/100 Training Loss: 1.73988489342923
# Epoch: 8/100 Training Loss: 1.7116148654850687
# Epoch: 9/100 Training Loss: 1.6882756201558093
# Epoch: 10/100 Training Loss: 1.6591404295561225
# Epoch: 11/100 Training Loss: 1.634979797102109
# Epoch: 12/100 Training Loss: 1.612901905760231
# Epoch: 13/100 Training Loss: 1.5912124131230398
# ...
