# %%
# %run fang_metrics.py
# Out:
# **************************************************************************************
# *************************************************************************************************

# %%
# %run fang_metrics_author.py
# Out:
# actual length = 13, received length = 12
# actual length = 13, received length = 7
# actual length = 13, received length = 1
# actual length = 13, received length = 3
# actual length = 13, received length = 1
# actual length = 14, received length = 12
# actual length = 1, received length = 2
# actual length = 13, received length = 3
# actual length = 4, received length = 2
# actual length = 13, received length = 1
# actual length = 16, received length = 14
# actual length = 13, received length = 4
# **************************************************************************************
# *************************************************************************************************
